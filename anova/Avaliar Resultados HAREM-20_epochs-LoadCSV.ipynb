# %%
import json
import pandas as pd
from pathlib import Path
from pprint import pprint
import datetime
import time
import numpy as np
import matplotlib as plt
import pandas
import researchpy as rp
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
# %matplotlib inline
# Out:
# /Users/home/Desenvolvimento/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
TRAINING_ID = 'Training_ID'
SCENARIO = 'Scenario'
MODEL = 'Model'
EMBEDDING = 'Embedding'
BATCH_SIZE = 'Batch_Size'
ELMO_DROPOUT = 'ELMo_Dropout'
TRAINING_NUMBER = 'Training_Number'
BEST_EPOCH = 'Best_Epoch'
TRAINING_EPOCHS = 'Training_Epochs'
TRAINING_DURATION = 'Training_Duration'
TOTAL_DURATION = 'Total_Duration(s)'
AVERAGE_EPOCH_DURATION = 'Average_Epoch_Duration(s)'
TRAINING_ACCURACY = 'Training_Accuracy'
TRAINING_ACCURACY_TOP3 = 'Training_Accuracy_Top-3'
TRAINING_PRECISION = 'Training_Precision'
TRAINING_RECALL = 'Training_Recall'
TRAINING_F1_MEASURE = 'Training_F1-Measure'
TRAINING_LOSS = 'Training_Loss'
BEST_VALIDATION_ACCURACY = 'Best_Validation_Accuracy'
BEST_VALIDATION_ACCURACY_TOP3 = 'Best_Validation_Accuracy_Top-3'
BEST_VALIDATION_PRECISION = 'Best_Validation_Precision'
BEST_VALIDATION_RECALL = 'Best_Validation_Recall'
BEST_VALIDATION_F1_MEASURE = 'Best_Validation_F1-Measure'
BEST_VALIDATION_LOSS = 'Best_Validation_Loss'
TEST_ACCURACY = 'Test_Accuracy'
TEST_ACCURACY_TOP3 = 'Test_Accuracy_Top-3'
TEST_PRECISION = 'Test_Precision'
TEST_RECALL = 'Test_Recall'
TEST_F1_MEASURE = 'Test_F1_Measure'
TEST_LOSS = 'Test_Loss'

# %%
columns = [TRAINING_ID, SCENARIO, MODEL, EMBEDDING, BATCH_SIZE, ELMO_DROPOUT, TRAINING_NUMBER, BEST_EPOCH, TRAINING_EPOCHS, TRAINING_DURATION, TOTAL_DURATION, AVERAGE_EPOCH_DURATION, TRAINING_ACCURACY, TRAINING_ACCURACY_TOP3, TRAINING_PRECISION, TRAINING_RECALL, TRAINING_F1_MEASURE, TRAINING_LOSS, BEST_VALIDATION_ACCURACY, BEST_VALIDATION_ACCURACY_TOP3, BEST_VALIDATION_PRECISION, BEST_VALIDATION_RECALL, BEST_VALIDATION_F1_MEASURE, BEST_VALIDATION_LOSS, TEST_ACCURACY, TEST_ACCURACY_TOP3, TEST_PRECISION, TEST_RECALL, TEST_F1_MEASURE, TEST_LOSS]

# %%
columns
# Out:
# ['Training_ID',
#  'Scenario',
#  'Model',
#  'Embedding',
#  'Batch_Size',
#  'ELMo_Dropout',
#  'Training_Number',
#  'Best_Epoch',
#  'Training_Epochs',
#  'Training_Duration',
#  'Total_Duration(s)',
#  'Average_Epoch_Duration(s)',
#  'Training_Accuracy',
#  'Training_Accuracy_Top-3',
#  'Training_Precision',
#  'Training_Recall',
#  'Training_F1-Measure',
#  'Training_Loss',
#  'Best_Validation_Accuracy',
#  'Best_Validation_Accuracy_Top-3',
#  'Best_Validation_Precision',
#  'Best_Validation_Recall',
#  'Best_Validation_F1-Measure',
#  'Best_Validation_Loss',
#  'Test_Accuracy',
#  'Test_Accuracy_Top-3',
#  'Test_Precision',
#  'Test_Recall',
#  'Test_F1_Measure',
#  'Test_Loss']

# %%
pd.set_option('display.max_columns', 1000)
path_results = 'training_data_20_epochs.csv'
training_data_df = pd.read_csv(path_results)
training_data_df
# Out:
#      Unnamed: 0                                       Training_ID   Scenario  \
# 0             1  selective_harem-transformer-ft_wang2vec_32_0.5_1  selective
# 1             2    selective_harem-transformer-ft_wang2vec_32_0_7  selective
# 2             3     selective_harem-transformer-ft_glove_32_0.5_2  selective
# 3             5    selective_harem-transformer-ft_fasttext_64_0_7  selective
# 4             6     selective_harem-transformer-ft_glove_32_0.5_6  selective
# 5             7  selective_harem-transformer-ft_fasttext_64_0.5_4  selective
# 6             9    selective_harem-transformer-ft_fasttext_64_0_1  selective
# 7            10  selective_harem-transformer-ft_word2vec_64_0.5_5  selective
# 8            11  selective_harem-transformer-ft_wang2vec_64_0.5_2  selective
# 9            12  selective_harem-transformer-ft_fasttext_64_0.5_6  selective
# 10           13       selective_harem-transformer-ft_glove_32_0_4  selective
# 11           15     selective_harem-transformer-ft_glove_32_0.5_8  selective
# 12           16       selective_harem-transformer-ft_glove_32_0_5  selective
# 13           17     selective_harem-transformer-ft_glove_32_0.5_9  selective
# 14           19    selective_harem-transformer-ft_wang2vec_32_0_1  selective
# 15           20  selective_harem-transformer-ft_word2vec_32_0.5_9  selective
# 16           22    selective_harem-transformer-ft_fasttext_32_0_9  selective
# 17           26  selective_harem-transformer-ft_word2vec_32_0.5_6  selective
# 18           28    selective_harem-transformer-ft_wang2vec_32_0_8  selective
# 19           29    selective_harem-transformer-ft_word2vec_32_0_4  selective
# 20           30  selective_harem-transformer-ft_wang2vec_64_0.5_8  selective
# 21           31    selective_harem-transformer-ft_wang2vec_64_0_3  selective
# 22           34  selective_harem-transformer-ft_wang2vec_64_0.5_5  selective
# 23           35    selective_harem-transformer-ft_wang2vec_32_0_5  selective
# 24           36    selective_harem-transformer-ft_wang2vec_32_0_6  selective
# 25           38       selective_harem-transformer-ft_glove_64_0_3  selective
# 26           40  selective_harem-transformer-ft_wang2vec_64_0.5_1  selective
# 27           41  selective_harem-transformer-ft_word2vec_32_0.5_3  selective
# 28           42    selective_harem-transformer-ft_fasttext_64_0_2  selective
# 29           43    selective_harem-transformer-ft_word2vec_64_0_0  selective
# ..          ...                                               ...        ...
# 610         830                 selective_harem_wang2vec_64_0.5_0  selective
# 611         831                 selective_harem_fasttext_64_0.5_1  selective
# 612         832                   selective_harem_word2vec_32_0_1  selective
# 613         833                 selective_harem_word2vec_64_0.5_8  selective
# 614         834                 selective_harem_word2vec_32_0.5_0  selective
# 615         835                 selective_harem_wang2vec_64_0.5_7  selective
# 616         836                 selective_harem_wang2vec_64_0.5_4  selective
# 617         837                   selective_harem_fasttext_32_0_1  selective
# 618         838                   selective_harem_fasttext_64_0_7  selective
# 619         839                   selective_harem_word2vec_32_0_7  selective
# 620         840                      selective_harem_glove_64_0_8  selective
# 621         842                 selective_harem_wang2vec_32_0.5_9  selective
# 622         843                   selective_harem_wang2vec_32_0_5  selective
# 623         844                 selective_harem_fasttext_64_0.5_9  selective
# 624         845                    selective_harem_glove_64_0.5_1  selective
# 625         846                   selective_harem_wang2vec_64_0_1  selective
# 626         847                 selective_harem_wang2vec_32_0.5_7  selective
# 627         848                 selective_harem_fasttext_32_0.5_8  selective
# 628         849                      selective_harem_glove_64_0_2  selective
# 629         850                 selective_harem_fasttext_64_0.5_6  selective
# 630         851                 selective_harem_wang2vec_32_0.5_2  selective
# 631         852                    selective_harem_glove_32_0.5_2  selective
# 632         853                 selective_harem_word2vec_64_0.5_6  selective
# 633         854                   selective_harem_fasttext_64_0_6  selective
# 634         855                   selective_harem_wang2vec_32_0_6  selective
# 635         856                 selective_harem_wang2vec_64_0.5_3  selective
# 636         857                 selective_harem_word2vec_64_0.5_9  selective
# 637         858                   selective_harem_wang2vec_64_0_3  selective
# 638         859                 selective_harem_wang2vec_32_0.5_6  selective
# 639         860                   selective_harem_fasttext_32_0_4  selective
#
#                     Model Embedding  Batch_Size  ELMo_Dropout  \
# 0    harem-transformer-ft  wang2vec          32           0.5
# 1    harem-transformer-ft  wang2vec          32           0.0
# 2    harem-transformer-ft     glove          32           0.5
# 3    harem-transformer-ft  fasttext          64           0.0
# 4    harem-transformer-ft     glove          32           0.5
# 5    harem-transformer-ft  fasttext          64           0.5
# 6    harem-transformer-ft  fasttext          64           0.0
# 7    harem-transformer-ft  word2vec          64           0.5
# 8    harem-transformer-ft  wang2vec          64           0.5
# 9    harem-transformer-ft  fasttext          64           0.5
# 10   harem-transformer-ft     glove          32           0.0
# 11   harem-transformer-ft     glove          32           0.5
# 12   harem-transformer-ft     glove          32           0.0
# 13   harem-transformer-ft     glove          32           0.5
# 14   harem-transformer-ft  wang2vec          32           0.0
# 15   harem-transformer-ft  word2vec          32           0.5
# 16   harem-transformer-ft  fasttext          32           0.0
# 17   harem-transformer-ft  word2vec          32           0.5
# 18   harem-transformer-ft  wang2vec          32           0.0
# 19   harem-transformer-ft  word2vec          32           0.0
# 20   harem-transformer-ft  wang2vec          64           0.5
# 21   harem-transformer-ft  wang2vec          64           0.0
# 22   harem-transformer-ft  wang2vec          64           0.5
# 23   harem-transformer-ft  wang2vec          32           0.0
# 24   harem-transformer-ft  wang2vec          32           0.0
# 25   harem-transformer-ft     glove          64           0.0
# 26   harem-transformer-ft  wang2vec          64           0.5
# 27   harem-transformer-ft  word2vec          32           0.5
# 28   harem-transformer-ft  fasttext          64           0.0
# 29   harem-transformer-ft  word2vec          64           0.0
# ..                    ...       ...         ...           ...
# 610                 harem  wang2vec          64           0.5
# 611                 harem  fasttext          64           0.5
# 612                 harem  word2vec          32           0.0
# 613                 harem  word2vec          64           0.5
# 614                 harem  word2vec          32           0.5
# 615                 harem  wang2vec          64           0.5
# 616                 harem  wang2vec          64           0.5
# 617                 harem  fasttext          32           0.0
# 618                 harem  fasttext          64           0.0
# 12          0.807550   63.699466
# 13          0.806874   52.774816
# 14          0.814005   59.106553
# 15          0.786687   62.341310
# 16          0.813387   60.536980
# 17          0.793788   67.367628
# 18          0.799467   55.367224
# 19          0.815171   64.969948
# 20          0.797960  108.814376
# 21          0.822218  126.313868
# 22          0.804186  108.350723
# 23          0.807865   65.309385
# 24          0.805120   75.103924
# 25          0.809710  117.782388
# 26          0.788348  111.195604
# 27          0.774334   71.473302
# 28          0.816791  122.738832
# 29          0.808712  126.296640
# ..               ...         ...
# 610         0.807385  122.950928
# 611         0.800605  146.803876
# 612         0.802395  101.000322
# 613         0.793765  144.575667
# 614         0.802705   71.695432
# 615         0.806799  133.698298
# 616         0.810088  132.088928
# 617         0.811599   87.090937
# 618         0.814257  165.950252
# 619         0.812901  102.607125
# 620         0.799007  167.595784
# 621         0.806484   74.282023
# 622         0.805405  105.063170
# 623         0.800200  137.113075
# 624         0.805809  137.421713
# 625         0.808904  174.184398
# 626         0.811861   80.631424
# 627         0.786451   65.771333
# 628         0.822145  157.016543
# 629         0.803339  126.768169
# 630         0.805086   58.093797
# 631         0.807900   62.067911
# 632         0.796817  160.007385
# 633         0.803390  191.379289
# 634         0.806751  106.072642
# 635         0.809247  122.033617
# 636         0.790275  129.157412
# 637         0.814901  178.234757
# 638         0.797680   62.225704
# 639         0.816437   88.620657
#
# [640 rows x 31 columns]

# %%
training_data_df = training_data_df[training_data_df.Scenario == 'selective']
len(training_data_df)
# Out:
# 640

# %%
training_data_df.groupby([BATCH_SIZE]).describe()[TOTAL_DURATION]
# Out:
#             count         mean         std     min      25%     50%      75%  \
# Batch_Size
# 32          320.0  2088.490625  549.872792  1513.0  1532.75  2208.0  2619.25
# 64          320.0  1627.831250  312.246150  1289.0  1306.75  1729.0  1919.00
#
#                max
# Batch_Size
# 32          2921.0
# 64          2287.0

# %%
training_data_df.groupby([BATCH_SIZE]).describe()[TEST_F1_MEASURE]
# Out:
#             count      mean       std       min      25%       50%       75%  \
# Batch_Size
# 32          320.0  0.800503  0.011972  0.767568  0.79253  0.802299  0.809736
# 64          320.0  0.801895  0.010440  0.770702  0.79545  0.803439  0.809126
#
#                  max
# Batch_Size
# 32          0.822973
# 64          0.824247

# %%
training_data_df.groupby([BATCH_SIZE, MODEL]).describe()[TEST_F1_MEASURE]
# Out:
#                                  count      mean       std       min  \
# Batch_Size Model
# 32         harem                  80.0  0.805607  0.008538  0.775250
#            harem-ft               80.0  0.807716  0.008243  0.788630
#            harem-transformer-ft   80.0  0.797890  0.011791  0.767568
#            harem-transformer-pt   80.0  0.790798  0.010843  0.769282
# 64         harem                  80.0  0.806305  0.007681  0.782058
#            harem-ft               80.0  0.807398  0.007471  0.788259
#            harem-transformer-ft   80.0  0.800074  0.010507  0.777016
#            harem-transformer-pt   80.0  0.793804  0.009742  0.770702
#
#                                       25%       50%       75%       max
# Batch_Size Model
# 32         harem                 0.801960  0.806770  0.811608  0.822548
#            harem-ft              0.800699  0.808946  0.813825  0.822973
#            harem-transformer-ft  0.790083  0.799999  0.807910  0.817423
#            harem-transformer-pt  0.782852  0.791340  0.798582  0.815554
# 64         harem                 0.801083  0.806945  0.811383  0.823872
#            harem-ft              0.802390  0.807674  0.812615  0.824247
#            harem-transformer-ft  0.791950  0.800964  0.807033  0.822218
#            harem-transformer-pt  0.787260  0.794712  0.800646  0.812543

# %%
training_data_df.groupby([ELMO_DROPOUT]).describe()[TEST_F1_MEASURE]
# Out:
#               count      mean       std       min       25%       50%  \
# ELMo_Dropout
# 0.0           320.0  0.807192  0.008257  0.776818  0.802368  0.808192
# 0.5           320.0  0.795206  0.010634  0.767568  0.788179  0.796097
#
#                    75%       max
# ELMo_Dropout
# 0.0           0.813123  0.824247
# 0.5           0.803411  0.818767

# %%
training_data_df.groupby([EMBEDDING]).describe()[TEST_F1_MEASURE]
# Out:
#            count      mean       std       min       25%       50%       75%  \
# Embedding
# fasttext   160.0  0.799225  0.011209  0.771289  0.791777  0.800638  0.807575
# glove      160.0  0.804439  0.009257  0.782058  0.797326  0.806226  0.810662
# wang2vec   160.0  0.803304  0.010775  0.770702  0.797380  0.805399  0.811280
# word2vec   160.0  0.797829  0.012264  0.767568  0.789893  0.799731  0.807221
#
#                 max
# Embedding
# fasttext   0.822548
# glove      0.824247
# wang2vec   0.822973
# word2vec   0.821343

# %%
training_data_df.groupby([EMBEDDING, MODEL]).describe()[TEST_F1_MEASURE].sort_values(by='mean', ascending=False)
# Out:
#                                 count      mean       std       min       25%  \
# Embedding Model
# glove     harem-ft               40.0  0.810146  0.007260  0.788259  0.807288
# wang2vec  harem-ft               40.0  0.809809  0.007187  0.795782  0.804787
#           harem                  40.0  0.808181  0.006608  0.783779  0.805624
# glove     harem                  40.0  0.807065  0.007813  0.782058  0.805783
# fasttext  harem                  40.0  0.805614  0.008643  0.786451  0.800651
# word2vec  harem-ft               40.0  0.805171  0.008605  0.788630  0.798114
# fasttext  harem-ft               40.0  0.805103  0.006950  0.789323  0.799499
# glove     harem-transformer-ft   40.0  0.803542  0.008384  0.786731  0.797652
# word2vec  harem                  40.0  0.802964  0.008520  0.775250  0.798488
# wang2vec  harem-transformer-ft   40.0  0.801613  0.010034  0.778550  0.797146
# glove     harem-transformer-pt   40.0  0.797002  0.008204  0.783156  0.791103
# fasttext  harem-transformer-ft   40.0  0.796557  0.011036  0.774979  0.788566
# word2vec  harem-transformer-ft   40.0  0.794216  0.012635  0.767568  0.787497
# wang2vec  harem-transformer-pt   40.0  0.793613  0.010501  0.770702  0.788353
# fasttext  harem-transformer-pt   40.0  0.789625  0.009398  0.771289  0.782094
# word2vec  harem-transformer-pt   40.0  0.788964  0.011426  0.769282  0.780961
#
#                                      50%       75%       max
# Embedding Model
# glove     harem-ft              0.810066  0.815947  0.824247
# wang2vec  harem-ft              0.811133  0.814404  0.822973
#           harem                 0.808948  0.812664  0.817017
# glove     harem                 0.807352  0.810795  0.823872
# fasttext  harem                 0.805374  0.813589  0.822548
# word2vec  harem-ft              0.805231  0.812026  0.820047
# fasttext  harem-ft              0.805687  0.809724  0.817352
# glove     harem-transformer-ft  0.805209  0.809039  0.818385
# word2vec  harem                 0.803712  0.809728  0.815892
# wang2vec  harem-transformer-ft  0.802721  0.808138  0.822218
# glove     harem-transformer-pt  0.796292  0.800841  0.815554
# fasttext  harem-transformer-ft  0.795624  0.806262  0.816791
# word2vec  harem-transformer-ft  0.793781  0.803632  0.821343
# wang2vec  harem-transformer-pt  0.794326  0.801016  0.810674
# fasttext  harem-transformer-pt  0.789396  0.798565  0.804841
# word2vec  harem-transformer-pt  0.787023  0.796889  0.809845

# %%
training_data_df.groupby([SCENARIO, BATCH_SIZE, EMBEDDING, MODEL]).describe()[TEST_F1_MEASURE].sort_values(by='mean', ascending=False)
# Out:
#                                                      count      mean  \
# Scenario  Batch_Size Embedding Model
# selective 32         wang2vec  harem-ft               20.0  0.811167
#                      glove     harem-ft               20.0  0.810696
#           64         glove     harem-ft               20.0  0.809595
#                      wang2vec  harem-ft               20.0  0.808451
#                                harem                  20.0  0.808448
#           32         wang2vec  harem                  20.0  0.807914
#           64         glove     harem                  20.0  0.807687
#           32         glove     harem                  20.0  0.806443
#           64         fasttext  harem-ft               20.0  0.805951
#           32         fasttext  harem                  20.0  0.805767
#           64         word2vec  harem-ft               20.0  0.805594
#                      fasttext  harem                  20.0  0.805460
#           32         word2vec  harem-ft               20.0  0.804747
#           64         glove     harem-transformer-ft   20.0  0.804576
#           32         fasttext  harem-ft               20.0  0.804255
#           64         word2vec  harem                  20.0  0.803626
#           32         glove     harem-transformer-ft   20.0  0.802509
#           64         wang2vec  harem-transformer-ft   20.0  0.802377
#           32         word2vec  harem                  20.0  0.802303
#                      wang2vec  harem-transformer-ft   20.0  0.800849
#           64         glove     harem-transformer-pt   20.0  0.797874
#                      word2vec  harem-transformer-ft   20.0  0.796678
#                      fasttext  harem-transformer-ft   20.0  0.796665
#           32         fasttext  harem-transformer-ft   20.0  0.796448
#                      glove     harem-transformer-pt   20.0  0.796130
#           64         wang2vec  harem-transformer-pt   20.0  0.794013
#           32         wang2vec  harem-transformer-pt   20.0  0.793214
#           64         fasttext  harem-transformer-pt   20.0  0.792030
#           32         word2vec  harem-transformer-ft   20.0  0.791754
#           64         word2vec  harem-transformer-pt   20.0  0.791301
#           32         fasttext  harem-transformer-pt   20.0  0.787219
#                      word2vec  harem-transformer-pt   20.0  0.786628
#
#                                                           std       min  \
# Scenario  Batch_Size Embedding Model
# selective 32         wang2vec  harem-ft              0.007488  0.797089
#                      glove     harem-ft              0.005643  0.800752
#           64         glove     harem-ft              0.008701  0.788259
#                      wang2vec  harem-ft              0.006787  0.795782
#                                harem                 0.005338  0.796176
#           32         wang2vec  harem                 0.007810  0.783779
#           64         glove     harem                 0.009497  0.782058
#           32         glove     harem                 0.005857  0.792066
#           64         fasttext  harem-ft              0.006607  0.790246
#           32         fasttext  harem                 0.009992  0.786451
#           64         word2vec  harem-ft              0.007401  0.795424
#                      fasttext  harem                 0.007311  0.791032
#           32         word2vec  harem-ft              0.009841  0.788630
#           64         glove     harem-transformer-ft  0.007720  0.791984
#           32         fasttext  harem-ft              0.007347  0.789323
#           64         word2vec  harem                 0.007616  0.790275
#           32         glove     harem-transformer-ft  0.009079  0.786731
#           64         wang2vec  harem-transformer-ft  0.010897  0.778550
#           32         word2vec  harem                 0.009492  0.775250
#                      wang2vec  harem-transformer-ft  0.009310  0.782551
#           64         glove     harem-transformer-pt  0.007365  0.788190
#                      word2vec  harem-transformer-ft  0.010579  0.781932
#                      fasttext  harem-transformer-ft  0.010840  0.777016
#           32         fasttext  harem-transformer-ft  0.011509  0.774979
#                      glove     harem-transformer-pt  0.009072  0.783156
#           64         wang2vec  harem-transformer-pt  0.009899  0.770702
#           32         wang2vec  harem-transformer-pt  0.011314  0.773342
#           64         fasttext  harem-transformer-pt  0.009165  0.777647
#           32         word2vec  harem-transformer-ft  0.014248  0.767568
#           64         word2vec  harem-transformer-pt  0.011444  0.772601
#           32         fasttext  harem-transformer-pt  0.009227  0.771289
#                      word2vec  harem-transformer-pt  0.011204  0.769282
#
#                                                           25%       50%  \
# Scenario  Batch_Size Embedding Model
# selective 32         wang2vec  harem-ft              0.805600  0.811849
#                      glove     harem-ft              0.807584  0.810066
#           64         glove     harem-ft              0.807288  0.810842
#                      wang2vec  harem-ft              0.803925  0.809105
#                                harem                 0.806527  0.809120
#           32         wang2vec  harem                 0.805518  0.807631
#           64         glove     harem                 0.805092  0.807352
#           32         glove     harem                 0.806033  0.807546
#           64         fasttext  harem-ft              0.803052  0.806591
#           32         fasttext  harem                 0.800003  0.807517
#           64         word2vec  harem-ft              0.799063  0.805128
#                      fasttext  harem                 0.800651  0.804973
#           32         word2vec  harem-ft              0.797691  0.805596
#           64         glove     harem-transformer-ft  0.798162  0.805446
#           32         fasttext  harem-ft              0.798868  0.801772
#           64         word2vec  harem                 0.797368  0.805203
#           32         glove     harem-transformer-ft  0.797190  0.800811
#           64         wang2vec  harem-transformer-ft  0.797816  0.802348
#           32         word2vec  harem                 0.799054  0.802883
#                      wang2vec  harem-transformer-ft  0.795041  0.803315
#           64         glove     harem-transformer-pt  0.792655  0.796418
#                      word2vec  harem-transformer-ft  0.790208  0.792655
#                      fasttext  harem-transformer-ft  0.789918  0.795624
#           32         fasttext  harem-transformer-ft  0.788241  0.796845
#                      glove     harem-transformer-pt  0.788840  0.795473
#           64         wang2vec  harem-transformer-pt  0.788353  0.795254
#           32         wang2vec  harem-transformer-pt  0.787412  0.793610
#           64         fasttext  harem-transformer-pt  0.784309  0.792723
#           32         word2vec  harem-transformer-ft  0.782823  0.795107
#           64         word2vec  harem-transformer-pt  0.783381  0.790043
#           32         fasttext  harem-transformer-pt  0.779121  0.785467
#                      word2vec  harem-transformer-pt  0.780262  0.784136
#
#                                                           75%       max
# Scenario  Batch_Size Embedding Model
# selective 32         wang2vec  harem-ft              0.817026  0.822973
#                      glove     harem-ft              0.813825  0.821729
#           64         glove     harem-ft              0.816129  0.824247
#                      wang2vec  harem-ft              0.813673  0.818674
#                                harem                 0.812134  0.814941
#           32         wang2vec  harem                 0.813485  0.817017
#           64         glove     harem                 0.813172  0.823872
#           32         glove     harem                 0.809940  0.813786
#           64         fasttext  harem-ft              0.809635  0.816497
#           32         fasttext  harem                 0.813589  0.822548
#           64         word2vec  harem-ft              0.811144  0.819051
#                      fasttext  harem                 0.811231  0.818104
#           32         word2vec  harem-ft              0.812526  0.820047
#           64         glove     harem-transformer-ft  0.808550  0.818385
#           32         fasttext  harem-ft              0.809724  0.817352
#           64         word2vec  harem                 0.809975  0.815892
#           32         glove     harem-transformer-ft  0.809039  0.817423
#           64         wang2vec  harem-transformer-ft  0.810522  0.822218
#           32         word2vec  harem                 0.808021  0.815785
#                      wang2vec  harem-transformer-ft  0.808067  0.814005
#           64         glove     harem-transformer-pt  0.801597  0.812543
#                      word2vec  harem-transformer-ft  0.805132  0.821343
#                      fasttext  harem-transformer-ft  0.802875  0.816791
#           32         fasttext  harem-transformer-ft  0.806262  0.813387
#                      glove     harem-transformer-pt  0.800841  0.815554
#           64         wang2vec  harem-transformer-pt  0.800255  0.808741
#           32         wang2vec  harem-transformer-pt  0.801143  0.810674
#           64         fasttext  harem-transformer-pt  0.800542  0.803811
#           32         word2vec  harem-transformer-ft  0.800186  0.815171
#           64         word2vec  harem-transformer-pt  0.801188  0.809845
#           32         fasttext  harem-transformer-pt  0.793403  0.804841
#                      word2vec  harem-transformer-pt  0.795058  0.806343

# %%
training_data_df.groupby([SCENARIO, ELMO_DROPOUT, BATCH_SIZE, EMBEDDING, MODEL]).describe()[TEST_F1_MEASURE].sort_values(by='mean', ascending=False)
# Out:
#                                                                   count  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft               10.0
#                                   glove     harem-ft               10.0
#                        64         glove     harem-ft               10.0
#                                             harem                  10.0
#                        32         fasttext  harem                  10.0
#                                   word2vec  harem-ft               10.0
#                        64         wang2vec  harem-ft               10.0
#                        32         wang2vec  harem                  10.0
#                        64         wang2vec  harem                  10.0
#                                   word2vec  harem-ft               10.0
#                                   glove     harem-transformer-ft   10.0
#                        32         glove     harem                  10.0
#                        64         fasttext  harem-ft               10.0
#                                             harem                  10.0
#                        32         glove     harem-transformer-ft   10.0
#                        64         wang2vec  harem-transformer-ft   10.0
#                                   word2vec  harem                  10.0
#                        32         word2vec  harem                  10.0
#                                   fasttext  harem-ft               10.0
#                                   wang2vec  harem-transformer-ft   10.0
#           0.5          32         wang2vec  harem-ft               10.0
#                                   glove     harem-ft               10.0
#           0.0          32         fasttext  harem-transformer-ft   10.0
#           0.5          64         wang2vec  harem                  10.0
#                                   glove     harem-ft               10.0
#           0.0          64         word2vec  harem-transformer-ft   10.0
#           0.5          64         wang2vec  harem-ft               10.0
#                        32         wang2vec  harem                  10.0
#           0.0          64         fasttext  harem-transformer-ft   10.0
#                                   glove     harem-transformer-pt   10.0
# ...                                                                 ...
#           0.5          64         fasttext  harem-ft               10.0
#                                             harem                  10.0
#           0.0          64         word2vec  harem-transformer-pt   10.0
#           0.5          64         word2vec  harem-ft               10.0
#           0.0          32         wang2vec  harem-transformer-pt   10.0
#                        64         wang2vec  harem-transformer-pt   10.0
#           0.5          32         fasttext  harem-ft               10.0
#                                             harem                  10.0
#                        64         glove     harem-transformer-ft   10.0
#           0.0          64         fasttext  harem-transformer-pt   10.0
#           0.5          64         word2vec  harem                  10.0
#                        32         word2vec  harem-ft               10.0
#                                             harem                  10.0
#                                   glove     harem-transformer-ft   10.0
#                        64         wang2vec  harem-transformer-ft   10.0
#                        32         wang2vec  harem-transformer-ft   10.0
#           0.0          32         fasttext  harem-transformer-pt   10.0
#                                   word2vec  harem-transformer-pt   10.0
#           0.5          64         glove     harem-transformer-pt   10.0
#                        32         glove     harem-transformer-pt   10.0
#                        64         fasttext  harem-transformer-ft   10.0
#                                   word2vec  harem-transformer-ft   10.0
#                                   wang2vec  harem-transformer-pt   10.0
#                        32         fasttext  harem-transformer-ft   10.0
#                                   wang2vec  harem-transformer-pt   10.0
#                        64         fasttext  harem-transformer-pt   10.0
#                                   word2vec  harem-transformer-pt   10.0
#                        32         word2vec  harem-transformer-ft   10.0
#                                   fasttext  harem-transformer-pt   10.0
#                                   word2vec  harem-transformer-pt   10.0
#
#                                                                       mean  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.815009
#                                   glove     harem-ft              0.814221
#                        64         glove     harem-ft              0.813471
#                                             harem                 0.812759
#                        32         fasttext  harem                 0.812586
#                                   word2vec  harem-ft              0.812458
#                        64         wang2vec  harem-ft              0.812409
#                        32         wang2vec  harem                 0.811506
#                        64         wang2vec  harem                 0.810555
#                                   word2vec  harem-ft              0.810468
#                                   glove     harem-transformer-ft  0.810344
#                        32         glove     harem                 0.810226
#                        64         fasttext  harem-ft              0.810136
#                                             harem                 0.809663
#                        32         glove     harem-transformer-ft  0.809435
#                        64         wang2vec  harem-transformer-ft  0.809405
#                                   word2vec  harem                 0.809233
#                        32         word2vec  harem                 0.808837
#                                   fasttext  harem-ft              0.808343
#                                   wang2vec  harem-transformer-ft  0.807398
#           0.5          32         wang2vec  harem-ft              0.807325
#                                   glove     harem-ft              0.807171
#           0.0          32         fasttext  harem-transformer-ft  0.806519
#           0.5          64         wang2vec  harem                 0.806341
#                                   glove     harem-ft              0.805719
#           0.0          64         word2vec  harem-transformer-ft  0.804872
#           0.5          64         wang2vec  harem-ft              0.804493
#                        32         wang2vec  harem                 0.804323
#           0.0          64         fasttext  harem-transformer-ft  0.804003
#                                   glove     harem-transformer-pt  0.802864
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.801766
#                                             harem                 0.801258
#           0.0          64         word2vec  harem-transformer-pt  0.800981
#           0.5          64         word2vec  harem-ft              0.800720
#           0.0          32         wang2vec  harem-transformer-pt  0.800592
#                        64         wang2vec  harem-transformer-pt  0.800397
#           0.5          32         fasttext  harem-ft              0.800167
#                                             harem                 0.798948
#                        64         glove     harem-transformer-ft  0.798807
#           0.0          64         fasttext  harem-transformer-pt  0.798649
#           0.5          64         word2vec  harem                 0.798019
#                        32         word2vec  harem-ft              0.797037
#                                             harem                 0.795769
#                                   glove     harem-transformer-ft  0.795583
#                        64         wang2vec  harem-transformer-ft  0.795349
#                        32         wang2vec  harem-transformer-ft  0.794301
#           0.0          32         fasttext  harem-transformer-pt  0.794289
#                                   word2vec  harem-transformer-pt  0.793878
#           0.5          64         glove     harem-transformer-pt  0.792883
#                        32         glove     harem-transformer-pt  0.789798
#                        64         fasttext  harem-transformer-ft  0.789328
#                                   word2vec  harem-transformer-ft  0.788484
#                                   wang2vec  harem-transformer-pt  0.787629
#                        32         fasttext  harem-transformer-ft  0.786377
#                                   wang2vec  harem-transformer-pt  0.785836
#                        64         fasttext  harem-transformer-pt  0.785412
#                                   word2vec  harem-transformer-pt  0.781620
#                        32         word2vec  harem-transformer-ft  0.781329
#                                   fasttext  harem-transformer-pt  0.780149
#                                   word2vec  harem-transformer-pt  0.779378
#
#                                                                        std  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.006223
#                                   glove     harem-ft              0.004208
#                        64         glove     harem-ft              0.007220
#                                             harem                 0.007745
#                        32         fasttext  harem                 0.006175
#                                   word2vec  harem-ft              0.005398
#                        64         wang2vec  harem-ft              0.003964
#                        32         wang2vec  harem                 0.004667
#                        64         wang2vec  harem                 0.004350
#                                   word2vec  harem-ft              0.006296
#                                   glove     harem-transformer-ft  0.005019
#                        32         glove     harem                 0.002517
#                        64         fasttext  harem-ft              0.004367
#                                             harem                 0.005840
#                        32         glove     harem-transformer-ft  0.005644
#                        64         wang2vec  harem-transformer-ft  0.007973
#                                   word2vec  harem                 0.003823
#                        32         word2vec  harem                 0.004330
#                                   fasttext  harem-ft              0.007085
#                                   wang2vec  harem-transformer-ft  0.004391
#           0.5          32         wang2vec  harem-ft              0.006845
#                                   glove     harem-ft              0.004681
#           0.0          32         fasttext  harem-transformer-ft  0.004156
#           0.5          64         wang2vec  harem                 0.005601
#                                   glove     harem-ft              0.008620
#           0.0          64         word2vec  harem-transformer-ft  0.008387
#           0.5          64         wang2vec  harem-ft              0.006834
#                        32         wang2vec  harem                 0.008850
#           0.0          64         fasttext  harem-transformer-ft  0.008659
#                                   glove     harem-transformer-pt  0.007094
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.005844
#                                             harem                 0.006285
#           0.0          64         word2vec  harem-transformer-pt  0.006203
#           0.5          64         word2vec  harem-ft              0.004819
#           0.0          32         wang2vec  harem-transformer-pt  0.009378
#                        64         wang2vec  harem-transformer-pt  0.006200
#           0.5          32         fasttext  harem-ft              0.005160
#                                             harem                 0.008325
#                        64         glove     harem-transformer-ft  0.005166
#           0.0          64         fasttext  harem-transformer-pt  0.007491
#           0.5          64         word2vec  harem                 0.006161
#                        32         word2vec  harem-ft              0.006572
#                                             harem                 0.008750
#                                   glove     harem-transformer-ft  0.005961
#                        64         wang2vec  harem-transformer-ft  0.008796
#                        32         wang2vec  harem-transformer-ft  0.008270
#           0.0          32         fasttext  harem-transformer-pt  0.006885
#                                   word2vec  harem-transformer-pt  0.010259
#           0.5          64         glove     harem-transformer-pt  0.002975
#                        32         glove     harem-transformer-pt  0.004899
#                        64         fasttext  harem-transformer-ft  0.007311
#                                   word2vec  harem-transformer-ft  0.004088
#                                   wang2vec  harem-transformer-pt  0.008824
#                        32         fasttext  harem-transformer-ft  0.006080
#                                   wang2vec  harem-transformer-pt  0.007830
#                        64         fasttext  harem-transformer-pt  0.004883
#                                   word2vec  harem-transformer-pt  0.005456
#                        32         word2vec  harem-transformer-ft  0.011272
#                                   fasttext  harem-transformer-pt  0.004608
#                                   word2vec  harem-transformer-pt  0.006553
#
#                                                                        min  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.804838
#                                   glove     harem-ft              0.809732
#                        64         glove     harem-ft              0.797062
#                                             harem                 0.799007
#                        32         fasttext  harem                 0.801106
#                                   word2vec  harem-ft              0.804261
#                        64         wang2vec  harem-ft              0.806133
#                        32         wang2vec  harem                 0.805405
#                        64         wang2vec  harem                 0.802285
#                                   word2vec  harem-ft              0.799530
#                                   glove     harem-transformer-ft  0.805412
#                        32         glove     harem                 0.806171
#                        64         fasttext  harem-ft              0.803332
#                                             harem                 0.800864
#                        32         glove     harem-transformer-ft  0.799799
#                        64         wang2vec  harem-transformer-ft  0.797304
#                                   word2vec  harem                 0.802858
#                        32         word2vec  harem                 0.802395
#                                   fasttext  harem-ft              0.797441
#                                   wang2vec  harem-transformer-ft  0.799467
#           0.5          32         wang2vec  harem-ft              0.797089
#                                   glove     harem-ft              0.800752
#           0.0          32         fasttext  harem-transformer-ft  0.800467
#           0.5          64         wang2vec  harem                 0.796176
#                                   glove     harem-ft              0.788259
#           0.0          64         word2vec  harem-transformer-ft  0.790526
#           0.5          64         wang2vec  harem-ft              0.795782
#                        32         wang2vec  harem                 0.783779
#           0.0          64         fasttext  harem-transformer-ft  0.787448
#                                   glove     harem-transformer-pt  0.790897
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.790246
#                                             harem                 0.791032
#           0.0          64         word2vec  harem-transformer-pt  0.791777
#           0.5          64         word2vec  harem-ft              0.795424
#           0.0          32         wang2vec  harem-transformer-pt  0.776818
#                        64         wang2vec  harem-transformer-pt  0.790136
#           0.5          32         fasttext  harem-ft              0.789323
#                                             harem                 0.786451
#                        64         glove     harem-transformer-ft  0.791984
#           0.0          64         fasttext  harem-transformer-pt  0.778767
#           0.5          64         word2vec  harem                 0.790275
#                        32         word2vec  harem-ft              0.788630
#                                             harem                 0.775250
#                                   glove     harem-transformer-ft  0.786731
#                        64         wang2vec  harem-transformer-ft  0.778550
#                        32         wang2vec  harem-transformer-ft  0.782551
#           0.0          32         fasttext  harem-transformer-pt  0.779144
#                                   word2vec  harem-transformer-pt  0.779511
#           0.5          64         glove     harem-transformer-pt  0.788190
#                        32         glove     harem-transformer-pt  0.783156
#                        64         fasttext  harem-transformer-ft  0.777016
#                                   word2vec  harem-transformer-ft  0.781932
#                                   wang2vec  harem-transformer-pt  0.770702
#                        32         fasttext  harem-transformer-ft  0.774979
#                                   wang2vec  harem-transformer-pt  0.773342
#                        64         fasttext  harem-transformer-pt  0.777647
#                                   word2vec  harem-transformer-pt  0.772601
#                        32         word2vec  harem-transformer-ft  0.767568
#                                   fasttext  harem-transformer-pt  0.771289
#                                   word2vec  harem-transformer-pt  0.769282
#
#                                                                        25%  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.812653
#                                   glove     harem-ft              0.810684
#                        64         glove     harem-ft              0.811848
#                                             harem                 0.806908
#                        32         fasttext  harem                 0.810563
#                                   word2vec  harem-ft              0.808514
#                        64         wang2vec  harem-ft              0.809591
#                        32         wang2vec  harem                 0.807191
#                        64         wang2vec  harem                 0.808926
#                                   word2vec  harem-ft              0.806509
#                                   glove     harem-transformer-ft  0.805818
#                        32         glove     harem                 0.809272
#                        64         fasttext  harem-ft              0.806849
#                                             harem                 0.805531
#                        32         glove     harem-transformer-ft  0.807884
#                        64         wang2vec  harem-transformer-ft  0.805477
#                                   word2vec  harem                 0.806958
#                        32         word2vec  harem                 0.805468
#                                   fasttext  harem-ft              0.802471
#                                   wang2vec  harem-transformer-ft  0.804511
#           0.5          32         wang2vec  harem-ft              0.801571
#                                   glove     harem-ft              0.803328
#           0.0          32         fasttext  harem-transformer-ft  0.803896
#           0.5          64         wang2vec  harem                 0.805983
#                                   glove     harem-ft              0.803411
#           0.0          64         word2vec  harem-transformer-ft  0.803632
#           0.5          64         wang2vec  harem-ft              0.800646
#                        32         wang2vec  harem                 0.801474
#           0.0          64         fasttext  harem-transformer-ft  0.800786
#                                   glove     harem-transformer-pt  0.797360
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.798171
#                                             harem                 0.798734
#           0.0          64         word2vec  harem-transformer-pt  0.795544
#           0.5          64         word2vec  harem-ft              0.796616
#           0.0          32         wang2vec  harem-transformer-pt  0.798719
#                        64         wang2vec  harem-transformer-pt  0.796641
#           0.5          32         fasttext  harem-ft              0.798556
#                                             harem                 0.792995
#                        64         glove     harem-transformer-ft  0.794171
#           0.0          64         fasttext  harem-transformer-pt  0.799259
#           0.5          64         word2vec  harem                 0.793958
#                        32         word2vec  harem-ft              0.792137
#                                             harem                 0.793292
#                                   glove     harem-transformer-ft  0.791885
#                        64         wang2vec  harem-transformer-ft  0.790607
#                        32         wang2vec  harem-transformer-ft  0.787957
#           0.0          32         fasttext  harem-transformer-pt  0.792434
#                                   word2vec  harem-transformer-pt  0.784638
#           0.5          64         glove     harem-transformer-pt  0.790431
#                        32         glove     harem-transformer-pt  0.785467
#                        64         fasttext  harem-transformer-ft  0.783372
#                                   word2vec  harem-transformer-ft  0.785004
#                                   wang2vec  harem-transformer-pt  0.785104
#                        32         fasttext  harem-transformer-ft  0.783477
#                                   wang2vec  harem-transformer-pt  0.780346
#                        64         fasttext  harem-transformer-pt  0.782669
#                                   word2vec  harem-transformer-pt  0.779641
#                        32         word2vec  harem-transformer-ft  0.771352
#                                   fasttext  harem-transformer-pt  0.777904
#                                   word2vec  harem-transformer-pt  0.774403
#
#                                                                        50%  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.815641
#                                   glove     harem-ft              0.813275
#                        64         glove     harem-ft              0.815972
#                                             harem                 0.813770
#                        32         fasttext  harem                 0.813591
#                                   word2vec  harem-ft              0.813120
#                        64         wang2vec  harem-ft              0.813319
#                        32         wang2vec  harem                 0.812256
#                        64         wang2vec  harem                 0.811796
#                                   word2vec  harem-ft              0.811533
#                                   glove     harem-transformer-ft  0.808936
#                        32         glove     harem                 0.810132
#                        64         fasttext  harem-ft              0.810323
#                                             harem                 0.809067
#                        32         glove     harem-transformer-ft  0.809082
#                        64         wang2vec  harem-transformer-ft  0.810753
#                                   word2vec  harem                 0.810138
#                        32         word2vec  harem                 0.808119
#                                   fasttext  harem-ft              0.810005
#                                   wang2vec  harem-transformer-ft  0.807955
#           0.5          32         wang2vec  harem-ft              0.810035
#                                   glove     harem-ft              0.807132
#           0.0          32         fasttext  harem-transformer-ft  0.806377
#           0.5          64         wang2vec  harem                 0.807238
#                                   glove     harem-ft              0.807947
#           0.0          64         word2vec  harem-transformer-ft  0.805468
#           0.5          64         wang2vec  harem-ft              0.803214
#                        32         wang2vec  harem                 0.806065
#           0.0          64         fasttext  harem-transformer-ft  0.804248
#                                   glove     harem-transformer-pt  0.802929
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.802990
#                                             harem                 0.800636
#           0.0          64         word2vec  harem-transformer-pt  0.801832
#           0.5          64         word2vec  harem-ft              0.799958
#           0.0          32         wang2vec  harem-transformer-pt  0.801339
#                        64         wang2vec  harem-transformer-pt  0.799522
#           0.5          32         fasttext  harem-ft              0.799464
#                                             harem                 0.799470
#                        64         glove     harem-transformer-ft  0.798002
#           0.0          64         fasttext  harem-transformer-pt  0.800679
#           0.5          64         word2vec  harem                 0.797184
#                        32         word2vec  harem-ft              0.797118
#                                             harem                 0.798969
#                                   glove     harem-transformer-ft  0.796826
#                        64         wang2vec  harem-transformer-ft  0.798132
#                        32         wang2vec  harem-transformer-ft  0.794651
#           0.0          32         fasttext  harem-transformer-pt  0.793542
#                                   word2vec  harem-transformer-pt  0.795577
#           0.5          64         glove     harem-transformer-pt  0.793363
#                        32         glove     harem-transformer-pt  0.790039
#                        64         fasttext  harem-transformer-ft  0.791099
#                                   word2vec  harem-transformer-ft  0.790195
#                                   wang2vec  harem-transformer-pt  0.788061
#                        32         fasttext  harem-transformer-ft  0.788070
#                                   wang2vec  harem-transformer-pt  0.788922
#                        64         fasttext  harem-transformer-pt  0.784994
#                                   word2vec  harem-transformer-pt  0.782728
#                        32         word2vec  harem-transformer-ft  0.782241
#                                   fasttext  harem-transformer-pt  0.780493
#                                   word2vec  harem-transformer-pt  0.780797
#
#                                                                        75%  \
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.818435
#                                   glove     harem-ft              0.816884
#                        64         glove     harem-ft              0.816728
#                                             harem                 0.817014
#                        32         fasttext  harem                 0.815999
#                                   word2vec  harem-ft              0.815776
#                        64         wang2vec  harem-ft              0.814391
#                        32         wang2vec  harem                 0.815893
#                        64         wang2vec  harem                 0.814122
#                                   word2vec  harem-ft              0.814846
#                                   glove     harem-transformer-ft  0.814084
#                        32         glove     harem                 0.812180
#                        64         fasttext  harem-ft              0.812256
#                                             harem                 0.814160
#                        32         glove     harem-transformer-ft  0.813592
#                        64         wang2vec  harem-transformer-ft  0.813673
#                                   word2vec  harem                 0.810781
#                        32         word2vec  harem                 0.812276
#                                   fasttext  harem-ft              0.813902
#                                   wang2vec  harem-transformer-ft  0.809401
#           0.5          32         wang2vec  harem-ft              0.811203
#                                   glove     harem-ft              0.809134
#           0.0          32         fasttext  harem-transformer-ft  0.809749
#           0.5          64         wang2vec  harem                 0.809878
#                                   glove     harem-ft              0.809662
#           0.0          64         word2vec  harem-transformer-ft  0.808295
#           0.5          64         wang2vec  harem-ft              0.808388
#                        32         wang2vec  harem                 0.809894
#           0.0          64         fasttext  harem-transformer-ft  0.808870
#                                   glove     harem-transformer-pt  0.808335
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.805495
#                                             harem                 0.804344
#           0.0          64         word2vec  harem-transformer-pt  0.805648
#           0.5          64         word2vec  harem-ft              0.804055
#           0.0          32         wang2vec  harem-transformer-pt  0.806370
#                        64         wang2vec  harem-transformer-pt  0.805968
#           0.5          32         fasttext  harem-ft              0.802352
#                                             harem                 0.806340
#                        64         glove     harem-transformer-ft  0.803765
#           0.0          64         fasttext  harem-transformer-pt  0.803005
#           0.5          64         word2vec  harem                 0.801083
#                        32         word2vec  harem-ft              0.799906
#                                             harem                 0.801956
#                                   glove     harem-transformer-ft  0.798153
#                        64         wang2vec  harem-transformer-ft  0.801554
#                        32         wang2vec  harem-transformer-ft  0.799272
#           0.0          32         fasttext  harem-transformer-pt  0.797628
#                                   word2vec  harem-transformer-pt  0.803074
#           0.5          64         glove     harem-transformer-pt  0.795306
#                        32         glove     harem-transformer-pt  0.793741
#                        64         fasttext  harem-transformer-ft  0.794868
#                                   word2vec  harem-transformer-ft  0.791233
#                                   wang2vec  harem-transformer-pt  0.790849
#                        32         fasttext  harem-transformer-ft  0.791212
#                                   wang2vec  harem-transformer-pt  0.791782
#                        64         fasttext  harem-transformer-pt  0.787260
#                                   word2vec  harem-transformer-pt  0.784765
#                        32         word2vec  harem-transformer-ft  0.787781
#                                   fasttext  harem-transformer-pt  0.783549
#                                   word2vec  harem-transformer-pt  0.784114
#
#                                                                        max
# Scenario  ELMo_Dropout Batch_Size Embedding Model
# selective 0.0          32         wang2vec  harem-ft              0.822973
#                                   glove     harem-ft              0.821729
#                        64         glove     harem-ft              0.824247
#                                             harem                 0.823872
#                        32         fasttext  harem                 0.822548
#                                   word2vec  harem-ft              0.820047
#                        64         wang2vec  harem-ft              0.818674
#                        32         wang2vec  harem                 0.817017
#                        64         wang2vec  harem                 0.814941
#                                   word2vec  harem-ft              0.819051
#                                   glove     harem-transformer-ft  0.818385
#                        32         glove     harem                 0.813786
#                        64         fasttext  harem-ft              0.816497
#                                             harem                 0.818104
#                        32         glove     harem-transformer-ft  0.817423
#                        64         wang2vec  harem-transformer-ft  0.822218
#                                   word2vec  harem                 0.815892
#                        32         word2vec  harem                 0.815785
#                                   fasttext  harem-ft              0.817352
#                                   wang2vec  harem-transformer-ft  0.814005
#           0.5          32         wang2vec  harem-ft              0.817193
#                                   glove     harem-ft              0.816049
#           0.0          32         fasttext  harem-transformer-ft  0.813387
#           0.5          64         wang2vec  harem                 0.812712
#                                   glove     harem-ft              0.818767
#           0.0          64         word2vec  harem-transformer-ft  0.821343
#           0.5          64         wang2vec  harem-ft              0.815772
#                        32         wang2vec  harem                 0.814753
#           0.0          64         fasttext  harem-transformer-ft  0.816791
#                                   glove     harem-transformer-pt  0.812543
# ...                                                                    ...
#           0.5          64         fasttext  harem-ft              0.808704
#                                             harem                 0.813891
#           0.0          64         word2vec  harem-transformer-pt  0.809845
#           0.5          64         word2vec  harem-ft              0.807744
#           0.0          32         wang2vec  harem-transformer-pt  0.810674
#                        64         wang2vec  harem-transformer-pt  0.808741
#           0.5          32         fasttext  harem-ft              0.808747
#                                             harem                 0.809766
#                        64         glove     harem-transformer-ft  0.805724
#           0.0          64         fasttext  harem-transformer-pt  0.803811
#           0.5          64         word2vec  harem                 0.808043
#                        32         word2vec  harem-ft              0.809145
#                                             harem                 0.803061
#                                   glove     harem-transformer-ft  0.806874
#                        64         wang2vec  harem-transformer-ft  0.804186
#                        32         wang2vec  harem-transformer-ft  0.808145
#           0.0          32         fasttext  harem-transformer-pt  0.804841
#                                   word2vec  harem-transformer-pt  0.806343
#           0.5          64         glove     harem-transformer-pt  0.796451
#                        32         glove     harem-transformer-pt  0.797423
#                        64         fasttext  harem-transformer-ft  0.799056
#                                   word2vec  harem-transformer-ft  0.793774
#                                   wang2vec  harem-transformer-pt  0.801222
#                        32         fasttext  harem-transformer-ft  0.793224
#                                   wang2vec  harem-transformer-pt  0.794544
#                        64         fasttext  harem-transformer-pt  0.792981
#                                   word2vec  harem-transformer-pt  0.788309
#                        32         word2vec  harem-transformer-ft  0.800338
#                                   fasttext  harem-transformer-pt  0.785762
#                                   word2vec  harem-transformer-pt  0.788196
#
# [64 rows x 8 columns]

# %%
training_data_df.groupby([MODEL]).describe()[TEST_F1_MEASURE]
# Out:
#                       count      mean       std       min       25%       50%  \
# Model
# harem                 160.0  0.805956  0.008103  0.775250  0.801101  0.806794
# harem-ft              160.0  0.807557  0.007843  0.788259  0.802213  0.808521
# harem-transformer-ft  160.0  0.798982  0.011186  0.767568  0.791561  0.800136
# harem-transformer-pt  160.0  0.792301  0.010384  0.769282  0.784656  0.792632
#
#                            75%       max
# Model
# harem                 0.811607  0.823872
# harem-ft              0.813522  0.824247
# harem-transformer-ft  0.807629  0.822218
# harem-transformer-pt  0.800405  0.815554

# %%
training_data_df[BEST_EPOCH].hist()

# %%
training_data_df[TOTAL_DURATION].describe()
# Out:
# count     640.000000
# mean     1858.160938
# std       502.743258
# min      1289.000000
# 25%      1513.750000
# 50%      1863.500000
# 75%      2361.250000
# max      2921.000000
# Name: Total_Duration(s), dtype: float64

# %%
training_data_df.groupby([TRAINING_NUMBER]).describe()[TEST_F1_MEASURE].sort_values(by='mean', ascending=False)
# Out:
#                  count      mean       std       min       25%       50%  \
# Training_Number
# 3                 64.0  0.805276  0.011910  0.774334  0.800033  0.806911
# 5                 64.0  0.803142  0.009385  0.783505  0.797817  0.805100
# 2                 64.0  0.803097  0.011560  0.767589  0.793476  0.805369
# 7                 64.0  0.803076  0.011714  0.769282  0.797352  0.805736
# 1                 64.0  0.800789  0.012134  0.767568  0.795952  0.804692
# 9                 64.0  0.800182  0.011442  0.771289  0.793414  0.802554
# 4                 64.0  0.799963  0.010740  0.770358  0.793222  0.800703
# 6                 64.0  0.799659  0.009716  0.777647  0.793682  0.800364
# 0                 64.0  0.798603  0.011231  0.772601  0.791605  0.799086
# 8                 64.0  0.798205  0.010895  0.770837  0.788296  0.798540
#
#                       75%       max
# Training_Number
# 3                0.813944  0.824247
# 5                0.808702  0.822952
# 2                0.811859  0.822145
# 7                0.811843  0.822973
# 1                0.809101  0.819461
# 9                0.808022  0.819051
# 4                0.808104  0.816562
# 6                0.806539  0.817400
# 0                0.807827  0.818658
# 8                0.806573  0.817844

# %%
rp.summary_cont(training_data_df[TEST_F1_MEASURE])
# Out:
#           Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  Test_F1_Measure  640.0  0.801199  0.011245  0.000445   0.800326  0.802072

# %%
rp.summary_cont(training_data_df.groupby(MODEL))[TEST_F1_MEASURE]
# Out:
#                         N      Mean        SD        SE  95% Conf.  Interval
# Model
# harem                 160  0.805956  0.008103  0.000641   0.804701  0.807212
# harem-ft              160  0.807557  0.007843  0.000620   0.806342  0.808772
# harem-transformer-ft  160  0.798982  0.011186  0.000884   0.797249  0.800715
# harem-transformer-pt  160  0.792301  0.010384  0.000821   0.790692  0.793910

# %%
rp.summary_cont(training_data_df.groupby(EMBEDDING))[TEST_F1_MEASURE]
# Out:
#              N      Mean        SD        SE  95% Conf.  Interval
# Embedding
# fasttext   160  0.799225  0.011209  0.000886   0.797488  0.800961
# glove      160  0.804439  0.009257  0.000732   0.803004  0.805873
# wang2vec   160  0.803304  0.010775  0.000852   0.801635  0.804974
# word2vec   160  0.797829  0.012264  0.000970   0.795928  0.799729

# %%
rp.summary_cont(training_data_df.groupby(BATCH_SIZE))[TEST_F1_MEASURE]
# Out:
#               N      Mean        SD        SE  95% Conf.  Interval
# Batch_Size
# 32          320  0.800503  0.011972  0.000669   0.799191  0.801815
# 64          320  0.801895  0.010440  0.000584   0.800751  0.803039

# %%
rp.summary_cont(training_data_df.groupby(ELMO_DROPOUT))[TEST_F1_MEASURE]
# Out:
#                 N      Mean        SD        SE  95% Conf.  Interval
# ELMo_Dropout
# 0.0           320  0.807192  0.008257  0.000462   0.806287  0.808097
# 0.5           320  0.795206  0.010634  0.000594   0.794041  0.796371

# %%
rp.summary_cont(training_data_df.groupby([MODEL,EMBEDDING]))[TEST_F1_MEASURE]
# Out:
#                                  N      Mean        SD        SE  95% Conf.  \
# Model                Embedding
# harem                fasttext   40  0.805614  0.008643  0.001367   0.802935
#                      glove      40  0.807065  0.007813  0.001235   0.804644
#                      wang2vec   40  0.808181  0.006608  0.001045   0.806133
#                      word2vec   40  0.802964  0.008520  0.001347   0.800324
# harem-ft             fasttext   40  0.805103  0.006950  0.001099   0.802949
#                      glove      40  0.810146  0.007260  0.001148   0.807896
#                      wang2vec   40  0.809809  0.007187  0.001136   0.807582
#                      word2vec   40  0.805171  0.008605  0.001361   0.802504
# harem-transformer-ft fasttext   40  0.796557  0.011036  0.001745   0.793137
#                      glove      40  0.803542  0.008384  0.001326   0.800944
#                      wang2vec   40  0.801613  0.010034  0.001586   0.798504
#                      word2vec   40  0.794216  0.012635  0.001998   0.790300
# harem-transformer-pt fasttext   40  0.789625  0.009398  0.001486   0.786712
#                      glove      40  0.797002  0.008204  0.001297   0.794459
#                      wang2vec   40  0.793613  0.010501  0.001660   0.790359
#                      word2vec   40  0.788964  0.011426  0.001807   0.785423
#
#                                 Interval
# Model                Embedding
# harem                fasttext   0.808292
#                      glove      0.809486
#                      wang2vec   0.810229
#                      word2vec   0.805605
# harem-ft             fasttext   0.807257
#                      glove      0.812396
#                      wang2vec   0.812036
#                      word2vec   0.807837
# harem-transformer-ft fasttext   0.799977
#                      glove      0.806141
#                      wang2vec   0.804723
#                      word2vec   0.798132
# harem-transformer-pt fasttext   0.792537
#                      glove      0.799544
#                      wang2vec   0.796868
#                      word2vec   0.792505

# %%
print(TEST_F1_MEASURE, MODEL, EMBEDDING, BATCH_SIZE, ELMO_DROPOUT)
# Out:
# Test_F1_Measure Model Embedding Batch_Size ELMo_Dropout

# %%
# Fits the model with the interaction term
# This will also automatically include the main effects for each factor
model = ols('Test_F1_Measure ~ C(Model)*C(Embedding)*C(Batch_Size)*C(ELMo_Dropout)', training_data_df).fit()

# Seeing if the overall model is significant
print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 63, 576) =  20.053, p =  0.0000

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Test_F1_Measure   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     20.05
# Date:                Mon, 08 Apr 2019   Prob (F-statistic):          2.32e-108
# Time:                        19:49:06   Log-Likelihood:                 2336.1
# No. Observations:                 640   AIC:                            -4544.
# Df Residuals:                     576   BIC:                            -4259.
# Df Model:                          63
# Covariance Type:            nonrobust
# ========================================================================================================================================================================
#                                                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                0.8126      0.002    387.690      0.000       0.808       0.817
# C(Model)[T.harem-ft]                                                                                    -0.0042      0.003     -1.432      0.153      -0.010       0.002
# C(Model)[T.harem-transformer-ft]                                                                        -0.0061      0.003     -2.047      0.041      -0.012      -0.000
# C(Model)[T.harem-transformer-pt]                                                                        -0.0183      0.003     -6.173      0.000      -0.024      -0.012
# C(Embedding)[T.glove]                                                                                   -0.0024      0.003     -0.796      0.426      -0.008       0.003
# C(Embedding)[T.wang2vec]                                                                                -0.0011      0.003     -0.364      0.716      -0.007       0.005
# C(Embedding)[T.word2vec]                                                                                -0.0037      0.003     -1.265      0.206      -0.010       0.002
# C(Batch_Size)[T.64]                                                                                     -0.0029      0.003     -0.986      0.324      -0.009       0.003
# C(ELMo_Dropout)[T.0.5]                                                                                  -0.0136      0.003     -4.601      0.000      -0.019      -0.008
# C(Model)[T.harem-ft]:C(Embedding)[T.glove]                                                               0.0082      0.004      1.965      0.050    5.36e-06       0.016
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.glove]                                                   0.0053      0.004      1.259      0.209      -0.003       0.014
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.glove]                                                   0.0105      0.004      2.513      0.012       0.002       0.019
# C(Model)[T.harem-ft]:C(Embedding)[T.wang2vec]                                                            0.0077      0.004      1.848      0.065      -0.000       0.016
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.wang2vec]                                                0.0020      0.004      0.467      0.640      -0.006       0.010
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.wang2vec]                                                0.0074      0.004      1.761      0.079      -0.001       0.016
# C(Model)[T.harem-ft]:C(Embedding)[T.word2vec]                                                            0.0079      0.004      1.876      0.061      -0.000       0.016
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.word2vec]                                               -0.0006      0.004     -0.141      0.888      -0.009       0.008
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.word2vec]                                                0.0033      0.004      0.796      0.426      -0.005       0.012
# C(Model)[T.harem-ft]:C(Batch_Size)[T.64]                                                                 0.0047      0.004      1.125      0.261      -0.004       0.013
# C(Model)[T.harem-transformer-ft]:C(Batch_Size)[T.64]                                                     0.0004      0.004      0.097      0.923      -0.008       0.009
# C(Model)[T.harem-transformer-pt]:C(Batch_Size)[T.64]                                                     0.0073      0.004      1.737      0.083      -0.001       0.016
# C(Embedding)[T.glove]:C(Batch_Size)[T.64]                                                                0.0055      0.004      1.302      0.194      -0.003       0.014
# C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]                                                             0.0020      0.004      0.470      0.638      -0.006       0.010
# C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]                                                             0.0033      0.004      0.792      0.429      -0.005       0.012
# C(Model)[T.harem-ft]:C(ELMo_Dropout)[T.0.5]                                                              0.0055      0.004      1.303      0.193      -0.003       0.014
# C(Model)[T.harem-transformer-ft]:C(ELMo_Dropout)[T.0.5]                                                 -0.0065      0.004     -1.551      0.121      -0.015       0.002
# C(Model)[T.harem-transformer-pt]:C(ELMo_Dropout)[T.0.5]                                                 -0.0005      0.004     -0.120      0.905      -0.009       0.008
# C(Embedding)[T.glove]:C(ELMo_Dropout)[T.0.5]                                                             0.0061      0.004      1.449      0.148      -0.002       0.014
# C(Embedding)[T.wang2vec]:C(ELMo_Dropout)[T.0.5]                                                          0.0065      0.004      1.540      0.124      -0.002       0.015
# C(Embedding)[T.word2vec]:C(ELMo_Dropout)[T.0.5]                                                          0.0006      0.004      0.136      0.892      -0.008       0.009
# C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                                                               0.0052      0.004      1.248      0.212      -0.003       0.013
# C(Model)[T.harem-ft]:C(Embedding)[T.glove]:C(Batch_Size)[T.64]                                          -0.0080      0.006     -1.349      0.178      -0.020       0.004
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.glove]:C(Batch_Size)[T.64]                              -0.0020      0.006     -0.342      0.732      -0.014       0.010
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.glove]:C(Batch_Size)[T.64]                              -0.0094      0.006     -1.588      0.113      -0.021       0.002
# C(Model)[T.harem-ft]:C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]                                       -0.0064      0.006     -1.074      0.283      -0.018       0.005
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]                            0.0026      0.006      0.430      0.667      -0.009       0.014
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]                           -0.0065      0.006     -1.101      0.271      -0.018       0.005
# C(Model)[T.harem-ft]:C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]                                       -0.0071      0.006     -1.198      0.231      -0.019       0.005
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]                            0.0019      0.006      0.319      0.750      -0.010       0.014
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]                           -0.0006      0.006     -0.097      0.923      -0.012       0.011
# C(Model)[T.harem-ft]:C(Embedding)[T.glove]:C(ELMo_Dropout)[T.0.5]                                       -0.0049      0.006     -0.834      0.404      -0.017       0.007
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.glove]:C(ELMo_Dropout)[T.0.5]                            0.0002      0.006      0.037      0.971      -0.011       0.012
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.glove]:C(ELMo_Dropout)[T.0.5]                           -0.0046      0.006     -0.775      0.439      -0.016       0.007
# C(Model)[T.harem-ft]:C(Embedding)[T.wang2vec]:C(ELMo_Dropout)[T.0.5]                                    -0.0060      0.006     -1.006      0.315      -0.018       0.006
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.wang2vec]:C(ELMo_Dropout)[T.0.5]                         0.0006      0.006      0.100      0.921      -0.011       0.012
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.wang2vec]:C(ELMo_Dropout)[T.0.5]                        -0.0071      0.006     -1.193      0.233      -0.019       0.005
# C(Model)[T.harem-ft]:C(Embedding)[T.word2vec]:C(ELMo_Dropout)[T.0.5]                                    -0.0078      0.006     -1.318      0.188      -0.019       0.004
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.word2vec]:C(ELMo_Dropout)[T.0.5]                        -0.0013      0.006     -0.216      0.829      -0.013       0.010
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.word2vec]:C(ELMo_Dropout)[T.0.5]                        -0.0009      0.006     -0.157      0.875      -0.013       0.011
# C(Model)[T.harem-ft]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                                         -0.0054      0.006     -0.916      0.360      -0.017       0.006
# C(Model)[T.harem-transformer-ft]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                              0.0002      0.006      0.040      0.968      -0.011       0.012
# C(Model)[T.harem-transformer-pt]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                             -0.0043      0.006     -0.730      0.465      -0.016       0.007
# C(Embedding)[T.glove]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                                        -0.0078      0.006     -1.318      0.188      -0.019       0.004
# C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                                     -0.0023      0.006     -0.382      0.703      -0.014       0.009
# C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                                     -0.0034      0.006     -0.570      0.569      -0.015       0.008
# C(Model)[T.harem-ft]:C(Embedding)[T.glove]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                    0.0073      0.008      0.871      0.384      -0.009       0.024
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.glove]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]        0.0047      0.008      0.556      0.579      -0.012       0.021
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.glove]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]        0.0096      0.008      1.144      0.253      -0.007       0.026
# C(Model)[T.harem-ft]:C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                 0.0022      0.008      0.265      0.791      -0.014       0.019
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]    -0.0042      0.008     -0.497      0.620      -0.021       0.012
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.wang2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]     0.0033      0.008      0.399      0.690      -0.013       0.020
# C(Model)[T.harem-ft]:C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]                 0.0092      0.008      1.103      0.271      -0.007       0.026
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]     0.0024      0.008      0.283      0.777      -0.014       0.019
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.word2vec]:C(Batch_Size)[T.64]:C(ELMo_Dropout)[T.0.5]    -0.0024      0.008     -0.284      0.776      -0.019       0.014
# ==============================================================================
# Omnibus:                       24.602   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.069
# Skew:                          -0.448   Prob(JB):                     1.32e-06
# Kurtosis:                       3.459   Cond. No.                         157.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res = sm.stats.anova_lm(model, typ= 2)

# %%
res
# Out:
#                                                       sum_sq     df  \
# C(Model)                                            0.023543    3.0
# C(Embedding)                                        0.004830    3.0
# C(Batch_Size)                                       0.000310    1.0
# C(ELMo_Dropout)                                     0.022986    1.0
# C(Model):C(Embedding)                               0.000657    9.0
# C(Model):C(Batch_Size)                              0.000266    3.0
# C(Embedding):C(Batch_Size)                          0.000178    3.0
# C(Model):C(ELMo_Dropout)                            0.001280    3.0
# C(Embedding):C(ELMo_Dropout)                        0.000668    3.0
# C(Batch_Size):C(ELMo_Dropout)                       0.000090    1.0
# C(Model):C(Embedding):C(Batch_Size)                 0.000200    9.0
# C(Model):C(Embedding):C(ELMo_Dropout)               0.000155    9.0
# C(Model):C(Batch_Size):C(ELMo_Dropout)              0.000038    3.0
# C(Embedding):C(Batch_Size):C(ELMo_Dropout)          0.000034    3.0
# C(Model):C(Embedding):C(Batch_Size):C(ELMo_Drop...  0.000265    9.0
# Residual                                            0.025304  576.0
#
#                                                              F        PR(>F)
# C(Model)                                            178.638007  7.214416e-82
# C(Embedding)                                         36.645293  1.099133e-21
# C(Batch_Size)                                         7.063039  8.087476e-03
# C(ELMo_Dropout)                                     523.235743  7.070118e-83
# C(Model):C(Embedding)                                 1.662613  9.480037e-02
# C(Model):C(Batch_Size)                                2.015914  1.105724e-01
# C(Embedding):C(Batch_Size)                            1.350072  2.572259e-01
# C(Model):C(ELMo_Dropout)                              9.714549  2.915060e-06
# C(Embedding):C(ELMo_Dropout)                          5.072042  1.789831e-03
# C(Batch_Size):C(ELMo_Dropout)                         2.052183  1.525306e-01
# C(Model):C(Embedding):C(Batch_Size)                   0.506789  8.700145e-01
# C(Model):C(Embedding):C(ELMo_Dropout)                 0.391257  9.394427e-01
# C(Model):C(Batch_Size):C(ELMo_Dropout)                0.285412  8.359482e-01
# C(Embedding):C(Batch_Size):C(ELMo_Dropout)            0.255342  8.575375e-01
# C(Model):C(Embedding):C(Batch_Size):C(ELMo_Drop...    0.671193  7.353357e-01
# Residual                                                   NaN           NaN

# %%
# Fits the model with the interaction term
# This will also automatically include the main effects for each factor
model = ols('Test_F1_Measure ~ C(Model)*C(Embedding)', training_data_df).fit()

# Seeing if the overall model is significant
print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 15, 624) =  23.325, p =  0.0000

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Test_F1_Measure   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     23.33
# Date:                Mon, 08 Apr 2019   Prob (F-statistic):           6.09e-51
# Time:                        19:49:07   Log-Likelihood:                 2107.0
# No. Observations:                 640   AIC:                            -4182.
# Df Residuals:                     624   BIC:                            -4111.
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     0.8056      0.001    559.357      0.000       0.803       0.808
# C(Model)[T.harem-ft]                                         -0.0005      0.002     -0.251      0.802      -0.005       0.003
# C(Model)[T.harem-transformer-ft]                             -0.0091      0.002     -4.447      0.000      -0.013      -0.005
# C(Model)[T.harem-transformer-pt]                             -0.0160      0.002     -7.850      0.000      -0.020      -0.012
# C(Embedding)[T.glove]                                         0.0015      0.002      0.713      0.476      -0.003       0.005
# C(Embedding)[T.wang2vec]                                      0.0026      0.002      1.260      0.208      -0.001       0.007
# C(Embedding)[T.word2vec]                                     -0.0026      0.002     -1.301      0.194      -0.007       0.001
# C(Model)[T.harem-ft]:C(Embedding)[T.glove]                    0.0036      0.003      1.247      0.213      -0.002       0.009
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.glove]        0.0055      0.003      1.921      0.055      -0.000       0.011
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.glove]        0.0059      0.003      2.057      0.040       0.000       0.012
# C(Model)[T.harem-ft]:C(Embedding)[T.wang2vec]                 0.0021      0.003      0.742      0.458      -0.004       0.008
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.wang2vec]     0.0025      0.003      0.864      0.388      -0.003       0.008
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.wang2vec]     0.0014      0.003      0.493      0.622      -0.004       0.007
# C(Model)[T.harem-ft]:C(Embedding)[T.word2vec]                 0.0027      0.003      0.943      0.346      -0.003       0.008
# C(Model)[T.harem-transformer-ft]:C(Embedding)[T.word2vec]     0.0003      0.003      0.107      0.915      -0.005       0.006
# C(Model)[T.harem-transformer-pt]:C(Embedding)[T.word2vec]     0.0020      0.003      0.691      0.490      -0.004       0.008
# ==============================================================================
# Omnibus:                        5.889   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                5.948
# Skew:                          -0.235   Prob(JB):                       0.0511
# Kurtosis:                       2.958   Cond. No.                         23.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sm.stats.anova_lm(model, typ= 2)
# Out:
#                          sum_sq     df          F        PR(>F)
# C(Model)               0.023543    3.0  94.582095  1.826957e-50
# C(Embedding)           0.004830    3.0  19.402302  4.882065e-12
# C(Model):C(Embedding)  0.000657    9.0   0.880291  5.425530e-01
# Residual               0.051775  624.0        NaN           NaN

# %%
# Fits the model with the interaction term
# This will also automatically include the main effects for each factor
model = ols('Test_F1_Measure ~ C(Model)+C(Embedding)', training_data_df).fit()

# Seeing if the overall model is significant
print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 6, 633) =  57.089, p =  0.0000

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Test_F1_Measure   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     57.09
# Date:                Mon, 08 Apr 2019   Prob (F-statistic):           2.23e-56
# Time:                        19:49:07   Log-Likelihood:                 2103.0
# No. Observations:                 640   AIC:                            -4192.
# Df Residuals:                     633   BIC:                            -4161.
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.8040      0.001    844.675      0.000       0.802       0.806
# C(Model)[T.harem-ft]                 0.0016      0.001      1.573      0.116      -0.000       0.004
# C(Model)[T.harem-transformer-ft]    -0.0070      0.001     -6.854      0.000      -0.009      -0.005
# C(Model)[T.harem-transformer-pt]    -0.0137      0.001    -13.420      0.000      -0.016      -0.012
# C(Embedding)[T.glove]                0.0052      0.001      5.124      0.000       0.003       0.007
# C(Embedding)[T.wang2vec]             0.0041      0.001      4.009      0.000       0.002       0.006
# C(Embedding)[T.word2vec]            -0.0014      0.001     -1.372      0.171      -0.003       0.001
# ==============================================================================
# Omnibus:                        7.365   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                7.401
# Skew:                          -0.263   Prob(JB):                       0.0247
# Kurtosis:                       3.010   Cond. No.                         5.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res = sm.stats.anova_lm(model, typ=2)
res
# Out:
#                 sum_sq     df          F        PR(>F)
# C(Model)      0.023543    3.0  94.743351  1.175349e-50
# C(Embedding)  0.004830    3.0  19.435382  4.592073e-12
# Residual      0.052432  633.0        NaN           NaN

# %%
# Calculating effect size
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'mean_sq', 'df', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

anova_table(res)
# Out:
#                 sum_sq   mean_sq     df          F        PR(>F)    eta_sq  \
# C(Model)      0.023543  0.007848    3.0  94.743351  1.175349e-50  0.291358
# C(Embedding)  0.004830  0.001610    3.0  19.435382  4.592073e-12  0.059768
# Residual      0.052432  0.000083  633.0        NaN           NaN       NaN
#
#               omega_sq
# C(Model)      0.287987
# C(Embedding)  0.056635
# Residual           NaN

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[TEST_F1_MEASURE], training_data_df[MODEL])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
#             Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =========================================================================
#        group1               group2        meandiff  lower   upper  reject
# -------------------------------------------------------------------------
#        harem               harem-ft        0.0016  -0.0011  0.0043 False
#        harem         harem-transformer-ft  -0.007  -0.0097 -0.0042  True
#        harem         harem-transformer-pt -0.0137  -0.0164 -0.0109  True
#       harem-ft       harem-transformer-ft -0.0086  -0.0113 -0.0058  True
#       harem-ft       harem-transformer-pt -0.0153   -0.018 -0.0125  True
# harem-transformer-ft harem-transformer-pt -0.0067  -0.0094 -0.0039  True
# -------------------------------------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[TEST_F1_MEASURE], training_data_df[EMBEDDING])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =================================================
#  group1   group2  meandiff  lower   upper  reject
# -------------------------------------------------
# fasttext  glove    0.0052   0.0021  0.0084  True
# fasttext wang2vec  0.0041   0.0009  0.0072  True
# fasttext word2vec -0.0014  -0.0045  0.0018 False
#  glove   wang2vec -0.0011  -0.0043  0.002  False
#  glove   word2vec -0.0066  -0.0098 -0.0035  True
# wang2vec word2vec -0.0055  -0.0086 -0.0023  True
# -------------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[TEST_F1_MEASURE], training_data_df[ELMO_DROPOUT])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =============================================
# group1 group2 meandiff  lower   upper  reject
# ---------------------------------------------
#  0.0    0.5    -0.012  -0.0135 -0.0105  True
# ---------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[TEST_F1_MEASURE], training_data_df[BATCH_SIZE])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   32     64    0.0014  -0.0004 0.0031 False
# --------------------------------------------
