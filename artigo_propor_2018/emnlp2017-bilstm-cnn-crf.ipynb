# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %%
dados_df = pd.read_csv('exp_results.csv', sep='\t')
dados_df
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                       ID     Backend  \
# 0                                               44978167      theano
# 1                                             1933783619      theano
# 2                                             1638715529      theano
# 3                                             1818116294      theano
# 4                                              194943475      theano
# 5                                               68895212      theano
# 6                                              592012203      theano
# 7                                             1817909453      theano
# 8                                              996149138      theano
# ...

# %%
dados_ner_df = dados_df[(dados_df['LabelKey'] == 'NER_BIO') | (dados_df['LabelKey'] == 'NER_IOB') | (dados_df['LabelKey'] == 'NER_IOBES')]
dados_ner_df
# Out:
#                                                       ID     Backend  \
# 9577                                           776306087      Theano
# 9578                                           477564709      theano
# 9579                                           673865018      theano
# 9580                                          1950080165      Theano
# 9581                                          1063740343      Theano
# 9582                                           297208236      theano
# 9583                                          1923171646      Theano
# 9584                                           106799960      Theano
# 9585                                          1862835381      Theano
# 9586                                           907414352      theano
# 9587                                           529668934      theano
# 9588                                          1095451589      Theano
# 9589                                          1873264855      theano
# ...

# %%
dados_ner_df.describe()
# Out:
#        TrainSize   LSTM-Layers  LSTM-Neurons     clipvalue      clipnorm  \
# count    10821.0  10821.000000  10821.000000  10821.000000  10821.000000
# mean   1000000.0      2.439701    181.725534      0.147491      4.798170
# std          0.0      0.720694     82.606089      1.013066      1.130946
# min    1000000.0      1.000000     25.000000      0.000000      0.000000
# 25%    1000000.0      2.000000    125.000000      0.000000      5.000000
# 50%    1000000.0      3.000000    175.000000      0.000000      5.000000
# 75%    1000000.0      3.000000    250.000000      0.000000      5.000000
# max    1000000.0      3.000000    375.000000     10.000000     10.000000
#
#        miniBatchSize  CharEmbeddingsSize  CharFilterSize  CharFilterLength  \
# count   10821.000000        10821.000000    10821.000000      10821.000000
# mean       31.617965            1.355697        0.751317          0.232326
# std         5.239395            6.231901        4.687970          2.315022
# ...

# %%
dados_ner_df[dados_ner_df['Dev_F1'] < 0.1]
# Out:
#                ID Backend     Setting            Dataset Embeddings AuxData  \
# 9870    120417680  Theano  SingleTask  conll2003_ner.pkl   levy_dep      []
# 9952   1293084862  theano  SingleTask  conll2003_ner.pkl   levy_dep      []
# 11868   177067648  Theano  SingleTask  conll2003_ner.pkl   levy_dep      []
#
#        useTaskIdentifier   LabelKey TaggingScheme  TrainSize  Decoder  \
# 9870               False  NER_IOBES         IOBES    1000000      CRF
# 9952               False  NER_IOBES         IOBES    1000000  Softmax
# 11868              False    NER_IOB           IOB    1000000      CRF
#
#       customDecoder      Dropout  DropoutType VariationalDropoutType  \
# 9870             []    [0.25, 0]  Variational                 drop_W
# 9952             []   [0.1, 0.5]  Variational              drop_both
# 11868            []  [0.5, 0.05]  Variational              drop_both
#
#            LSTM-Size  LSTM-Layers  LSTM-Neurons Optimizer  clipvalue  \
# ...

# %%
dados_ner_df[(dados_ner_df['Optimizer'] == 'RMSProp') & (dados_ner_df['Decoder'] == 'CRF')].describe()
# Out:
#        TrainSize  LSTM-Layers  LSTM-Neurons    clipvalue     clipnorm  \
# count     1196.0  1196.000000   1196.000000  1196.000000  1196.000000
# mean   1000000.0     2.433946    180.433110     0.158863     4.782609
# std          0.0     0.704903     82.575801     1.050927     1.172730
# min    1000000.0     1.000000     25.000000     0.000000     0.000000
# 25%    1000000.0     2.000000    125.000000     0.000000     5.000000
# 50%    1000000.0     3.000000    175.000000     0.000000     5.000000
# 75%    1000000.0     3.000000    225.000000     0.000000     5.000000
# max    1000000.0     3.000000    375.000000    10.000000    10.000000
#
#        miniBatchSize  CharEmbeddingsSize  CharFilterSize  CharFilterLength  \
# count    1196.000000         1196.000000     1196.000000       1196.000000
# mean       31.576087            1.705686        0.953177          0.230769
# std         5.519541            6.949935        5.264023          2.169455
# ...

# %%
dados_ner_df[(dados_ner_df['Optimizer'] == 'Nadam') & (dados_ner_df['Decoder'] == 'CRF')].describe()
# Out:
#        TrainSize  LSTM-Layers  LSTM-Neurons    clipvalue     clipnorm  \
# count     1292.0  1292.000000   1292.000000  1292.000000  1292.000000
# mean   1000000.0     2.567337    189.652477     0.176471     4.758514
# std          0.0     0.663968     80.437027     1.106199     1.233617
# min    1000000.0     1.000000     25.000000     0.000000     0.000000
# 25%    1000000.0     2.000000    125.000000     0.000000     5.000000
# 50%    1000000.0     3.000000    200.000000     0.000000     5.000000
# 75%    1000000.0     3.000000    250.000000     0.000000     5.000000
# max    1000000.0     3.000000    375.000000    10.000000    10.000000
#
#        miniBatchSize  CharEmbeddingsSize  CharFilterSize  CharFilterLength  \
# count    1292.000000         1292.000000     1292.000000       1292.000000
# mean       31.426471            2.159443        1.137771          0.322755
# std         6.413218            7.756717        5.732717          2.671885
# ...

# %%
dados_ner_df[(dados_ner_df['Optimizer'] == 'SGD') & (dados_ner_df['Decoder'] == 'CRF')].describe()
# Out:
#        TrainSize  LSTM-Layers  LSTM-Neurons  clipvalue  clipnorm  \
# count      133.0   133.000000    133.000000      133.0     133.0
# mean   1000000.0     2.428571    175.939850        0.0       5.0
# std          0.0     0.731185     75.591482        0.0       0.0
# min    1000000.0     1.000000     25.000000        0.0       5.0
# 25%    1000000.0     2.000000    125.000000        0.0       5.0
# 50%    1000000.0     3.000000    175.000000        0.0       5.0
# 75%    1000000.0     3.000000    225.000000        0.0       5.0
# max    1000000.0     3.000000    375.000000        0.0       5.0
#
#        miniBatchSize  CharEmbeddingsSize  CharFilterSize  CharFilterLength  \
# count          133.0               133.0           133.0             133.0
# mean            32.0                 0.0             0.0               0.0
# std              0.0                 0.0             0.0               0.0
# min             32.0                 0.0             0.0               0.0
# ...

# %%
dados_ner_df.groupby(by=['Optimizer'])['Dev_F1','Test_F1'].describe(percentiles=[])
# Out:
#            Dev_F1                                                   Test_F1  \
#             count      mean       std       min       50%       max   count
# Optimizer
# Adadelta    270.0  0.914616  0.015636  0.863794  0.917573  0.941167   270.0
# Adagrad     269.0  0.912250  0.017731  0.844591  0.915513  0.941384   269.0
# Adam       4536.0  0.924251  0.016151  0.539702  0.926403  0.949230  4536.0
# Adam_org    228.0  0.928509  0.007825  0.894899  0.929750  0.943719   228.0
# Nadam      2743.0  0.927362  0.007833  0.894724  0.928361  0.948245  2743.0
# RMSProp    2504.0  0.924322  0.009787  0.884228  0.925060  0.945708  2504.0
# SGD         271.0  0.778042  0.163857  0.009680  0.831243  0.933804   271.0
#
#
#                mean       std       min       50%       max
# Optimizer
# Adadelta   0.876129  0.014191  0.828680  0.877957  0.905099
# Adagrad    0.874377  0.015914  0.818772  0.876720  0.903829
# Adam       0.884828  0.014391  0.547086  0.886530  0.905925
# ...

# %%
dados_ner_df.groupby(by=['TaggingScheme'])['Dev_F1','Test_F1'].describe(percentiles=[])
# Out:
#                Dev_F1                                                    \
#                 count      mean       std       min       50%       max
# TaggingScheme
# BIO            4583.0  0.921430  0.031694  0.148663  0.925657  0.948245
# IOB            3050.0  0.919381  0.035589  0.061592  0.924885  0.946706
# IOBES          3188.0  0.921744  0.044456  0.009680  0.927962  0.949230
#
#               Test_F1
#                 count      mean       std       min       50%       max
# TaggingScheme
# BIO            4583.0  0.882272  0.029649  0.162226  0.885931  0.910356
# IOB            3050.0  0.878189  0.031789  0.087571  0.882660  0.904996
# IOBES          3188.0  0.882920  0.041308  0.011952  0.888370  0.909816

# %%
dados_ner_df.groupby(by=['CharEmbeddings'])['Dev_F1','Test_F1'].describe(percentiles=[])
# Out:
#                  Dev_F1                                                    \
#                   count      mean       std       min       50%       max
# CharEmbeddings
# CNN               271.0  0.931813  0.007209  0.911341  0.932523  0.949230
# False           10332.0  0.920428  0.037706  0.009680  0.925873  0.945129
# LSTM              218.0  0.931947  0.007016  0.907129  0.933031  0.948245
#
#                 Test_F1
#                   count      mean       std       min       50%       max
# CharEmbeddings
# CNN               271.0  0.889597  0.008116  0.863191  0.890109  0.907570
# False           10332.0  0.880911  0.034813  0.011952  0.885714  0.910356
# LSTM              218.0  0.890036  0.007996  0.861927  0.890964  0.907437

# %%
dados_df.columns.values
# Out:
# array(['Training Round', 'Epochs', 'Scenario', 'Embedding',
#        'Tagging Scheme', 'Capitalisation Dim', 'Lower', 'Char LSTM Dim',
#        'Word LSTM Dim', 'Precision', 'Recall', 'F1 Score'], dtype=object)

# %%
dados_df.groupby('Embedding').describe(percentiles=[])
# Out:
#           Char LSTM Dim                                         Epochs       \
#                   count       mean        std   min   50%   max  count mean
# Embedding
# FastText           74.0  37.162162  12.580728  25.0  25.0  50.0   74.0  5.0
# Wang2Vec          227.0  37.444934  12.527503  25.0  25.0  50.0  227.0  5.0
#
#                               F1 Score                                     \
#            std  min  50%  max    count       mean       std    min    50%
# Embedding
# FastText   0.0  5.0  5.0  5.0     74.0  60.850811  4.600628  53.90  60.51
# Wang2Vec   0.0  5.0  5.0  5.0    227.0  60.938326  5.234653  53.82  57.76
#
#                  Precision                                            Recall  \
#              max     count       mean       std    min     50%    max  count
# Embedding
# FastText   66.90      74.0  64.694324  3.477877  54.60  64.905  70.48   74.0
# Wang2Vec   68.26     227.0  64.707709  4.243702  55.18  65.470  72.78  227.0
#
# ...

# %%
dados_df.pivot_table(columns=['Embedding'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                           mean                   amax                  amin  \
# Embedding             FastText    Wang2Vec   FastText   Wang2Vec   FastText
# Capitalisation Dim    0.513514    0.519824       True       True      False
# Char LSTM Dim        37.162162   37.444934         50         50         25
# Epochs                5.000000    5.000000          5          5          5
# F1 Score             60.850811   60.938326       66.9      68.26       53.9
# Lower                 0.500000    0.444934       True       True      False
# Precision            64.694324   64.707709      70.48      72.78       54.6
# Recall               57.740541   57.888546      69.13      69.27      45.43
# Scenario                   NaN         NaN  selective  selective  selective
# Tagging Scheme             NaN         NaN      iobes      iobes        iob
# Training Round        1.054054    4.515419          2          9          0
# ...

# %%
dados_df.pivot_table(columns=['Lower','Capitalisation Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                                                mean       amax       amin  \
#                Lower Capitalisation Dim
# Char LSTM Dim  False False                37.179487         50         25
#                      True                 37.647059         50         25
#                True  False                37.686567         50         25
#                      True                 36.971831         50         25
# Embedding      False False                      NaN   Wang2Vec   FastText
#                      True                       NaN   Wang2Vec   FastText
#                True  False                      NaN   Wang2Vec   FastText
#                      True                       NaN   Wang2Vec   FastText
# Epochs         False False                 5.000000          5          5
#                      True                  5.000000          5          5
#                True  False                 5.000000          5          5
# ...

# %%
dados_df.pivot_table(columns=['Tagging Scheme'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                           mean                   amax                  amin  \
# Tagging Scheme             iob       iobes        iob      iobes        iob
# Capitalisation Dim    0.513514    0.522876       True       True      False
# Char LSTM Dim        37.500000   37.254902         50         50         25
# Embedding                  NaN         NaN   Wang2Vec   Wang2Vec   FastText
# Epochs                5.000000    5.000000          5          5          5
# F1 Score             60.837500   60.993529      68.26      67.87      53.82
# Lower                 0.459459    0.457516       True       True      False
# Precision            64.783378   64.628039      72.78      72.08      55.18
# Recall               57.641419   58.056013      69.27      69.13      45.79
# Scenario                   NaN         NaN  selective  selective  selective
# Training Round        3.547297    3.777778          9          9          0
# ...

# %%
dados_df.pivot_table(columns=['Char LSTM Dim','Word LSTM Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                                                      mean       amax  \
#                    Char LSTM Dim Word LSTM Dim
# Capitalisation Dim 25            100             0.556962       True
#                                  200             0.479452       True
#                    50            100             0.513158       True
#                                  200             0.520548       True
# Embedding          25            100                  NaN   Wang2Vec
#                                  200                  NaN   Wang2Vec
#                    50            100                  NaN   Wang2Vec
#                                  200                  NaN   Wang2Vec
# Epochs             25            100             5.000000          5
#                                  200             5.000000          5
#                    50            100             5.000000          5
#                                  200             5.000000          5
# ...

# %%
dados_df.pivot_table(columns=['Word LSTM Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                          mean                  amax                  amin  \
# Word LSTM Dim             100        200        100        200        100
# Capitalisation Dim   0.535484   0.500000       True       True      False
# Char LSTM Dim       37.258065  37.500000         50         50         25
# Embedding                 NaN        NaN   Wang2Vec   Wang2Vec   FastText
# Epochs               5.000000   5.000000          5          5          5
# F1 Score            61.337484  60.470205      68.26      68.07       53.9
# Lower                0.483871   0.431507       True       True      False
# Precision           64.819032  64.582740      72.42      72.78      55.92
# Recall              58.523677  57.139247      69.27      68.59      47.01
# Scenario                  NaN        NaN  selective  selective  selective
# Tagging Scheme            NaN        NaN      iobes      iobes        iob
# Training Round       3.690323   3.636986          9          9          0
#
# ...

# %%
dados_df.pivot_table(columns=['Char LSTM Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                           mean                   amax                  amin  \
# Char LSTM Dim               25          50         25         50         25
# Capitalisation Dim    0.519737    0.516779       True       True      False
# Embedding                  NaN         NaN   Wang2Vec   Wang2Vec   FastText
# Epochs                5.000000    5.000000          5          5          5
# F1 Score             60.934211   60.899060      68.26      68.07      53.82
# Lower                 0.460526    0.456376       True       True      False
# Precision            64.579342   64.832013      72.08      72.78      55.89
# Recall               57.989605   57.711946      69.27      69.13      45.89
# Scenario                   NaN         NaN  selective  selective  selective
# Tagging Scheme             NaN         NaN      iobes      iobes        iob
# Training Round        3.697368    3.630872          9          9          0
# ...

# %%
dados_df.plot(kind='hist', x='Embedding', y='F1 Score')

# %%
dados_df.boxplot(column='F1 Score', by='Embedding')
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
tagging_scheme_axes = dados_df.boxplot(column='F1 Score', by='Tagging Scheme', showmeans=True, return_type='axes')
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
lower_plot = dados_df.boxplot(column='F1 Score', by='Lower', showmeans=True, ax=tagging_scheme_axes)
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:5847: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   return_type=return_type, **kwds)
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
dados_df.boxplot(column='F1 Score', by='Lower')
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
plot = dados_df.boxplot(column='F1 Score', by='Capitalisation Dim')
#fig = plot.figure
#fig.savefig('cap_dim.png')
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
dados_df.boxplot(column='F1 Score', by='Char LSTM Dim')
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
dados_df.boxplot(column='F1 Score', by=['Word LSTM Dim','Char LSTM Dim'])
# Out:
# /home/pedro/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
dados_wang_df = dados_df[dados_df['Embedding'] == 'Wang2Vec']
del dados_wang_df['Embedding']
dados_wang_df
# Out:
#      Training Round  Epochs   Scenario Tagging Scheme  Capitalisation Dim  \
# 0                 0       5  selective            iob               False
# 32                1       5  selective            iob               False
# 64                2       5  selective            iob               False
# 128               4       5  selective            iob               False
# 192               6       5  selective            iob               False
# 224               7       5  selective            iob               False
# 1                 0       5  selective            iob               False
# 33                1       5  selective            iob               False
# 65                2       5  selective            iob               False
# 97                3       5  selective            iob               False
# 129               4       5  selective            iob               False
# 161               5       5  selective            iob               False
# ...

# %%
dados_wang_df.pivot_table(columns=['Char LSTM Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                           mean                   amax                  amin  \
# Char LSTM Dim               25          50         25         50         25
# Capitalisation Dim    0.517544    0.522124       True       True      False
# Epochs                5.000000    5.000000          5          5          5
# F1 Score             60.917807   60.959027      68.26      68.07      53.82
# Lower                 0.447368    0.442478       True       True      False
# Precision            64.600263   64.816106      72.08      72.78      55.89
# Recall               57.956667   57.819823      69.27      68.59      45.89
# Scenario                   NaN         NaN  selective  selective  selective
# Tagging Scheme             NaN         NaN      iobes      iobes        iob
# Training Round        4.578947    4.451327          9          9          0
# Word LSTM Dim       148.245614  147.787611        200        200        100
#
#                                      std
# ...

# %%
dados_wang_df.pivot_table(columns=['Word LSTM Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                          mean                  amax                  amin  \
# Word LSTM Dim             100        200        100        200        100
# Capitalisation Dim   0.550847   0.486239       True       True      False
# Char LSTM Dim       37.500000  37.385321         50         50         25
# Epochs               5.000000   5.000000          5          5          5
# F1 Score            61.383220  60.456697      68.26      68.07      54.68
# Lower                0.474576   0.412844       True       True      False
# Precision           64.871441  64.530459      72.42      72.78      55.92
# Recall              58.556017  57.165963      69.27      68.59      47.01
# Scenario                  NaN        NaN  selective  selective  selective
# Tagging Scheme            NaN        NaN      iobes      iobes        iob
# Training Round       4.550847   4.477064          9          9          0
#
#                                      std
# ...

# %%
dados_wang_df.pivot_table(columns=['Word LSTM Dim', 'Char LSTM Dim'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                                                      mean       amax  \
#                    Word LSTM Dim Char LSTM Dim
# Capitalisation Dim 100           25              0.576271       True
#                                  50              0.525424       True
#                    200           25              0.454545       True
#                                  50              0.518519       True
# Epochs             100           25              5.000000          5
#                                  50              5.000000          5
#                    200           25              5.000000          5
#                                  50              5.000000          5
# F1 Score           100           25             61.939492      68.26
#                                  50             60.826949      67.69
#                    200           25             59.821818      67.27
#                                  50             61.103333      68.07
# ...

# %%
dados_wang_df.pivot_table(columns=['Tagging Scheme'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                           mean                   amax                  amin  \
# Tagging Scheme             iob       iobes        iob      iobes        iob
# Capitalisation Dim    0.513274    0.526316       True       True      False
# Char LSTM Dim        37.610619   37.280702         50         50         25
# Epochs                5.000000    5.000000          5          5          5
# F1 Score             60.902212   60.974123      68.26      67.87      53.82
# Lower                 0.451327    0.438596       True       True      False
# Precision            64.898850   64.518246      72.78      72.08      55.18
# Recall               57.684867   58.090439      69.27      68.16      45.79
# Scenario                   NaN         NaN  selective  selective  selective
# Training Round        4.318584    4.710526          9          9          0
# Word LSTM Dim       146.017699  150.000000        200        200        100
#
#                                      std
# ...

# %%
dados_wang_df.pivot_table(columns=['Capitalisation Dim', 'Lower'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                                                mean       amax       amin  \
#                Capitalisation Dim Lower
# Char LSTM Dim  False              False   37.083333         50         25
#                                   True    37.755102         50         25
#                True               False   37.878788         50         25
#                                   True    37.019231         50         25
# Epochs         False              False    5.000000          5          5
#                                   True     5.000000          5          5
#                True               False    5.000000          5          5
#                                   True     5.000000          5          5
# F1 Score       False              False   56.144000      58.28      53.82
#                                   True    66.605306      68.07      64.95
#                True               False   56.494242      58.64      53.87
# ...

# %%
cols_alias = {'Embedding': 'Embedding', 'Tagging Scheme': 'Tagging Scheme', 'Lower': 'Normalization', 'Char LSTM Dim': 'Character Dimension', 'Word LSTM Dim': 'Word Dimension'}
fig, axes = plt.subplots(1, 5, figsize=(15, 5), sharey=True)

for idx, column in enumerate(cols_alias.keys()):
    idf = dados_df[['F1 Score',column]].pivot(columns=column)
    #print(idf)
    
    idf.plot.box(ax=axes[idx])
    axes[idx].set_title(cols_alias.get(column))
    axes[idx].set_xticklabels([e[1] for e in idf.columns])

plt.show()
fig.savefig('parameters_box_plots.png')

# %%
cols_alias = {'Tagging Scheme': 'Tagging Scheme', 'Lower': 'Normalization', 'Char LSTM Dim': 'Character Dimension', 'Word LSTM Dim': 'Word Dimension'}
fig, axes = plt.subplots(1, 4, figsize=(15, 5), sharey=True)

for idx, column in enumerate(cols_alias.keys()):
    idf = dados_wang_df[['F1 Score',column]].pivot(columns=column)
    
    idf.plot.box(ax=axes[idx])
    axes[idx].set_title(cols_alias.get(column))
    axes[idx].set_xticklabels([e[1] for e in idf.columns])

plt.show()
fig.savefig('parameters_box_plots_wang.png')

# %%
cols_alias = {'Tagging Scheme': {'label': 'Tagging Scheme', 'columns': ['Tagging Scheme']}, 
              'Lower': {'label': 'Normalization', 'columns': ['Lower']}, 
              'Char LSTM Dim': {'label': 'Character Dimension', 'columns': ['Word LSTM Dim','Char LSTM Dim']}, 
              'Word LSTM Dim': {'label': 'Word Dimension', 'columns': ['Word LSTM Dim']}}
#cols_alias = {'Tagging Scheme': ('Tagging Scheme','Tagging Scheme'), 'Lower': ('Normalization','Lower'), 'Char LSTM Dim': ('Character Dimension','Char LSTM Dim'), 'Word LSTM Dim': ('Word Dimension','Word LSTM Dim')}
fig, axes = plt.subplots(1, 4, figsize=(15, 5), sharey=True)

for idx, column in enumerate(cols_alias.keys()):
    columns = cols_alias.get(column)['columns']
    label = cols_alias.get(column)['label']
    #print(columns, type(columns), len(columns))
    data = [column for column in columns]
    #print(data)
    data.insert(0, 'F1 Score')
    #print(columns, data)
    idf = dados_wang_df[data].pivot_table(columns=columns)
    #idf = dados_wang_df[data].pivot(columns=columns[0])
    idf.plot.box(ax=axes[idx])
    axes[idx].set_title(label)
    print(type(idf))
    if isinstance(idf, pd.core.series.Series):
        idf = idf.to_frame()
        print(idf.index)
    for column in idf.columns:
        print(column)
    axes[idx].set_xticklabels([e for e in idf.columns])

plt.show()
fig.savefig('parameters_box_plots_wang.png')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# iob
# iobes
# <class 'pandas.core.frame.DataFrame'>
# False
# True
# <class 'pandas.core.series.Series'>
# MultiIndex(levels=[['F1 Score'], [100, 200], [25, 50]],
#            labels=[[0, 0, 0, 0], [0, 0, 1, 1], [0, 1, 0, 1]],
#            names=[None, 'Word LSTM Dim', 'Char LSTM Dim'])
# 0
# <class 'pandas.core.frame.DataFrame'>
# 100
# 200

# %%
df_pivot = dados_wang_df[['F1 Score','Word LSTM Dim','Char LSTM Dim']].pivot_table(columns=['Word LSTM Dim','Char LSTM Dim'])
print(df_pivot)
print(df_pivot.)
# Out:
#           Word LSTM Dim  Char LSTM Dim
# F1 Score  100            25               61.939492
#                          50               60.826949
#           200            25               59.821818
#                          50               61.103333
# dtype: float64
# MultiIndex(levels=[['F1 Score'], [100, 200], [25, 50]],
#            labels=[[0, 0, 0, 0], [0, 0, 1, 1], [0, 1, 0, 1]],
#            names=[None, 'Word LSTM Dim', 'Char LSTM Dim'])

# %%
df_pivot_2 = dados_wang_df[['F1 Score','Word LSTM Dim']].pivot(columns='Word LSTM Dim')
df_pivot_2
# Out:
#               F1 Score
# Word LSTM Dim      100    200
# 0                56.79    NaN
# 1                  NaN  56.43
# 2                55.40    NaN
# 4                67.00    NaN
# 5                  NaN  66.58
# 6                67.57    NaN
# 7                  NaN  65.21
# 8                58.08    NaN
# 9                  NaN  56.59
# 10               56.26    NaN
# 12               66.20    NaN
# 13                 NaN  66.11
# 14               66.75    NaN
# 15                 NaN  66.49
# 16               57.08    NaN
# 17                 NaN  55.25
# 19                 NaN  56.57
# 21                 NaN  66.00
# 22               66.67    NaN
# 24               57.77    NaN
# 25                 NaN  56.62
# 26               55.39    NaN
# 27                 NaN  58.12
# 28               66.27    NaN
# 29                 NaN  66.99
# 30               66.73    NaN
# 31                 NaN  66.28
# 32               56.07    NaN
# 33                 NaN  53.82
# ...
