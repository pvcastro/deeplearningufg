# %%
import json
import pandas as pd
from pathlib import Path
from pprint import pprint
import datetime
import time
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
TRAINING_ROUND = 'Training_Round'
EPOCHS = 'Epochs'
SCENARIO = 'Scenario'
EMBEDDING = 'Embedding'
TAGGING_SCHEME = 'Tagging_Scheme'
CAP_DIM = 'Capitalisation_Dim'
LOWER = 'Lower'
CHAR_DIM = 'Char_LSTM_Dim'
WORD_DIM = 'Word_LSTM_Dim'
PRECISION = 'Precision'
RECALL = 'Recall'
F1_SCORE = 'F1_Score'

# %%
columns = [TRAINING_ROUND, EPOCHS, SCENARIO, EMBEDDING, TAGGING_SCHEME, CAP_DIM, LOWER, CHAR_DIM, WORD_DIM, PRECISION, RECALL, F1_SCORE]

# %%
columns
# Out:
# ['Training_Round',
#  'Epochs',
#  'Scenario',
#  'Embedding',
#  'Tagging_Scheme',
#  'Capitalisation_Dim',
#  'Lower',
#  'Char_LSTM_Dim',
#  'Word_LSTM_Dim',
#  'Precision',
#  'Recall',
#  'F1_Score']

# %%
pd.set_option('display.max_columns', 1000)
training_data_df = pd.read_csv('resultados.csv')
training_data_df
# Out:
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 0                  0       5  selective  Wang2Vec            iob
# 1                  0       5  selective  Wang2Vec            iob
# 2                  0       5  selective  Wang2Vec            iob
# 3                  0       5  selective  Wang2Vec            iob
# 4                  0       5  selective  Wang2Vec            iob
# 5                  0       5  selective  Wang2Vec            iob
# 6                  0       5  selective  Wang2Vec            iob
# 7                  0       5  selective  Wang2Vec            iob
# 8                  0       5  selective  Wang2Vec            iob
# 9                  0       5  selective  Wang2Vec            iob
# 10                 0       5  selective  Wang2Vec            iob
# 11                 0       5  selective  Wang2Vec            iob
# 12                 0       5  selective  Wang2Vec            iob
# 13                 0       5  selective  Wang2Vec            iob
# 14                 0       5  selective  Wang2Vec            iob
# 15                 0       5  selective  Wang2Vec            iob
# 16                 0       5  selective  Wang2Vec          iobes
# 17                 0       5  selective  Wang2Vec          iobes
# 18                 0       5  selective  Wang2Vec          iobes
# 19                 0       5  selective  Wang2Vec          iobes
# 20                 0       5  selective  Wang2Vec          iobes
# 21                 0       5  selective  Wang2Vec          iobes
# 22                 0       5  selective  Wang2Vec          iobes
# 23                 0       5  selective  Wang2Vec          iobes
# 24                 0       5  selective  Wang2Vec          iobes
# 25                 0       5  selective  Wang2Vec          iobes
# 26                 0       5  selective  Wang2Vec          iobes
# 27                 0       5  selective  Wang2Vec          iobes
# 28                 0       5  selective  Wang2Vec          iobes
# 29                 0       5  selective  Wang2Vec          iobes
# ...              ...     ...        ...       ...            ...
# 1250               9       5  selective  Word2Vec            iob
# 1251               9       5  selective  Word2Vec            iob
# 1252               9       5  selective  Word2Vec            iob
# 1253               9       5  selective  Word2Vec            iob
# 1254               9       5  selective  Word2Vec            iob
# 1255               9       5  selective  Word2Vec            iob
# 1256               9       5  selective  Word2Vec            iob
# 1257               9       5  selective  Word2Vec            iob
# 1258               9       5  selective  Word2Vec            iob
# 1259               9       5  selective  Word2Vec            iob
# 1260               9       5  selective  Word2Vec            iob
# 1261               9       5  selective  Word2Vec            iob
# 1262               9       5  selective  Word2Vec            iob
# 1263               9       5  selective  Word2Vec            iob
# 1264               9       5  selective  Word2Vec          iobes
# 1265               9       5  selective  Word2Vec          iobes
# 1266               9       5  selective  Word2Vec          iobes
# 1267               9       5  selective  Word2Vec          iobes
# 1268               9       5  selective  Word2Vec          iobes
# 1269               9       5  selective  Word2Vec          iobes
# 1270               9       5  selective  Word2Vec          iobes
# 1271               9       5  selective  Word2Vec          iobes
# 1272               9       5  selective  Word2Vec          iobes
# 1273               9       5  selective  Word2Vec          iobes
# 1274               9       5  selective  Word2Vec          iobes
# 1275               9       5  selective  Word2Vec          iobes
# 1276               9       5  selective  Word2Vec          iobes
# 1277               9       5  selective  Word2Vec          iobes
# 1278               9       5  selective  Word2Vec          iobes
# 1279               9       5  selective  Word2Vec          iobes
#
#       Capitalisation_Dim  Lower  Char_LSTM_Dim  Word_LSTM_Dim  Precision  \
# 0                  False  False             25            100      58.95
# 1                  False  False             25            200      61.60
# 2                  False  False             50            100      66.50
# 3                  False  False             50            200      58.54
# 4                  False   True             25            100      66.28
# 5                  False   True             25            200      71.00
# 6                  False   True             50            100      70.14
# 7                  False   True             50            200      66.93
# 8                   True  False             25            100      58.62
# 9                   True  False             25            200      64.42
# 10                  True  False             50            100      66.29
# 11                  True  False             50            200      57.48
# 12                  True   True             25            100      70.32
# 13                  True   True             25            200      69.64
# 14                  True   True             50            100      69.42
# 15                  True   True             50            200      68.37
# 16                 False  False             25            100      62.34
# 17                 False  False             25            200      59.79
# 18                 False  False             50            100      68.57
# 19                 False  False             50            200      59.35
# 20                 False   True             25            100      67.04
# 21                 False   True             25            200      69.78
# 22                 False   True             50            100      67.37
# 23                 False   True             50            200       1.09
# 24                  True  False             25            100      64.54
# 25                  True  False             25            200      58.86
# 26                  True  False             50            100      61.45
# 27                  True  False             50            200      61.48
# 28                  True   True             25            100      68.14
# 29                  True   True             25            200      68.93
# ...                  ...    ...            ...            ...        ...
# 1250               False  False             50            100      56.50
# 1251               False  False             50            200      53.05
# 1252               False   True             25            100      52.88
# 1253               False   True             25            200      51.21
# 1254               False   True             50            100      48.90
# 1255               False   True             50            200      53.92
# 1256                True  False             25            100      60.26
# 1257                True  False             25            200      53.88
# 1258                True  False             50            100      56.27
# 1259                True  False             50            200      60.33
# 1260                True   True             25            100      52.93
# 1261                True   True             25            200      50.44
# 1262                True   True             50            100      46.86
# 1263                True   True             50            200      55.14
# 1264               False  False             25            100      59.74
# 1265               False  False             25            200      51.19
# 1266               False  False             50            100      59.56
# 1267               False  False             50            200      56.36
# 1268               False   True             25            100      47.82
# 1269               False   True             25            200      53.66
# 1270               False   True             50            100      51.79
# 1271               False   True             50            200      55.89
# 1272                True  False             25            100      57.79
# 1273                True  False             25            200      55.91
# 1274                True  False             50            100      58.84
# 1275                True  False             50            200      55.10
# 1276                True   True             25            100      51.59
# 1277                True   True             25            200      52.38
# 1278                True   True             50            100      49.53
# 1279                True   True             50            200      56.24
#
#       Recall  F1_Score
# 0      54.79     56.79
# 1      52.06     56.43
# 2      47.47     55.40
# 3      50.74     54.36
# 4      67.73     67.00
# 5      62.67     66.58
# 6      65.18     67.57
# 7      63.57     65.21
# 8      57.55     58.08
# 9      50.45     56.59
# 10     48.87     56.26
# 11     26.17     35.97
# 12     62.53     66.20
# 13     62.93     66.11
# 14     64.29     66.75
# 15     64.72     66.49
# 16     52.64     57.08
# 17     51.34     55.25
# 18     44.68     54.10
# 19     54.03     56.57
# 20     64.11     65.54
# 21     62.60     66.00
# 22     65.97     66.67
# 23      6.92      1.88
# 24     52.28     57.77
# 25     54.54     56.62
# 26     50.41     55.39
# 27     55.11     58.12
# 28     64.50     66.27
# 29     65.15     66.99
# ...      ...       ...
# 1250   53.78     55.11
# 1251   53.32     53.18
# 1252   50.02     51.41
# 1253   44.93     47.86
# 1254   38.26     42.93
# 1255   46.40     49.87
# 1256   49.80     54.53
# 1257   52.78     53.32
# 1258   55.18     55.72
# 1259   52.67     56.24
# 1260   48.23     50.47
# 1261   53.39     51.87
# 1262   52.67     49.59
# 1263   43.10     48.38
# 1264   50.59     54.79
# 1265   54.82     52.94
# 1266   51.85     55.43
# 1267   54.36     55.34
# 1268   46.47     47.14
# 1269   46.76     49.97
# 1270   52.81     52.30
# 1271   43.24     48.76
# 1272   50.95     54.15
# 1273   52.06     53.92
# 1274   53.35     55.96
# 1275   53.07     54.06
# 1276   43.06     46.94
# 1277   45.00     48.41
# 1278   46.83     48.14
# 1279   42.95     48.71
#
# [1280 rows x 12 columns]

# %%
training_data_df = training_data_df[training_data_df.Scenario == 'selective']
len(training_data_df)
# Out:
# 1280

# %%
training_data_df.groupby([TAGGING_SCHEME]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                 count       mean        std  min     25%     50%      75%  \
# Tagging_Scheme
# iob             640.0  55.331156  11.682397  0.0  53.620  55.950  63.1800
# iobes           640.0  55.052266  12.412086  0.0  53.435  56.245  63.2025
#
#                   max
# Tagging_Scheme
# iob             68.26
# iobes           67.99

# %%
training_data_df.groupby([EMBEDDING]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#            count       mean        std   min      25%     50%      75%    max
# Embedding
# Wang2Vec   320.0  57.490094  13.722370  0.00  55.7250  57.585  66.3850  68.26
# FastText   320.0  56.529375  14.100258  0.00  55.9200  57.605  65.0075  67.05
# Glove      320.0  56.169750  11.123950  1.01  54.7225  56.575  62.6050  64.89
# Word2Vec   320.0  50.577625   6.464692  0.19  48.7075  51.510  54.4125  56.92

# %%
training_data_df.groupby([CAP_DIM]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                     count       mean        std  min      25%    50%      75%  \
# Capitalisation_Dim
# True                640.0  56.097187  10.481794  0.0  53.8875  56.29  63.4100
# False               640.0  54.286234  13.381588  0.0  53.1875  55.90  62.9775
#
#                       max
# Capitalisation_Dim
# True                68.26
# False               68.07

# %%
training_data_df.groupby([CHAR_DIM]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                count       mean        std  min      25%    50%      75%  \
# Char_LSTM_Dim
# 25             640.0  55.322891  11.981899  0.0  53.5375  56.09  63.1725
# 50             640.0  55.060531  12.123402  0.0  53.5200  56.16  63.2125
#
#                  max
# Char_LSTM_Dim
# 25             68.26
# 50             68.07

# %%
training_data_df.groupby([WORD_DIM]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                count       mean        std  min      25%     50%      75%  \
# Word_LSTM_Dim
# 100            640.0  56.021109  10.629522  0.0  54.0875  56.275  63.2750
# 200            640.0  54.362312  13.274508  0.0  52.9775  55.945  63.1425
#
#                  max
# Word_LSTM_Dim
# 100            68.26
# 200            68.07

# %%
training_data_df.groupby([LOWER]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#        count       mean        std  min      25%     50%      75%    max
# Lower
# True   640.0  57.346156  13.749383  0.0  49.9350  63.185  65.6925  68.26
# False  640.0  53.037266   9.603849  0.0  54.1875  55.430  56.4600  59.82

# %%
training_data_df.groupby([EMBEDDING, TAGGING_SCHEME, CAP_DIM, WORD_DIM, CHAR_DIM, LOWER]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                                                                                count  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True    10.0
#           iobes          True               200           25            True    10.0
#           iob            True               100           50            True    10.0
#           iobes          True               100           25            True    10.0
#                                                           50            True    10.0
#                                             200           50            True    10.0
# FastText  iob            True               100           25            True    10.0
#                          False              100           25            True    10.0
#           iobes          True               200           25            True    10.0
#           iob            False              200           50            True    10.0
#           iobes          False              100           25            True    10.0
# Wang2Vec  iob            True               100           25            True    10.0
# FastText  iob            True               200           50            True    10.0
#           iobes          True               100           25            True    10.0
# Glove     iob            True               100           50            True    10.0
# Wang2Vec  iob            True               200           50            True    10.0
# Glove     iobes          True               100           25            True    10.0
#           iob            False              100           50            True    10.0
#                                             200           25            True    10.0
#                          True               200           25            True    10.0
#           iobes          True               200           50            True    10.0
# FastText  iob            True               100           50            True    10.0
# Wang2Vec  iob            True               200           25            True    10.0
# Glove     iobes          True               100           50            True    10.0
# Wang2Vec  iob            False              200           25            True    10.0
# FastText  iob            True               200           25            True    10.0
# Wang2Vec  iobes          False              200           50            True    10.0
# FastText  iobes          False              100           50            True    10.0
# Wang2Vec  iobes          False              100           25            True    10.0
# Glove     iobes          False              200           50            True    10.0
# ...                                                                              ...
# FastText  iobes          False              200           50            False   10.0
#           iob            False              200           50            False   10.0
# Wang2Vec  iobes          False              100           25            False   10.0
# Word2Vec  iob            False              100           25            True    10.0
#           iobes          True               100           50            True    10.0
# Glove     iob            False              200           25            False   10.0
# Word2Vec  iob            False              100           50            False   10.0
#                                             200           50            True    10.0
#           iobes          False              200           50            True    10.0
#                                             100           50            True    10.0
#           iob            True               100           25            True    10.0
# Glove     iobes          True               200           50            False   10.0
# Word2Vec  iobes          True               200           50            True    10.0
#           iob            False              100           50            True    10.0
#           iobes          True               100           25            True    10.0
#           iob            True               200           25            True    10.0
#                                             100           50            True    10.0
#           iobes          False              200           25            True    10.0
#                                             100           25            True    10.0
#           iob            True               200           50            True    10.0
# Glove     iobes          True               200           25            False   10.0
# Word2Vec  iobes          True               200           25            True    10.0
# Glove     iobes          False              200           25            False   10.0
# FastText  iobes          False              100           25            False   10.0
# Word2Vec  iob            True               200           50            False   10.0
#           iobes          True               200           50            False   10.0
# Wang2Vec  iob            True               200           50            False   10.0
# Word2Vec  iob            False              200           25            True    10.0
# FastText  iob            False              200           25            False   10.0
# Wang2Vec  iob            False              200           50            True    10.0
#
#                                                                                  mean  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   66.901
#           iobes          True               200           25            True   66.788
#           iob            True               100           50            True   66.668
#           iobes          True               100           25            True   66.550
#                                                           50            True   66.446
#                                             200           50            True   66.328
# FastText  iob            True               100           25            True   65.836
#                          False              100           25            True   65.259
#           iobes          True               200           25            True   64.729
#           iob            False              200           50            True   64.634
#           iobes          False              100           25            True   64.368
# Wang2Vec  iob            True               100           25            True   63.950
# FastText  iob            True               200           50            True   63.393
#           iobes          True               100           25            True   63.310
# Glove     iob            True               100           50            True   62.995
# Wang2Vec  iob            True               200           50            True   62.694
# Glove     iobes          True               100           25            True   62.613
#           iob            False              100           50            True   62.551
#                                             200           25            True   62.184
#                          True               200           25            True   62.116
#           iobes          True               200           50            True   62.046
# FastText  iob            True               100           50            True   61.543
# Wang2Vec  iob            True               200           25            True   61.420
# Glove     iobes          True               100           50            True   60.996
# Wang2Vec  iob            False              200           25            True   60.233
# FastText  iob            True               200           25            True   60.202
# Wang2Vec  iobes          False              200           50            True   59.872
# FastText  iobes          False              100           50            True   59.872
# Wang2Vec  iobes          False              100           25            True   59.791
# Glove     iobes          False              200           50            True   59.764
# ...                                                                               ...
# FastText  iobes          False              200           50            False  50.724
#           iob            False              200           50            False  50.019
# Wang2Vec  iobes          False              100           25            False  49.688
# Word2Vec  iob            False              100           25            True   49.637
#           iobes          True               100           50            True   49.536
# Glove     iob            False              200           25            False  49.435
# Word2Vec  iob            False              100           50            False  49.241
#                                             200           50            True   49.153
#           iobes          False              200           50            True   49.137
#                                             100           50            True   49.136
#           iob            True               100           25            True   49.032
# Glove     iobes          True               200           50            False  49.008
# Word2Vec  iobes          True               200           50            True   48.987
#           iob            False              100           50            True   48.679
#           iobes          True               100           25            True   48.598
#           iob            True               200           25            True   48.434
#                                             100           50            True   48.404
#           iobes          False              200           25            True   48.069
#                                             100           25            True   47.938
#           iob            True               200           50            True   47.849
# Glove     iobes          True               200           25            False  47.686
# Word2Vec  iobes          True               200           25            True   47.344
# Glove     iobes          False              200           25            False  46.726
# FastText  iobes          False              100           25            False  45.852
# Word2Vec  iob            True               200           50            False  45.815
#           iobes          True               200           50            False  45.792
# Wang2Vec  iob            True               200           50            False  45.655
# Word2Vec  iob            False              200           25            True   45.091
# FastText  iob            False              200           25            False  44.466
# Wang2Vec  iob            False              200           50            True   43.167
#
#                                                                                      std  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True    0.721641
#           iobes          True               200           25            True    0.771432
#           iob            True               100           50            True    0.790974
#           iobes          True               100           25            True    1.105039
#                                                           50            True    1.103260
#                                             200           50            True    0.419571
# FastText  iob            True               100           25            True    0.611777
#                          False              100           25            True    0.888988
#           iobes          True               200           25            True    1.051522
#           iob            False              200           50            True    0.748913
#           iobes          False              100           25            True    4.215779
# Wang2Vec  iob            True               100           25            True    9.360411
# FastText  iob            True               200           50            True    3.937312
#           iobes          True               100           25            True    6.793863
# Glove     iob            True               100           50            True    0.973165
# Wang2Vec  iob            True               200           50            True   12.344834
# Glove     iobes          True               100           25            True    1.207229
#           iob            False              100           50            True    1.429145
#                                             200           25            True    1.057567
#                          True               200           25            True    0.846630
#           iobes          True               200           50            True    2.439737
# FastText  iob            True               100           50            True   13.202239
# Wang2Vec  iob            True               200           25            True    9.623968
# Glove     iobes          True               100           50            True    4.721071
# Wang2Vec  iob            False              200           25            True   18.961831
# FastText  iob            True               200           25            True   16.065675
# Wang2Vec  iobes          False              200           50            True   20.394392
# FastText  iobes          False              100           50            True   13.420776
# Wang2Vec  iobes          False              100           25            True   20.431977
# Glove     iobes          False              200           50            True   10.517873
# ...                                                                                  ...
# FastText  iobes          False              200           50            False  17.488646
#           iob            False              200           50            False  13.364860
# Wang2Vec  iobes          False              100           25            False  16.520855
# Word2Vec  iob            False              100           25            True    1.567893
#           iobes          True               100           50            True    0.926921
# Glove     iob            False              200           25            False  14.588726
# Word2Vec  iob            False              100           50            False  12.836257
#                                             200           50            True    1.987562
#           iobes          False              200           50            True    1.437653
#                                             100           50            True    2.135698
#           iob            True               100           25            True    1.725346
# Glove     iobes          True               200           50            False  16.409136
# Word2Vec  iobes          True               200           50            True    1.344818
#           iob            False              100           50            True    2.778243
#           iobes          True               100           25            True    1.155939
#           iob            True               200           25            True    1.984737
#                                             100           50            True    1.931644
#           iobes          False              200           25            True    2.013617
#                                             100           25            True    2.347967
#           iob            True               200           50            True    3.496673
# Glove     iobes          True               200           25            False  16.157694
# Word2Vec  iobes          True               200           25            True    2.079531
# Glove     iobes          False              200           25            False  18.465574
# FastText  iobes          False              100           25            False  16.261060
# Word2Vec  iob            True               200           50            False  18.767193
#           iobes          True               200           50            False  18.202460
# Wang2Vec  iob            True               200           50            False  18.174768
# Word2Vec  iob            False              200           25            True   10.278486
# FastText  iob            False              200           25            False  23.086051
# Wang2Vec  iob            False              200           50            True   30.903620
#
#                                                                                  min  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   65.44
#           iobes          True               200           25            True   65.54
#           iob            True               100           50            True   65.00
#           iobes          True               100           25            True   63.99
#                                                           50            True   63.63
#                                             200           50            True   65.60
# FastText  iob            True               100           25            True   64.78
#                          False              100           25            True   64.14
#           iobes          True               200           25            True   63.11
#           iob            False              200           50            True   63.09
#           iobes          False              100           25            True   52.44
# Wang2Vec  iob            True               100           25            True   37.49
# FastText  iob            True               200           50            True   52.43
#           iobes          True               100           25            True   44.09
# Glove     iob            True               100           50            True   61.44
# Wang2Vec  iob            True               200           50            True   27.58
# Glove     iobes          True               100           25            True   59.37
#           iob            False              100           50            True   59.96
#                                             200           25            True   60.31
#                          True               200           25            True   60.68
#           iobes          True               200           50            True   55.69
# FastText  iob            True               100           50            True   24.06
# Wang2Vec  iob            True               200           25            True   36.85
# Glove     iobes          True               100           50            True   47.80
# Wang2Vec  iob            False              200           25            True    6.28
# FastText  iob            True               200           25            True   14.51
# Wang2Vec  iobes          False              200           50            True    1.88
# FastText  iobes          False              100           50            True   22.55
# Wang2Vec  iobes          False              100           25            True    1.66
# Glove     iobes          False              200           50            True   29.93
# ...                                                                              ...
# FastText  iobes          False              200           50            False   1.01
#           iob            False              200           50            False  21.65
# Wang2Vec  iobes          False              100           25            False  10.46
# Word2Vec  iob            False              100           25            True   46.85
#           iobes          True               100           50            True   48.14
# Glove     iob            False              200           25            False   7.99
# Word2Vec  iob            False              100           50            False  22.25
#                                             200           50            True   46.26
#           iobes          False              200           50            True   46.45
#                                             100           50            True   45.68
#           iob            True               100           25            True   45.96
# Glove     iobes          True               200           50            False   3.10
# Word2Vec  iobes          True               200           50            True   46.85
#           iob            False              100           50            True   42.93
#           iobes          True               100           25            True   46.94
#           iob            True               200           25            True   44.34
#                                             100           50            True   45.23
#           iobes          False              200           25            True   44.33
#                                             100           25            True   42.97
#           iob            True               200           50            True   38.92
# Glove     iobes          True               200           25            False  14.60
# Word2Vec  iobes          True               200           25            True   43.81
# Glove     iobes          False              200           25            False   2.25
# FastText  iobes          False              100           25            False  21.27
# Word2Vec  iob            True               200           50            False   9.01
#           iobes          True               200           50            False   0.19
# Wang2Vec  iob            True               200           50            False   6.73
# Word2Vec  iob            False              200           25            True   16.37
# FastText  iob            False              200           25            False   0.00
# Wang2Vec  iob            False              200           50            True    0.55
#
#                                                                                    25%  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   66.4250
#           iobes          True               200           25            True   66.2750
#           iob            True               100           50            True   66.3300
#           iobes          True               100           25            True   66.2625
#                                                           50            True   66.3150
#                                             200           50            True   66.2125
# FastText  iob            True               100           25            True   65.4750
#                          False              100           25            True   64.5925
#           iobes          True               200           25            True   64.3175
#           iob            False              200           50            True   64.2075
#           iobes          False              100           25            True   65.3025
# Wang2Vec  iob            True               100           25            True   65.7650
# FastText  iob            True               200           50            True   63.7275
#           iobes          True               100           25            True   64.9150
# Glove     iob            True               100           50            True   62.4550
# Wang2Vec  iob            True               200           50            True   66.1375
# Glove     iobes          True               100           25            True   62.6825
#           iob            False              100           50            True   62.2500
#                                             200           25            True   61.3825
#                          True               200           25            True   61.5600
#           iobes          True               200           50            True   61.5875
# FastText  iob            True               100           50            True   64.6800
# Wang2Vec  iob            True               200           25            True   59.4925
# Glove     iobes          True               100           50            True   61.6225
# Wang2Vec  iob            False              200           25            True   65.8300
# FastText  iob            True               200           25            True   64.6450
# Wang2Vec  iobes          False              200           50            True   65.5150
# FastText  iobes          False              100           50            True   63.6900
# Wang2Vec  iobes          False              100           25            True   65.5625
# Glove     iobes          False              200           50            True   62.4725
# ...                                                                                ...
# FastText  iobes          False              200           50            False  55.4025
#           iob            False              200           50            False  55.8400
# Wang2Vec  iobes          False              100           25            False  56.0300
# Word2Vec  iob            False              100           25            True   48.3575
#           iobes          True               100           50            True   48.9625
# Glove     iob            False              200           25            False  53.0750
# Word2Vec  iob            False              100           50            False  52.8250
#                                             200           50            True   48.0000
#           iobes          False              200           50            True   48.7975
#                                             100           50            True   47.5950
#           iob            True               100           25            True   47.9875
# Glove     iobes          True               200           50            False  52.5175
# Word2Vec  iobes          True               200           50            True   47.9775
#           iob            False              100           50            True   48.2175
#           iobes          True               100           25            True   47.5475
#           iob            True               200           25            True   47.8150
#                                             100           50            True   47.6000
#           iobes          False              200           25            True   46.5800
#                                             100           25            True   47.3250
#           iob            True               200           50            True   47.2500
# Glove     iobes          True               200           25            False  53.6325
# Word2Vec  iobes          True               200           25            True   46.2025
# Glove     iobes          False              200           25            False  53.4200
# FastText  iobes          False              100           25            False  31.6250
# Word2Vec  iob            True               200           50            False  52.2950
#           iobes          True               200           50            False  52.4575
# Wang2Vec  iob            True               200           50            False  40.4450
# Word2Vec  iob            False              200           25            True   46.1550
# FastText  iob            False              200           25            False  53.7700
# Wang2Vec  iob            False              200           50            True   12.5800
#
#                                                                                   50%  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   67.105
#           iobes          True               200           25            True   66.845
#           iob            True               100           50            True   66.755
#           iobes          True               100           25            True   66.440
#                                                           50            True   66.630
#                                             200           50            True   66.460
# FastText  iob            True               100           25            True   65.780
#                          False              100           25            True   65.140
#           iobes          True               200           25            True   64.425
#           iob            False              200           50            True   64.765
#           iobes          False              100           25            True   65.670
# Wang2Vec  iob            True               100           25            True   66.830
# FastText  iob            True               200           50            True   64.360
#           iobes          True               100           25            True   64.985
# Glove     iob            True               100           50            True   62.900
# Wang2Vec  iob            True               200           50            True   66.570
# Glove     iobes          True               100           25            True   62.785
#           iob            False              100           50            True   62.785
#                                             200           25            True   62.285
#                          True               200           25            True   62.145
#           iobes          True               200           50            True   62.650
# FastText  iob            True               100           50            True   65.595
# Wang2Vec  iob            True               200           25            True   66.070
# Glove     iobes          True               100           50            True   62.305
# Wang2Vec  iob            False              200           25            True   66.250
# FastText  iob            True               200           25            True   65.230
# Wang2Vec  iobes          False              200           50            True   66.175
# FastText  iobes          False              100           50            True   64.390
# Wang2Vec  iobes          False              100           25            True   66.335
# Glove     iobes          False              200           50            True   63.225
# ...                                                                               ...
# FastText  iobes          False              200           50            False  56.490
#           iob            False              200           50            False  56.090
# Wang2Vec  iobes          False              100           25            False  56.990
# Word2Vec  iob            False              100           25            True   50.125
#           iobes          True               100           50            True   49.285
# Glove     iob            False              200           25            False  54.010
# Word2Vec  iob            False              100           50            False  55.075
#                                             200           50            True   48.990
#           iobes          False              200           50            True   49.225
#                                             100           50            True   49.685
#           iob            True               100           25            True   49.860
# Glove     iobes          True               200           50            False  54.760
# Word2Vec  iobes          True               200           50            True   49.010
#           iob            False              100           50            True   49.380
#           iobes          True               100           25            True   48.825
#           iob            True               200           25            True   48.290
#                                             100           50            True   48.825
#           iobes          False              200           25            True   48.545
#                                             100           25            True   48.005
#           iob            True               200           50            True   48.515
# Glove     iobes          True               200           25            False  55.170
# Word2Vec  iobes          True               200           25            True   48.105
# Glove     iobes          False              200           25            False  54.910
# FastText  iobes          False              100           25            False  55.400
# Word2Vec  iob            True               200           50            False  54.070
#           iobes          True               200           50            False  53.595
# Wang2Vec  iob            True               200           50            False  55.125
# Word2Vec  iob            False              200           25            True   47.660
# FastText  iob            False              200           25            False  55.145
# Wang2Vec  iob            False              200           50            True   65.570
#
#                                                                                    75%  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   67.4925
#           iobes          True               200           25            True   67.2000
#           iob            True               100           50            True   67.2925
#           iobes          True               100           25            True   67.2775
#                                                           50            True   66.7175
#                                             200           50            True   66.6125
# FastText  iob            True               100           25            True   66.1875
#                          False              100           25            True   65.7100
#           iobes          True               200           25            True   65.3800
#           iob            False              200           50            True   65.0975
#           iobes          False              100           25            True   65.9750
# Wang2Vec  iob            True               100           25            True   67.7900
# FastText  iob            True               200           50            True   65.0100
#           iobes          True               100           25            True   65.5475
# Glove     iob            True               100           50            True   63.4800
# Wang2Vec  iob            True               200           50            True   66.7950
# Glove     iobes          True               100           25            True   63.2850
#           iob            False              100           50            True   63.4675
#                                             200           25            True   62.9425
#                          True               200           25            True   62.6900
#           iobes          True               200           50            True   63.4100
# FastText  iob            True               100           50            True   66.5450
# Wang2Vec  iob            True               200           25            True   66.4150
# Glove     iobes          True               100           50            True   62.7200
# Wang2Vec  iob            False              200           25            True   66.4775
# FastText  iob            True               200           25            True   65.6875
# Wang2Vec  iobes          False              200           50            True   66.7200
# FastText  iobes          False              100           50            True   65.6600
# Wang2Vec  iobes          False              100           25            True   66.5950
# Glove     iobes          False              200           50            True   63.3725
# ...                                                                                ...
# FastText  iobes          False              200           50            False  56.8675
#           iob            False              200           50            False  56.4650
# Wang2Vec  iobes          False              100           25            False  57.4550
# Word2Vec  iob            False              100           25            True   50.7925
#           iobes          True               100           50            True   50.2425
# Glove     iob            False              200           25            False  54.5300
# Word2Vec  iob            False              100           50            False  56.1125
#                                             200           50            True   50.2900
#           iobes          False              200           50            True   50.0500
#                                             100           50            True   49.8950
#           iob            True               100           25            True   50.2625
# Glove     iobes          True               200           50            False  55.9425
# Word2Vec  iobes          True               200           50            True   50.0975
#           iob            False              100           50            True   50.1675
#           iobes          True               100           25            True   49.4350
#           iob            True               200           25            True   49.3700
#                                             100           50            True   49.4825
#           iobes          False              200           25            True   49.7625
#                                             100           25            True   49.4400
#           iob            True               200           50            True   49.4850
# Glove     iobes          True               200           25            False  55.9925
# Word2Vec  iobes          True               200           25            True   48.7625
# Glove     iobes          False              200           25            False  55.7450
# FastText  iobes          False              100           25            False  56.2350
# Word2Vec  iob            True               200           50            False  56.0000
#           iobes          True               200           50            False  54.0550
# Wang2Vec  iob            True               200           50            False  56.7650
# Word2Vec  iob            False              200           25            True   49.1600
# FastText  iob            False              200           25            False  56.1425
# Wang2Vec  iob            False              200           50            True   67.2125
#
#                                                                                  max
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   67.69
#           iobes          True               200           25            True   67.99
#           iob            True               100           50            True   67.64
#           iobes          True               100           25            True   67.87
#                                                           50            True   67.79
#                                             200           50            True   66.78
# FastText  iob            True               100           25            True   66.90
#                          False              100           25            True   66.78
#           iobes          True               200           25            True   66.42
#           iob            False              200           50            True   65.59
#           iobes          False              100           25            True   66.42
# Wang2Vec  iob            True               100           25            True   68.26
# FastText  iob            True               200           50            True   66.07
#           iobes          True               100           25            True   67.05
# Glove     iob            True               100           50            True   64.89
# Wang2Vec  iob            True               200           50            True   67.22
# Glove     iobes          True               100           25            True   63.60
#           iob            False              100           50            True   64.30
#                                             200           25            True   63.77
#                          True               200           25            True   63.39
#           iobes          True               200           50            True   64.03
# FastText  iob            True               100           50            True   66.86
# Wang2Vec  iob            True               200           25            True   67.57
# Glove     iobes          True               100           50            True   64.45
# Wang2Vec  iob            False              200           25            True   66.93
# FastText  iob            True               200           25            True   66.02
# Wang2Vec  iobes          False              200           50            True   67.94
# FastText  iobes          False              100           50            True   66.43
# Wang2Vec  iobes          False              100           25            True   66.92
# Glove     iobes          False              200           50            True   64.44
# ...                                                                              ...
# FastText  iobes          False              200           50            False  57.16
#           iob            False              200           50            False  56.98
# Wang2Vec  iobes          False              100           25            False  58.52
# Word2Vec  iob            False              100           25            True   51.41
#           iobes          True               100           50            True   51.09
# Glove     iob            False              200           25            False  55.36
# Word2Vec  iob            False              100           50            False  56.92
#                                             200           50            True   52.42
#           iobes          False              200           50            True   51.18
#                                             100           50            True   52.30
#           iob            True               100           25            True   50.55
# Glove     iobes          True               200           50            False  56.96
# Word2Vec  iobes          True               200           50            True   50.94
#           iob            False              100           50            True   51.92
#           iobes          True               100           25            True   50.18
#           iob            True               200           25            True   51.87
#                                             100           50            True   51.56
#           iobes          False              200           25            True   50.50
#                                             100           25            True   51.53
#           iob            True               200           50            True   52.18
# Glove     iobes          True               200           25            False  56.44
# Word2Vec  iobes          True               200           25            True   49.57
# Glove     iobes          False              200           25            False  56.34
# FastText  iobes          False              100           25            False  58.10
# Word2Vec  iob            True               200           50            False  56.46
#           iobes          True               200           50            False  55.49
# Wang2Vec  iob            True               200           50            False  58.05
# Word2Vec  iob            False              200           25            True   51.71
# FastText  iob            False              200           25            False  56.73
# Wang2Vec  iob            False              200           50            True   68.07
#
# [128 rows x 8 columns]

# %%
training_data_df.groupby([TRAINING_ROUND]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                 count       mean        std   min      25%     50%      75%  \
# Training_Round
# 0               128.0  56.230312  10.374244  1.88  54.3975  56.430  63.1550
# 2               128.0  56.145391  10.862623  0.00  54.5500  56.325  64.0025
# 9               128.0  56.042891  10.250838  0.00  54.0250  56.245  63.0600
# 6               128.0  55.825156  11.313928  0.00  53.8575  56.420  63.2250
# 1               128.0  55.576953  11.572404  0.00  53.7450  55.715  63.2025
# 8               128.0  55.066484  12.006276  1.17  52.7150  55.855  63.1400
# 4               128.0  54.720625  12.887910  1.66  53.3000  56.165  63.1575
# 3               128.0  54.697266  12.825114  0.19  53.6200  56.070  63.5250
# 7               128.0  53.865234  13.735734  1.01  52.6450  55.945  62.3050
# 5               128.0  53.746797  14.083934  0.55  52.6675  55.750  63.2650
#
#                   max
# Training_Round
# 0               67.57
# 2               68.07
# 9               67.87
# 6               67.74
# 1               67.99
# 8               67.73
# 4               68.26
# 3               67.79
# 7               67.53
# 5               67.86

# %%
import pandas
import researchpy as rp
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

# %%
rp.summary_cont(training_data_df[F1_SCORE])
# Out:
#    Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0  F1_Score  1280.0  55.191711  12.04886  0.336776  54.531017  55.852405

# %%
rp.summary_cont(training_data_df.groupby(EMBEDDING))[F1_SCORE]
# Out:
#              N       Mean         SD        SE  95% Conf.   Interval
# Embedding
# FastText   320  56.529375  14.100258  0.788228  54.984447  58.074303
# Glove      320  56.169750  11.123950  0.621848  54.950929  57.388571
# Wang2Vec   320  57.490094  13.722370  0.767104  55.986570  58.993617
# Word2Vec   320  50.577625   6.464692  0.361387  49.869306  51.285944

# %%
print(F1_SCORE, EMBEDDING, TAGGING_SCHEME, CAP_DIM, CHAR_DIM, WORD_DIM, LOWER)
# Out:
# F1_Score Embedding Tagging_Scheme Capitalisation_Dim Char_LSTM_Dim Word_LSTM_Dim Lower

# %%
# Fits the model with the interaction term
# This will also automatically include the main effects for each factor
model = ols('F1_Score ~ C(Embedding)*C(Tagging_Scheme)*C(Capitalisation_Dim)*C(Char_LSTM_Dim)*C(Word_LSTM_Dim)*C(Lower)', training_data_df).fit()

# Seeing if the overall model is significant
print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
# Out:
# Overall model F( 127, 1152) =  2.483, p =  0.0000

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               F1_Score   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     2.483
# Date:                Wed, 03 Apr 2019   Prob (F-statistic):           3.35e-15
# Time:                        22:34:41   Log-Likelihood:                -4846.8
# No. Observations:                1280   AIC:                             9950.
# Df Residuals:                    1152   BIC:                         1.061e+04
# Df Model:                         127
# Covariance Type:            nonrobust
# =====================================================================================================================================================================================================================
#                                                                                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                                                            56.7950      3.557     15.966      0.000      49.816      63.774
# C(Embedding)[T.Glove]                                                                                                                                -1.1490      5.031     -0.228      0.819     -11.019       8.721
# C(Embedding)[T.Wang2Vec]                                                                                                                             -1.1730      5.031     -0.233      0.816     -11.043       8.697
# C(Embedding)[T.Word2Vec]                                                                                                                             -5.2860      5.031     -1.051      0.294     -15.156       4.584
# C(Tagging_Scheme)[T.iobes]                                                                                                                          -10.9430      5.031     -2.175      0.030     -20.813      -1.073
# C(Capitalisation_Dim)[T.True]                                                                                                                        -0.5390      5.031     -0.107      0.915     -10.409       9.331
# C(Char_LSTM_Dim)[T.50]                                                                                                                               -4.2360      5.031     -0.842      0.400     -14.106       5.634
# C(Word_LSTM_Dim)[T.200]                                                                                                                             -12.3290      5.031     -2.451      0.014     -22.199      -2.459
# C(Lower)[T.True]                                                                                                                                      8.4640      5.031      1.682      0.093      -1.406      18.334
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]                                                                                                     10.4120      7.114      1.464      0.144      -3.547      24.371
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]                                                                                                   5.0090      7.114      0.704      0.482      -8.950      18.968
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]                                                                                                  13.5740      7.114      1.908      0.057      -0.385      27.533
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]                                                                                                  -0.3020      7.114     -0.042      0.966     -14.261      13.657
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]                                                                                               -0.1670      7.114     -0.023      0.981     -14.126      13.792
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]                                                                                                3.2920      7.114      0.463      0.644     -10.667      17.251
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                                             10.6290      7.114      1.494      0.135      -3.330      24.588
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]                                                                                                          3.2310      7.114      0.454      0.650     -10.728      17.190
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]                                                                                                       0.9230      7.114      0.130      0.897     -13.036      14.882
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]                                                                                                       1.9680      7.114      0.277      0.782     -11.991      15.927
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                                                     9.3730      7.114      1.317      0.188      -4.586      23.332
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                                                  4.6330      7.114      0.651      0.515      -9.326      18.592
# C(Embedding)[T.Glove]:C(Word_LSTM_Dim)[T.200]                                                                                                         6.1180      7.114      0.860      0.390      -7.841      20.077
# C(Embedding)[T.Wang2Vec]:C(Word_LSTM_Dim)[T.200]                                                                                                     11.9700      7.114      1.683      0.093      -1.989      25.929
# C(Embedding)[T.Word2Vec]:C(Word_LSTM_Dim)[T.200]                                                                                                     14.6190      7.114      2.055      0.040       0.660      28.578
# C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                                                   19.1800      7.114      2.696      0.007       5.221      33.139
# C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                                                 9.1810      7.114      1.290      0.197      -4.778      23.140
# C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                                                        9.7890      7.114      1.376      0.169      -4.170      23.748
# C(Embedding)[T.Glove]:C(Lower)[T.True]                                                                                                               -6.3150      7.114     -0.888      0.375     -20.274       7.644
# C(Embedding)[T.Wang2Vec]:C(Lower)[T.True]                                                                                                           -10.5970      7.114     -1.490      0.137     -24.556       3.362
# C(Embedding)[T.Word2Vec]:C(Lower)[T.True]                                                                                                           -10.3360      7.114     -1.453      0.147     -24.295       3.623
# C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                                          10.0520      7.114      1.413      0.158      -3.907      24.011
# C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                                                        1.1160      7.114      0.157      0.875     -12.843      15.075
# C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                                              -3.9880      7.114     -0.561      0.575     -17.947       9.971
# C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                                              3.1990      7.114      0.450      0.653     -10.760      17.158
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                       -8.9920     10.061     -0.894      0.372     -28.732      10.748
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                    -7.7650     10.061     -0.772      0.440     -27.505      11.975
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                   -13.2900     10.061     -1.321      0.187     -33.030       6.450
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                             -10.7890     10.061     -1.072      0.284     -30.529       8.951
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                           -0.0580     10.061     -0.006      0.995     -19.798      19.682
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                           -5.6760     10.061     -0.564      0.573     -25.416      14.064
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                           -5.9440     10.061     -0.591      0.555     -25.684      13.796
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                        -0.3530     10.061     -0.035      0.972     -20.093      19.387
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                        -1.5980     10.061     -0.159      0.874     -21.338      18.142
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                      -9.0200     10.061     -0.897      0.370     -28.760      10.720
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                            -21.3580     10.061     -2.123      0.034     -41.098      -1.618
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                         -16.9050     10.061     -1.680      0.093     -36.645       2.835
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                         -21.9020     10.061     -2.177      0.030     -41.642      -2.162
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                          -3.5230     10.061     -0.350      0.726     -23.263      16.217
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                       -7.8370     10.061     -0.779      0.436     -27.577      11.903
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                      -12.2730     10.061     -1.220      0.223     -32.013       7.467
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                    -20.9120     10.061     -2.078      0.038     -40.652      -1.172
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                                 -4.1660     10.061     -0.414      0.679     -23.906      15.574
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                              -6.1210     10.061     -0.608      0.543     -25.861      13.619
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                              -7.2750     10.061     -0.723      0.470     -27.015      12.465
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                           -16.9050     10.061     -1.680      0.093     -36.645       2.835
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                         -8.2280     10.061     -0.818      0.414     -27.968      11.512
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                   -11.8820     10.061     -1.181      0.238     -31.622       7.858
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                  2.1840     10.061      0.217      0.828     -17.556      21.924
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                -14.3820     10.061     -1.429      0.153     -34.122       5.358
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                                 -1.0400     10.061     -0.103      0.918     -20.780      18.700
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                              10.0510     10.061      0.999      0.318      -9.689      29.791
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                              -4.4740     10.061     -0.445      0.657     -24.214      15.266
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                           -12.2640     10.061     -1.219      0.223     -32.004       7.476
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                         9.7490     10.061      0.969      0.333      -9.991      29.489
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                     20.7130     10.061      2.059      0.040       0.973      40.453
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                      5.2980     10.061      0.527      0.599     -14.442      25.038
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                   -5.6450     10.061     -0.561      0.575     -25.385      14.095
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                -0.7020     10.061     -0.070      0.944     -20.442      19.038
# C(Embedding)[T.Glove]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                        7.4010     10.061      0.736      0.462     -12.339      27.141
# C(Embedding)[T.Wang2Vec]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                     3.9040     10.061      0.388      0.698     -15.836      23.644
# C(Embedding)[T.Word2Vec]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                   -10.0350     10.061     -0.997      0.319     -29.775       9.705
# C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                 -15.7610     10.061     -1.567      0.118     -35.501       3.979
# C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                               -5.6850     10.061     -0.565      0.572     -25.425      14.055
# C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                       6.9400     10.061      0.690      0.490     -12.800      26.680
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                12.0280     14.229      0.845      0.398     -15.889      39.945
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                              2.3830     14.229      0.167      0.867     -25.534      30.300
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                              4.8150     14.229      0.338      0.735     -23.102      32.732
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                               15.4180     14.229      1.084      0.279     -12.499      43.335
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                            21.7420     14.229      1.528      0.127      -6.175      49.659
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                            24.7500     14.229      1.739      0.082      -3.167      52.667
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                      22.0600     14.229      1.550      0.121      -5.857      49.977
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                    9.8770     14.229      0.694      0.488     -18.040      37.794
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                   13.0760     14.229      0.919      0.358     -14.841      40.993
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                    5.3930     14.229      0.379      0.705     -22.524      33.310
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                -6.6530     14.229     -0.468      0.640     -34.570      21.264
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                -2.6980     14.229     -0.190      0.850     -30.615      25.219
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                              18.0570     14.229      1.269      0.205      -9.860      45.974
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                      18.5710     14.229      1.305      0.192      -9.346      46.488
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                    5.6980     14.229      0.400      0.689     -22.219      33.615
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                   16.1900     14.229      1.138      0.255     -11.727      44.107
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                              3.9210     14.229      0.276      0.783     -23.996      31.838
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                         -20.9870     14.229     -1.475      0.140     -48.904       6.930
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                           4.1040     14.229      0.288      0.773     -23.813      32.021
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                           3.2220     14.229      0.226      0.821     -24.695      31.139
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                      -14.2720     14.229     -1.003      0.316     -42.189      13.645
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                       -2.0030     14.229     -0.141      0.888     -29.920      25.914
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                     -0.8460     14.229     -0.059      0.953     -28.763      27.071
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                            14.7060     14.229      1.034      0.302     -13.211      42.623
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                          6.3920     14.229      0.449      0.653     -21.525      34.309
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                         23.1600     14.229      1.628      0.104      -4.757      51.077
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                          0.7240     14.229      0.051      0.959     -27.193      28.641
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                      -4.9330     14.229     -0.347      0.729     -32.850      22.984
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                      12.7250     14.229      0.894      0.371     -15.192      40.642
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                    24.5460     14.229      1.725      0.085      -3.371      52.463
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                               -23.0320     14.229     -1.619      0.106     -50.949       4.885
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                            -41.0860     14.229     -2.888      0.004     -69.003     -13.169
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                             -4.4340     14.229     -0.312      0.755     -32.351      23.483
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                           -2.4520     14.229     -0.172      0.863     -30.369      25.465
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                        -1.0170     14.229     -0.071      0.943     -28.934      26.900
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                       -23.9540     20.123     -1.190      0.234     -63.435      15.527
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                     -5.0060     20.123     -0.249      0.804     -44.487      34.475
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                    -14.8290     20.123     -0.737      0.461     -54.310      24.652
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                               -6.6040     20.123     -0.328      0.743     -46.085      32.877
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                            21.9780     20.123      1.092      0.275     -17.503      61.459
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                             4.4610     20.123      0.222      0.825     -35.020      43.942
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                             -27.1020     20.123     -1.347      0.178     -66.583      12.379
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                          -15.5140     20.123     -0.771      0.441     -54.995      23.967
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                          -33.7170     20.123     -1.676      0.094     -73.198       5.764
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                      9.3240     20.123      0.463      0.643     -30.157      48.805
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                  44.2940     20.123      2.201      0.028       4.813      83.775
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                   1.1310     20.123      0.056      0.955     -38.350      40.612
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                   4.1660     20.123      0.207      0.836     -35.315      43.647
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                               44.9320     20.123      2.233      0.026       5.451      84.413
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                6.9660     20.123      0.346      0.729     -32.515      46.447
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                             -4.3320     20.123     -0.215      0.830     -43.813      35.149
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]       15.6040     28.458      0.548      0.584     -40.230      71.438
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]   -42.4450     28.458     -1.492      0.136     -98.279      13.389
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]     6.9160     28.458      0.243      0.808     -48.918      62.750
# ==============================================================================
# Omnibus:                      910.596   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10835.528
# Skew:                          -3.306   Prob(JB):                         0.00
# Kurtosis:                      15.628   Cond. No.                         589.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res = sm.stats.anova_lm(model, typ= 2)

# %%
res
# Out:
#                                                            sum_sq      df  \
# C(Embedding)                                          9381.842606     3.0
# C(Tagging_Scheme)                                       24.889594     1.0
# C(Capitalisation_Dim)                                 1049.456391     1.0
# C(Char_LSTM_Dim)                                        22.026381     1.0
# C(Word_LSTM_Dim)                                       880.514263     1.0
# C(Lower)                                              5941.292294     1.0
# C(Embedding):C(Tagging_Scheme)                         543.364110     3.0
# C(Embedding):C(Capitalisation_Dim)                     892.327178     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim)                  4.078174     1.0
# C(Embedding):C(Char_LSTM_Dim)                          242.907520     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim)                       8.047047     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim)                 105.369189     1.0
# C(Embedding):C(Word_LSTM_Dim)                           38.957008     3.0
# C(Tagging_Scheme):C(Word_LSTM_Dim)                      85.723877     1.0
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                  29.043513     1.0
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                       17.170361     1.0
# C(Embedding):C(Lower)                                 7934.595746     3.0
# C(Tagging_Scheme):C(Lower)                               3.358926     1.0
# C(Capitalisation_Dim):C(Lower)                         287.120948     1.0
# C(Char_LSTM_Dim):C(Lower)                               33.777254     1.0
# C(Word_LSTM_Dim):C(Lower)                               24.318394     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     101.107864     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)        371.481028     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...      46.242778     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...      17.318931     1.0
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)        487.945958     3.0
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     198.151868     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...      43.604736     1.0
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)         940.083271     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...      28.438144     1.0
# ...                                                           ...     ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)                 692.052780     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)            250.605451     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)        102.361157     1.0
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                 246.847777     3.0
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)             35.069451     1.0
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)        223.989611     1.0
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)               3.348688     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...       5.264313     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     208.617875     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    1253.600250     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     148.478505     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...      30.089111     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     160.833685     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     337.699542     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     193.829893     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...       1.479000     1.0
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...     344.648250     3.0
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     188.991394     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...       3.249188     1.0
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...     616.299100     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...     216.391534     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...     347.976103     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     444.768774     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...      50.437476     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     969.923979     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     431.494080     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     353.370143     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     108.420782     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     623.013278     3.0
# Residual                                            145770.118750  1152.0
#
#                                                             F        PR(>F)
# C(Embedding)                                        24.714445  1.683918e-15
# C(Tagging_Scheme)                                    0.196699  6.574820e-01
# C(Capitalisation_Dim)                                8.293701  4.051909e-03
# C(Char_LSTM_Dim)                                     0.174071  6.765963e-01
# C(Word_LSTM_Dim)                                     6.958576  8.454233e-03
# C(Lower)                                            46.953167  1.181543e-11
# C(Embedding):C(Tagging_Scheme)                       1.431376  2.319975e-01
# C(Embedding):C(Capitalisation_Dim)                   2.350644  7.083815e-02
# C(Tagging_Scheme):C(Capitalisation_Dim)              0.032229  8.575571e-01
# C(Embedding):C(Char_LSTM_Dim)                        0.639888  5.894093e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim)                   0.063595  8.009471e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim)               0.832717  3.616789e-01
# C(Embedding):C(Word_LSTM_Dim)                        0.102624  9.585238e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim)                   0.677463  4.106319e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim)               0.229527  6.319660e-01
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                    0.135695  7.126667e-01
# C(Embedding):C(Lower)                               20.901985  3.446383e-13
# C(Tagging_Scheme):C(Lower)                           0.026545  8.706047e-01
# C(Capitalisation_Dim):C(Lower)                       2.269075  1.322528e-01
# C(Char_LSTM_Dim):C(Lower)                            0.266937  6.054933e-01
# C(Word_LSTM_Dim):C(Lower)                            0.192185  6.611867e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.266347  8.496798e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)      0.978587  4.020241e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.121817  9.472633e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.136869  7.114817e-01
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)      1.285389  2.779643e-01
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...   0.521988  6.672191e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...   0.344602  5.572999e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)       2.476447  5.995137e-02
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...   0.224743  6.355397e-01
# ...                                                       ...           ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)               1.823064  1.411348e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)          1.980498  1.596077e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)      0.808945  3.686202e-01
# C(Embedding):C(Word_LSTM_Dim):C(Lower)               0.650267  5.828495e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)          0.277149  5.986775e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)      1.770157  1.836259e-01
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)           0.026464  8.708003e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.013868  9.977697e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.549559  6.485080e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   3.302340  1.971368e-02
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.391135  7.594112e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.237790  6.258998e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.423682  7.360555e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   0.889597  4.458885e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.510603  6.750296e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.011688  9.139252e-01
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...   0.907902  4.365572e-01
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...   0.497857  6.838287e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...   0.025678  8.727177e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...   1.623507  1.821575e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...   1.710111  1.912319e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...   2.750004  9.752639e-02
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   1.171648  3.193236e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.132867  9.405101e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   2.555056  5.399358e-02
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   1.136678  3.330961e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.930878  4.250722e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.856834  3.548202e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   1.641194  1.781113e-01
# Residual                                                  NaN           NaN
#
# [64 rows x 4 columns]

# %%
# Calculating effect size
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'mean_sq', 'df', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

anova_table(res)
# Out:
#                                                            sum_sq  \
# C(Embedding)                                          9381.842606
# C(Tagging_Scheme)                                       24.889594
# C(Capitalisation_Dim)                                 1049.456391
# C(Char_LSTM_Dim)                                        22.026381
# C(Word_LSTM_Dim)                                       880.514263
# C(Lower)                                              5941.292294
# C(Embedding):C(Tagging_Scheme)                         543.364110
# C(Embedding):C(Capitalisation_Dim)                     892.327178
# C(Tagging_Scheme):C(Capitalisation_Dim)                  4.078174
# C(Embedding):C(Char_LSTM_Dim)                          242.907520
# C(Tagging_Scheme):C(Char_LSTM_Dim)                       8.047047
# C(Capitalisation_Dim):C(Char_LSTM_Dim)                 105.369189
# C(Embedding):C(Word_LSTM_Dim)                           38.957008
# C(Tagging_Scheme):C(Word_LSTM_Dim)                      85.723877
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                  29.043513
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                       17.170361
# C(Embedding):C(Lower)                                 7934.595746
# C(Tagging_Scheme):C(Lower)                               3.358926
# C(Capitalisation_Dim):C(Lower)                         287.120948
# C(Char_LSTM_Dim):C(Lower)                               33.777254
# C(Word_LSTM_Dim):C(Lower)                               24.318394
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     101.107864
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)        371.481028
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...      46.242778
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...      17.318931
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)        487.945958
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     198.151868
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...      43.604736
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)         940.083271
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...      28.438144
# ...                                                           ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)                 692.052780
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)            250.605451
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)        102.361157
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                 246.847777
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)             35.069451
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)        223.989611
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)               3.348688
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...       5.264313
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     208.617875
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    1253.600250
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     148.478505
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...      30.089111
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     160.833685
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     337.699542
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     193.829893
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...       1.479000
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...     344.648250
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     188.991394
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...       3.249188
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...     616.299100
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...     216.391534
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...     347.976103
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     444.768774
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...      50.437476
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     969.923979
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     431.494080
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     353.370143
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     108.420782
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     623.013278
# Residual                                            145770.118750
#
#                                                         mean_sq      df  \
# C(Embedding)                                        3127.280869     3.0
# C(Tagging_Scheme)                                     24.889594     1.0
# C(Capitalisation_Dim)                               1049.456391     1.0
# C(Char_LSTM_Dim)                                      22.026381     1.0
# C(Word_LSTM_Dim)                                     880.514263     1.0
# C(Lower)                                            5941.292294     1.0
# C(Embedding):C(Tagging_Scheme)                       181.121370     3.0
# C(Embedding):C(Capitalisation_Dim)                   297.442393     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim)                4.078174     1.0
# C(Embedding):C(Char_LSTM_Dim)                         80.969173     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim)                     8.047047     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim)               105.369189     1.0
# C(Embedding):C(Word_LSTM_Dim)                         12.985669     3.0
# C(Tagging_Scheme):C(Word_LSTM_Dim)                    85.723877     1.0
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                29.043513     1.0
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                     17.170361     1.0
# C(Embedding):C(Lower)                               2644.865249     3.0
# C(Tagging_Scheme):C(Lower)                             3.358926     1.0
# C(Capitalisation_Dim):C(Lower)                       287.120948     1.0
# C(Char_LSTM_Dim):C(Lower)                             33.777254     1.0
# C(Word_LSTM_Dim):C(Lower)                             24.318394     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    33.702621     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)      123.827009     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    15.414259     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    17.318931     1.0
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)      162.648653     3.0
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...    66.050623     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...    43.604736     1.0
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)       313.361090     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...    28.438144     1.0
# ...                                                         ...     ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)               230.684260     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)          250.605451     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)      102.361157     1.0
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                82.282592     3.0
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)           35.069451     1.0
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)      223.989611     1.0
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)             3.348688     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     1.754771     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    69.539292     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   417.866750     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    49.492835     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    30.089111     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    53.611228     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   112.566514     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    64.609964     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     1.479000     1.0
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...   114.882750     3.0
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...    62.997131     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...     3.249188     1.0
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...   205.433033     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...   216.391534     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...   347.976103     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   148.256258     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    16.812492     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   323.307993     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   143.831360     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   117.790048     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   108.420782     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   207.671093     3.0
# Residual                                             126.536561  1152.0
#
#                                                             F        PR(>F)  \
# C(Embedding)                                        24.714445  1.683918e-15
# C(Tagging_Scheme)                                    0.196699  6.574820e-01
# C(Capitalisation_Dim)                                8.293701  4.051909e-03
# C(Char_LSTM_Dim)                                     0.174071  6.765963e-01
# C(Word_LSTM_Dim)                                     6.958576  8.454233e-03
# C(Lower)                                            46.953167  1.181543e-11
# C(Embedding):C(Tagging_Scheme)                       1.431376  2.319975e-01
# C(Embedding):C(Capitalisation_Dim)                   2.350644  7.083815e-02
# C(Tagging_Scheme):C(Capitalisation_Dim)              0.032229  8.575571e-01
# C(Embedding):C(Char_LSTM_Dim)                        0.639888  5.894093e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim)                   0.063595  8.009471e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim)               0.832717  3.616789e-01
# C(Embedding):C(Word_LSTM_Dim)                        0.102624  9.585238e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim)                   0.677463  4.106319e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim)               0.229527  6.319660e-01
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                    0.135695  7.126667e-01
# C(Embedding):C(Lower)                               20.901985  3.446383e-13
# C(Tagging_Scheme):C(Lower)                           0.026545  8.706047e-01
# C(Capitalisation_Dim):C(Lower)                       2.269075  1.322528e-01
# C(Char_LSTM_Dim):C(Lower)                            0.266937  6.054933e-01
# C(Word_LSTM_Dim):C(Lower)                            0.192185  6.611867e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.266347  8.496798e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)      0.978587  4.020241e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.121817  9.472633e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.136869  7.114817e-01
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)      1.285389  2.779643e-01
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...   0.521988  6.672191e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...   0.344602  5.572999e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)       2.476447  5.995137e-02
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...   0.224743  6.355397e-01
# ...                                                       ...           ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)               1.823064  1.411348e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)          1.980498  1.596077e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)      0.808945  3.686202e-01
# C(Embedding):C(Word_LSTM_Dim):C(Lower)               0.650267  5.828495e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)          0.277149  5.986775e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)      1.770157  1.836259e-01
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)           0.026464  8.708003e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.013868  9.977697e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.549559  6.485080e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   3.302340  1.971368e-02
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.391135  7.594112e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.237790  6.258998e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.423682  7.360555e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   0.889597  4.458885e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.510603  6.750296e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.011688  9.139252e-01
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...   0.907902  4.365572e-01
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...   0.497857  6.838287e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...   0.025678  8.727177e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...   1.623507  1.821575e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...   1.710111  1.912319e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...   2.750004  9.752639e-02
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   1.171648  3.193236e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   0.132867  9.405101e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   2.555056  5.399358e-02
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...   1.136678  3.330961e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...   0.930878  4.250722e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...   0.856834  3.548202e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...   1.641194  1.781113e-01
# Residual                                                  NaN           NaN
#
#                                                       eta_sq  omega_sq
# C(Embedding)                                        0.050527  0.048450
# C(Tagging_Scheme)                                   0.000134 -0.000547
# C(Capitalisation_Dim)                               0.005652  0.004967
# C(Char_LSTM_Dim)                                    0.000119 -0.000562
# C(Word_LSTM_Dim)                                    0.004742  0.004058
# C(Lower)                                            0.031998  0.031295
# C(Embedding):C(Tagging_Scheme)                      0.002926  0.000881
# C(Embedding):C(Capitalisation_Dim)                  0.004806  0.002759
# C(Tagging_Scheme):C(Capitalisation_Dim)             0.000022 -0.000659
# C(Embedding):C(Char_LSTM_Dim)                       0.001308 -0.000736
# C(Tagging_Scheme):C(Char_LSTM_Dim)                  0.000043 -0.000638
# C(Capitalisation_Dim):C(Char_LSTM_Dim)              0.000567 -0.000114
# C(Embedding):C(Word_LSTM_Dim)                       0.000210 -0.001833
# C(Tagging_Scheme):C(Word_LSTM_Dim)                  0.000462 -0.000220
# C(Capitalisation_Dim):C(Word_LSTM_Dim)              0.000156 -0.000525
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                   0.000092 -0.000589
# C(Embedding):C(Lower)                               0.042733  0.040661
# C(Tagging_Scheme):C(Lower)                          0.000018 -0.000663
# C(Capitalisation_Dim):C(Lower)                      0.001546  0.000864
# C(Char_LSTM_Dim):C(Lower)                           0.000182 -0.000499
# C(Word_LSTM_Dim):C(Lower)                           0.000131 -0.000550
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.000545 -0.001499
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)     0.002001 -0.000044
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  0.000249 -0.001794
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  0.000093 -0.000588
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)     0.002628  0.000583
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...  0.001067 -0.000977
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...  0.000235 -0.000446
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)      0.005063  0.003016
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...  0.000153 -0.000528
# ...                                                      ...       ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)              0.003727  0.001682
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)         0.001350  0.000668
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)     0.000551 -0.000130
# C(Embedding):C(Word_LSTM_Dim):C(Lower)              0.001329 -0.000715
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)         0.000189 -0.000492
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)     0.001206  0.000524
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)          0.000018 -0.000663
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.000028 -0.002015
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.001124 -0.000920
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  0.006751  0.004704
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  0.000800 -0.001244
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  0.000162 -0.000519
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.000866 -0.001177
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  0.001819 -0.000226
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  0.001044 -0.001000
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  0.000008 -0.000673
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...  0.001856 -0.000188
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...  0.001018 -0.001026
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...  0.000017 -0.000664
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...  0.003319  0.001274
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...  0.001165  0.000484
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...  0.001874  0.001192
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.002395  0.000351
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.000272 -0.001772
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.005224  0.003177
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  0.002324  0.000279
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  0.001903 -0.000141
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  0.000584 -0.000097
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  0.003355  0.001310
# Residual                                                 NaN       NaN
#
# [64 rows x 7 columns]

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[EMBEDDING])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# =================================================
#  group1   group2  meandiff  lower   upper  reject
# -------------------------------------------------
# FastText  Glove   -0.3596  -2.7501  2.0308 False
# FastText Wang2Vec  0.9607  -1.4297  3.3512 False
# FastText Word2Vec -5.9518  -8.3422 -3.5613  True
#  Glove   Wang2Vec  1.3203  -1.0701  3.7108 False
#  Glove   Word2Vec -5.5921  -7.9826 -3.2017  True
# Wang2Vec Word2Vec -6.9125  -9.3029  -4.522  True
# -------------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[CAP_DIM])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ===========================================
# group1 group2 meandiff lower  upper  reject
# -------------------------------------------
# False   True   1.811   0.4928 3.1291  True
# -------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[LOWER])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ===========================================
# group1 group2 meandiff lower  upper  reject
# -------------------------------------------
# False   True   4.3089  3.0083 5.6095  True
# -------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[TAGGING_SCHEME])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#  iob   iobes  -0.2789  -1.6007 1.0429 False
# --------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[CHAR_DIM])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   25     50   -0.2624  -1.5842 1.0595 False
# --------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[WORD_DIM])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ===========================================
# group1 group2 meandiff  lower  upper reject
# -------------------------------------------
#  100    200   -1.6588  -2.9776 -0.34  True
# -------------------------------------------
