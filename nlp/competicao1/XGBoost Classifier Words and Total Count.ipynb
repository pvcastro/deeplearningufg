# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier
import nltk
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
from nltk.tokenize import word_tokenize
import re
from sklearn.metrics import balanced_accuracy_score, f1_score
from pathlib import Path

# %%
stop_words = [word.strip() for word in open('stopwords-pt.txt', mode='r', encoding='utf8')]

# %%
class TextSelector(BaseEstimator, TransformerMixin):
    def __init__(self, field):
        self.field = field
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.field]
    
class NumberSelector(BaseEstimator, TransformerMixin):
    def __init__(self, field):
        self.field = field
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[[self.field]]
    

def Tokenizer(str_input):
    porter_stemmer=nltk.PorterStemmer()
    words = [porter_stemmer.stem(word) for word in words]
    return words

def get_total_words(row):
    return len(word_tokenize(row['text']))

def write_predictions(predictions, out_path):
    count = 0

    with open(out_path, mode='w', encoding='utf-8') as out_file:
        print('Saving predictions to %s' % out_path)
        out_file.write('id,category\n')
        idx = 0
        for result in predictions:
            count += 1
            out_file.write(str(idx) + ',' + result + '\n')
            idx += 1
            if count % 100 == 0:
                print('Predicted %d sentences' % count)
    out_file.close()
    print('Finished predicting %d sentences' % count)
    print('Results saved in %s' % Path(out_path).absolute())

# %%
stop_words.extend(Tokenizer(' '.join(stop_words)))
stop_words = sorted(set(stop_words))
stop_words
# Out:
# ['a',
#  'acerca',
#  'adeu',
#  'adeus',
#  'agora',
#  'ainda',
#  'al',
#  'alem',
#  'algma',
#  'algmas',
#  'algo',
#  'alguma',
#  'algumas',
#  'algun',
#  'alguns',
#  'ali',
#  'além',
#  'amba',
#  'ambas',
#  'ambo',
#  'ambos',
#  'amo',
#  'ano',
#  'anos',
#  'ant',
#  'antes',
#  'ao',
#  'aond',
#  'aonde',
#  'aos',
#  'ap',
#  'apena',
#  'apenas',
#  'apo',
#  'apoio',
#  'apontar',
#  'apos',
#  'após',
#  'aquel',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aqui',
#  'aquilo',
#  'as',
#  'assim',
#  'at',
#  'atr',
#  'atrav',
#  'através',
#  'atrás',
#  'até',
#  'aí',
#  'baixo',
#  'bastant',
#  'bastante',
#  'bem',
#  'boa',
#  'boas',
#  'bom',
#  'bon',
#  'bons',
#  'breve',
#  'c',
#  'cada',
#  'caminho',
#  'catorz',
#  'catorze',
#  'cedo',
#  'cento',
#  'certament',
#  'certamente',
#  'certeza',
#  'cima',
#  'cinco',
#  'coisa',
#  'com',
#  'como',
#  'comprido',
#  'conhecido',
#  'conselho',
#  'contra',
#  'contudo',
#  'corrent',
#  'corrente',
#  'cuja',
#  'cujas',
#  'cujo',
#  'cujos',
#  'custa',
#  'cá',
#  'd',
#  'da',
#  'daquel',
#  'daquela',
#  'daquelas',
#  'daquele',
#  'daqueles',
#  'dar',
#  'das',
#  'de',
#  'debaixo',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'demai',
#  'demais',
#  'dentro',
#  'depoi',
#  'depois',
#  'desd',
#  'desde',
#  'desligado',
#  'dess',
#  'dessa',
#  'dessas',
#  'desse',
#  'desses',
#  'dest',
#  'desta',
#  'destas',
#  'deste',
#  'destes',
#  'deve',
#  'devem',
#  'dever',
#  'deverá',
#  'dez',
#  'dezanov',
#  'dezanove',
#  'dezassei',
#  'dezasseis',
#  'dezasset',
#  'dezassete',
#  'dezoito',
#  'dia',
#  'diant',
#  'diante',
#  'direita',
#  'dispo',
#  'dispoe',
#  'dispoem',
#  'diversa',
#  'diversas',
#  'diverso',
#  'diversos',
#  'diz',
#  'dizem',
#  'dizer',
#  'do',
#  'doi',
#  'dois',
#  'dos',
#  'doze',
#  'dua',
#  'duas',
#  'durant',
#  'durante',
#  'dá',
#  'dão',
#  'dúvida',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'embora',
#  'enquanto',
#  'ent',
#  'entao',
#  'entr',
#  'entre',
#  'então',
#  'era',
#  'eram',
#  'ess',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'est',
#  'esta',
#  'estado',
#  'estamo',
#  'estamos',
#  'estar',
#  'estará',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamo',
#  'estejamos',
#  'estes',
#  'estev',
#  'esteve',
#  'estiv',
#  'estive',
#  'estivemo',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermo',
#  'estivermos',
#  'estivess',
#  'estivesse',
#  'estivessem',
#  'estivest',
#  'estiveste',
#  'estivestes',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estás',
#  'estávamos',
#  'estão',
#  'eu',
#  'exemplo',
#  'f',
#  'fa',
#  'falta',
#  'far',
#  'fará',
#  'favor',
#  'faz',
#  'faze',
#  'fazei',
#  'fazeis',
#  'fazem',
#  'fazemo',
#  'fazemos',
#  'fazer',
#  'fazes',
#  'fazia',
#  'faço',
#  'fez',
#  'fim',
#  'final',
#  'foi',
#  'fomo',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'forma',
#  'formo',
#  'formos',
#  'foss',
#  'fosse',
#  'fossem',
#  'fost',
#  'foste',
#  'fostes',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'geral',
#  'grand',
#  'grande',
#  'grandes',
#  'grupo',
#  'h',
#  'ha',
#  'haja',
#  'hajam',
#  'hajamo',
#  'hajamos',
#  'havemo',
#  'havemos',
#  'havia',
#  'hei',
#  'hoje',
#  'hora',
#  'horas',
#  'houv',
#  'houve',
#  'houvemo',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremo',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermo',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvess',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'iniciar',
#  'inicio',
#  'ir',
#  'irá',
#  'is',
#  'isso',
#  'ist',
#  'ista',
#  'iste',
#  'isto',
#  'j',
#  'já',
#  'l',
#  'lado',
#  'lhe',
#  'lhes',
#  'ligado',
#  'local',
#  'logo',
#  'long',
#  'longe',
#  'ltimo',
#  'lugar',
#  'lá',
#  'm',
#  'ma',
#  'mai',
#  'maior',
#  'maioria',
#  'maiorias',
#  'mais',
#  'mal',
#  'mas',
#  'me',
#  'mediant',
#  'mediante',
#  'meio',
#  'meno',
#  'menor',
#  'menos',
#  'mero',
#  'mese',
#  'meses',
#  'mesma',
#  'mesmas',
#  'mesmo',
#  'mesmos',
#  'meu',
#  'meus',
#  'mil',
#  'minha',
#  'minhas',
#  'momento',
#  'muito',
#  'muitos',
#  'máximo',
#  'mês',
#  'n',
#  'na',
#  'nada',
#  'nao',
#  'naquel',
#  'naquela',
#  'naquelas',
#  'naquele',
#  'naqueles',
#  'nas',
#  'nem',
#  'nenhuma',
#  'ness',
#  'nessa',
#  'nessas',
#  'nesse',
#  'nesses',
#  'nest',
#  'nesta',
#  'nestas',
#  'neste',
#  'nestes',
#  'nhamo',
#  'no',
#  'noit',
#  'noite',
#  'nome',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'nova',
#  'novas',
#  'nove',
#  'novo',
#  'novos',
#  'num',
#  'numa',
#  'numas',
#  'nun',
#  'nunca',
#  'nuns',
#  'não',
#  'nível',
#  'nós',
#  'número',
#  'o',
#  'obra',
#  'obrigada',
#  'obrigado',
#  'oitava',
#  'oitavo',
#  'oito',
#  'ond',
#  'onde',
#  'ontem',
#  'onz',
#  'onze',
#  'os',
#  'ou',
#  'outra',
#  'outras',
#  'outro',
#  'outros',
#  'p',
#  'para',
#  'parec',
#  'parece',
#  'part',
#  'parte',
#  'partir',
#  'pauca',
#  'paucas',
#  'pegar',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'perant',
#  'perante',
#  'perto',
#  'pessoa',
#  'pessoas',
#  'pode',
#  'podem',
#  'poder',
#  'poderá',
#  'podia',
#  'poi',
#  'pois',
#  'ponto',
#  'pontos',
#  'por',
#  'porqu',
#  'porque',
#  'porquê',
#  'portanto',
#  'posi',
#  'posição',
#  'poss',
#  'possivel',
#  'possivelment',
#  'possivelmente',
#  'posso',
#  'possível',
#  'pouca',
#  'pouco',
#  'poucos',
#  'povo',
#  'pr',
#  'pria',
#  'primeira',
#  'primeiras',
#  'primeiro',
#  'primeiros',
#  'prio',
#  'promeiro',
#  'propio',
#  'propios',
#  'proprio',
#  'própria',
#  'próprias',
#  'próprio',
#  'próprios',
#  'próxima',
#  'próximas',
#  'próximo',
#  'próximos',
#  'puderam',
#  'pôde',
#  'põe',
#  'põem',
#  'qu',
#  'quai',
#  'quais',
#  'qual',
#  'qualquer',
#  'quando',
#  'quanto',
#  'quarta',
#  'quarto',
#  'quatro',
#  'que',
#  'quem',
#  'quer',
#  'querei',
#  'quereis',
#  'querem',
#  'querema',
#  'queremas',
#  'queres',
#  'quero',
#  'quest',
#  'questão',
#  'quieto',
#  'quinta',
#  'quinto',
#  'quinz',
#  'quinze',
#  'quáis',
#  'quê',
#  'ramo',
#  'rea',
#  'rela',
#  'relação',
#  'rio',
#  's',
#  'sabe',
#  'sabem',
#  'saber',
#  'se',
#  'segunda',
#  'segundo',
#  'sei',
#  'seis',
#  'seja',
#  'sejam',
#  'sejamo',
#  'sejamos',
#  'sem',
#  'sempr',
#  'sempre',
#  'sendo',
#  'ser',
#  'serei',
#  'seremo',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'sete',
#  'seu',
#  'seus',
#  'sexta',
#  'sexto',
#  'sim',
#  'sistema',
#  'sob',
#  'sobr',
#  'sobre',
#  'soi',
#  'sois',
#  'soment',
#  'somente',
#  'somo',
#  'somos',
#  'sou',
#  'ssemo',
#  'sua',
#  'suas',
#  'são',
#  'sétima',
#  'sétimo',
#  'só',
#  't',
#  'tal',
#  'talvez',
#  'tamb',
#  'tambem',
#  'também',
#  'tanta',
#  'tantas',
#  'tanto',
#  'tard',
#  'tarde',
#  'te',
#  'tem',
#  'temo',
#  'temos',
#  'tempo',
#  'ten',
#  'tend',
#  'tendes',
#  'tenha',
#  'tenham',
#  'tenhamo',
#  'tenhamos',
#  'tenho',
#  'tens',
#  'tent',
#  'tentar',
#  'tentaram',
#  'tente',
#  'tentei',
#  'ter',
#  'terceira',
#  'terceiro',
#  'terei',
#  'teremo',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tima',
#  'timo',
#  'tinha',
#  'tinham',
#  'tipo',
#  'tiv',
#  'tive',
#  'tivemo',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermo',
#  'tivermos',
#  'tivess',
#  'tivesse',
#  'tivessem',
#  'tivest',
#  'tiveste',
#  'tivestes',
#  'tivéramos',
#  'tivéssemos',
#  'toda',
#  'todas',
#  'todo',
#  'todos',
#  'tr',
#  'trabalhar',
#  'trabalho',
#  'treze',
#  'três',
#  'tu',
#  'tua',
#  'tuas',
#  'tudo',
#  'tão',
#  'tém',
#  'têm',
#  'tínhamos',
#  'um',
#  'uma',
#  'umas',
#  'un',
#  'uns',
#  'usa',
#  'usar',
#  'v',
#  'vai',
#  'vais',
#  'valor',
#  'vamo',
#  'veja',
#  'vel',
#  'vem',
#  'ven',
#  'vens',
#  'ver',
#  'verdad',
#  'verdade',
#  'verdadeiro',
#  'vez',
#  'veze',
#  'vezes',
#  'viagem',
#  'vida',
#  'vindo',
#  'vint',
#  'vinte',
#  'vo',
#  'voc',
#  'você',
#  'vocês',
#  'vos',
#  'vossa',
#  'vossas',
#  'vosso',
#  'vossos',
#  'vários',
#  'vão',
#  'vêm',
#  'vós',
#  'xima',
#  'ximo',
#  'zero',
#  'à',
#  'às',
#  'área',
#  'é',
#  'éramos',
#  'és',
#  'último']

# %%
classifier = Pipeline([
    ('features', FeatureUnion([
        ('text', Pipeline([
            ('colext', TextSelector('text')),
            ('tfidf', TfidfVectorizer(tokenizer=Tokenizer, stop_words=stop_words,
                     min_df=.0025, max_df=0.25, ngram_range=(1,3))),
            ('svd', TruncatedSVD(algorithm='randomized', n_components=300)), #for XGB
        ])),
        ('words', Pipeline([
            ('wordext', NumberSelector('TotalWords')),
            ('wscaler', StandardScaler()),
        ])),
    ])),
    ('clf', XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.1)),
    ])

# %%
train_df = pd.read_csv('train_text_label.csv')
train_df
# Out:
#                                                    text               label
# 0     Casa da Barra Funda tem clima roceiro e receit...              comida
# 1     Professores de SP decidem manter greve; grupo ...            educacao
# 2     Em segunda edição, concurso paga R$ 35 mil par...  empreendedorsocial
# 3     Usar maconha por anos não faz tão mal para a s...    equilibrioesaude
# 4     Baleia-azul percorre 5.200 km e revela a cient...             ciencia
# 5     Líderes inovadores se reunem em rede para comp...  empreendedorsocial
# 6     Conheça Pandora, atração milionária da Disney ...             turismo
# 7     Fiesp organiza quarta edição de maratona hacke...  empreendedorsocial
# 8     Praia do Forte mistura natureza com resorts es...             turismo
# 9     App de agência avisa quando visto e passaporte...             turismo
# 10    App de caronas para viagens não teme comparaçõ...             turismo
# 11    Veja quais são os tipos de veículos que precis...           sobretudo
# 12    Rica em fósseis de dinos, Uberaba deve ter geo...             ciencia
# 13    Yahoo! tem prejuízo de US$ 492 milhões no 2º t...                 tec
# 14    Bazar beneficente tem comida típica síria feit...  empreendedorsocial
# 15    5 lugares para voar de balão no Brasil. As pos...             turismo
# 16    Loja de aplicativos do Google oferece opção pr...                 tec
# 17    Paris proibirá circulação de carros em trecho ...             turismo
# 18    Chinesa ZTE diz que lucro dobrou no ano passad...                 tec
# 19    Gwyneth Paltrow desiste do desafio de passar 7...              comida
# 20    Tema de redação do Enem vazou antes do início ...            educacao
# 21    Planejamento evita aperto no orçamento na hora...            educacao
# 22    Nas mensagens, GIFs valem pelo menos mil palav...                 tec
# 23    ONG arrecada material escolar a 7 mil crianças...  empreendedorsocial
# 24    Educação média não consegue formar quadros téc...            educacao
# 25    Artista plástica ensina a fazer suportes para ...           sobretudo
# 26    Confira o kit de decoração de unhas tetris e o...                 tec
# 27    Ciclo Brilhante quer inspirar 100 mil brasilei...  empreendedorsocial
# 28    Trump diz estar com 'mente aberta' em relação ...            ambiente
# 29    Temida, química exige relações com o cotidiano...            educacao
# ...                                                 ...                 ...
# 7864  Pica-paus se arriscam para manter higiene do n...             ciencia
# 7865  Programa deixa o novo Windows 10 com cara de W...                 tec
# 7866  Brasileiros dão 'jeitinho' para baratear ida a...             turismo
# 7867  Pouco conhecida, ilha de Santa Lúcia tem paisa...             turismo
# 7868  Criado nos EUA, conceito de MBA foi 'tropicali...           sobretudo
# 7869  É preciso abrir mão de espaço e localização na...           sobretudo
# 7870  Não usar azeite para fritar? Veja regras culin...    equilibrioesaude
# 7871  Que navegador para celular usar? Os pontos pos...                 tec
# 7872  FGV Eaesp lança mestrado profissional de suste...  empreendedorsocial
# 7873  Justiça realiza audiência de conciliação entre...            educacao
# 7874  Empreendedores sociais fazem da cidadania o fo...  empreendedorsocial
# 7875  Mudança no clima leva marca francesa a produzi...              comida
# 7876  Aventura política na Nova Zelândia afeta reput...                 tec
# 7877  Imagem de satélite mostra movimento de iceberg...            ambiente
# 7878  Saiba como limpar a lavadora de roupas da form...           sobretudo
# 7879  Ansiedade matemática de pais contagia filhos. ...    equilibrioesaude
# 7880  MEC vai receber até dia 17 sugestões de mudanç...            educacao
# 7881  Apple conquista patente para aparelho de reali...                 tec
# 7882  Veg: Curitiba terá festival com sete tipos de ...              comida
# 7883  Quanto custa a comida que as companhias aéreas...             turismo
# 7884  'Amo o lixão', afirma catadora após trocar o l...  empreendedorsocial
# 7885  Tenho uma bolha na gengiva. O que faço, devo m...    equilibrioesaude
# 7886  Planetas fora do Sistema Solar são batizados e...             ciencia
# 7887  Entrada do zika no Brasil pode ter sido na Cop...    equilibrioesaude
# 7888  Veg: Comidas vegetarianas para uma viagem de b...              comida
# 7889  Mensageiro Sideral: Uma olhada noutros planeta...             ciencia
# 7890  Sem verba, MEC pode suspender Pronatec. A cont...            educacao
# 7891  Deputado do PT agride PM durante invasão na As...            educacao
# 7892  Governo avalia reduzir a 10% desconto automáti...            educacao
# 7893  Calouro vira CEO de rede de escolas de inglês ...  empreendedorsocial
#
# [7894 rows x 2 columns]

# %%
train_df['TotalWords'] = train_df.apply(lambda row: get_total_words(row), axis=1)
train_df
# Out:
#                                                    text               label  \
# 0     Casa da Barra Funda tem clima roceiro e receit...              comida
# 1     Professores de SP decidem manter greve; grupo ...            educacao
# 2     Em segunda edição, concurso paga R$ 35 mil par...  empreendedorsocial
# 3     Usar maconha por anos não faz tão mal para a s...    equilibrioesaude
# 4     Baleia-azul percorre 5.200 km e revela a cient...             ciencia
# 5     Líderes inovadores se reunem em rede para comp...  empreendedorsocial
# 6     Conheça Pandora, atração milionária da Disney ...             turismo
# 7     Fiesp organiza quarta edição de maratona hacke...  empreendedorsocial
# 8     Praia do Forte mistura natureza com resorts es...             turismo
# 9     App de agência avisa quando visto e passaporte...             turismo
# 10    App de caronas para viagens não teme comparaçõ...             turismo
# 11    Veja quais são os tipos de veículos que precis...           sobretudo
# 12    Rica em fósseis de dinos, Uberaba deve ter geo...             ciencia
# 13    Yahoo! tem prejuízo de US$ 492 milhões no 2º t...                 tec
# 14    Bazar beneficente tem comida típica síria feit...  empreendedorsocial
# 15    5 lugares para voar de balão no Brasil. As pos...             turismo
# 16    Loja de aplicativos do Google oferece opção pr...                 tec
# 17    Paris proibirá circulação de carros em trecho ...             turismo
# 18    Chinesa ZTE diz que lucro dobrou no ano passad...                 tec
# 19    Gwyneth Paltrow desiste do desafio de passar 7...              comida
# 20    Tema de redação do Enem vazou antes do início ...            educacao
# 21    Planejamento evita aperto no orçamento na hora...            educacao
# 22    Nas mensagens, GIFs valem pelo menos mil palav...                 tec
# 23    ONG arrecada material escolar a 7 mil crianças...  empreendedorsocial
# 24    Educação média não consegue formar quadros téc...            educacao
# 25    Artista plástica ensina a fazer suportes para ...           sobretudo
# 26    Confira o kit de decoração de unhas tetris e o...                 tec
# 27    Ciclo Brilhante quer inspirar 100 mil brasilei...  empreendedorsocial
# 28    Trump diz estar com 'mente aberta' em relação ...            ambiente
# 29    Temida, química exige relações com o cotidiano...            educacao
# ...                                                 ...                 ...
# 7864  Pica-paus se arriscam para manter higiene do n...             ciencia
# 7865  Programa deixa o novo Windows 10 com cara de W...                 tec
# 7866  Brasileiros dão 'jeitinho' para baratear ida a...             turismo
# 7867  Pouco conhecida, ilha de Santa Lúcia tem paisa...             turismo
# 7868  Criado nos EUA, conceito de MBA foi 'tropicali...           sobretudo
# 7869  É preciso abrir mão de espaço e localização na...           sobretudo
# 7870  Não usar azeite para fritar? Veja regras culin...    equilibrioesaude
# 7871  Que navegador para celular usar? Os pontos pos...                 tec
# 7872  FGV Eaesp lança mestrado profissional de suste...  empreendedorsocial
# 7873  Justiça realiza audiência de conciliação entre...            educacao
# 7874  Empreendedores sociais fazem da cidadania o fo...  empreendedorsocial
# 7875  Mudança no clima leva marca francesa a produzi...              comida
# 7876  Aventura política na Nova Zelândia afeta reput...                 tec
# 7877  Imagem de satélite mostra movimento de iceberg...            ambiente
# 7878  Saiba como limpar a lavadora de roupas da form...           sobretudo
# 7879  Ansiedade matemática de pais contagia filhos. ...    equilibrioesaude
# 7880  MEC vai receber até dia 17 sugestões de mudanç...            educacao
# 7881  Apple conquista patente para aparelho de reali...                 tec
# 7882  Veg: Curitiba terá festival com sete tipos de ...              comida
# 7883  Quanto custa a comida que as companhias aéreas...             turismo
# 7884  'Amo o lixão', afirma catadora após trocar o l...  empreendedorsocial
# 7885  Tenho uma bolha na gengiva. O que faço, devo m...    equilibrioesaude
# 7886  Planetas fora do Sistema Solar são batizados e...             ciencia
# 7887  Entrada do zika no Brasil pode ter sido na Cop...    equilibrioesaude
# 7888  Veg: Comidas vegetarianas para uma viagem de b...              comida
# 7889  Mensageiro Sideral: Uma olhada noutros planeta...             ciencia
# 7890  Sem verba, MEC pode suspender Pronatec. A cont...            educacao
# 7891  Deputado do PT agride PM durante invasão na As...            educacao
# 7892  Governo avalia reduzir a 10% desconto automáti...            educacao
# 7893  Calouro vira CEO de rede de escolas de inglês ...  empreendedorsocial
#
#       TotalWords
# 0            453
# 1            462
# 2            255
# 3            833
# 4            771
# 5            356
# 6           1087
# 7            250
# 8           1152
# 9            615
# 10           397
# 11           147
# 12           666
# 13           240
# 14           349
# 15           810
# 16           334
# 17           332
# 18           231
# 19           378
# 20           747
# 21           605
# 22          1533
# 23           358
# 24           800
# 25           136
# 26            59
# 27           468
# 28           278
# 29           943
# ...          ...
# 7864         720
# 7865         184
# 7866         869
# 7867         609
# 7868         536
# 7869         840
# 7870         875
# 7871         827
# 7872         476
# 7873         288
# 7874         610
# 7875         176
# 7876         317
# 7877         599
# 7878         149
# 7879         821
# 7880         181
# 7881         922
# 7882          66
# 7883        1328
# 7884        1750
# 7885         291
# 7886         600
# 7887         884
# 7888          67
# 7889          57
# 7890         624
# 7891         436
# 7892         444
# 7893        1193
#
# [7894 rows x 3 columns]

# %%
dev_df = pd.read_csv('dev_text.csv')
dev_df['TotalWords'] = dev_df.apply(lambda row: get_total_words(row), axis=1)
dev_df
# Out:
#                                                    text  TotalWords
# 0     Vitrine de Dilma, Pronatec terá orçamento 65% ...         648
# 1     Por direitos autorais e publicidade, 'youtuber...         660
# 2     Rótulos de alimentos terão que alertar sobre l...         866
# 3     Sociedade britânica de compositores processa S...         201
# 4     Por Fies, aluna madruga na porta da FMU, mas s...         764
# 5     Cientistas aguardam nascimento raro de 'dragõe...         798
# 6     Aplicativo mostra quem está no mesmo voo que v...         693
# 7     Pesquisas indicam que sono na direção pode ser...         612
# 8     Brasil lançará missão à Lua até 2020 para estu...        1262
# 9     Cientistas testam vacina contra colesterol e d...         639
# 10    Farol da Torre Eiffel é desligado para manuten...         188
# 11    Finalistas do Empreendedor Social terão mentor...         333
# 12    Eventos marcam comemorações do aniversário de ...         577
# 13    Folha realiza fórum sobre saúde em tempo de re...         319
# 14    Por que o 'MasterChef' bateu recordes no Twitt...         761
# 15    Complexo gastronômico é inaugurado no Recife; ...         617
# 16    Empresa de presidente do Twitter, Square vai e...         354
# 17    Lojas e restaurantes testemunham as transforma...         470
# 18    Fotógrafo registra cânions gaúchos em preto e ...         256
# 19    Fórum discute inclusão teatral com foco em pro...         189
# 20    Artista cria em meio ao inferno da favela: 'Co...        1291
# 21    Casal fotografa cenas e paisagens pelo mundo q...         498
# 22    Fóssil de mandíbula leva à descoberta de bicho...         846
# 23    Food truck do Mocotó venderá dadinhos de tapio...         155
# 24    Cientistas comparam ondas cerebrais e algoritm...         680
# 25    Música mais antiga criada por computador é res...         692
# 26    Lua de Júpiter vira aposta de cientistas na bu...        1045
# 27    Projeto transforma quarto em área multiúso e t...         202
# 28    Especialistas estimam em US$ 3 tri transição p...         804
# 29    Área de reserva para mineração é igual a 4 ano...         380
# ...                                                 ...         ...
# 4221  Fenômeno El Niño de 2015 deve ser um dos mais ...         364
# 4222  Mensageiro Sideral: Treinamento em jornalismo ...          65
# 4223  Pirituba concentra condomínios gigantescos apó...         624
# 4224  Carreira de direito ganha mais fama e interess...         826
# 4225  Um reconhecimento à causa. O bom de ser reconh...         613
# 4226  Refazer provas antigas do Enem pode ajudar na ...         919
# 4227  Negócios sociais voltados à primeira infância ...         946
# 4228  Carros que chegam em 2017 valorizam espaço int...         452
# 4229  Proposta pode acabar com despacho gratuito de ...         672
# 4230  Cai para 57 o número de escolas ocupadas em Sã...         181
# 4231  Brasileiro é eleito melhor jogador de videogam...         308
# 4232  Em um ano na Microsoft, executivo mudou jeito ...         578
# 4233  Artemisia seleciona negócios de impacto para p...         557
# 4234  Após reclamações, LinkedIn diminui número de e...         254
# 4235  Fumar no inverno é pior para a saúde?. Sou fum...         267
# 4236  Consumo de cereais integrais pode aumentar lon...         381
# 4237  Próxima do metrô, Vila Guilherme cresce ao lad...         665
# 4238  Microsoft vai abandonar marca Internet Explore...         338
# 4239  OMS comemora grandes avanços na luta contra do...         501
# 4240  Modelo de financiamento estudantil também é de...         258
# 4241  Queda na cotação do euro estimula compra da mo...         418
# 4242  Governo promete pagar a professores meses desc...         265
# 4243  Astrônomos da USP tiram dinheiro do próprio bo...         820
# 4244  Venda de PCs despencou 38% no segundo trimestr...         280
# 4245  Azul do mar se encontra com paisagem do desert...         559
# 4246  Barbie grava conversa e 'vira' espiã da Aleman...         229
# 4247  Crescimento no serviço de nuvem não evita qued...         247
# 4248  O revolucionário projeto de viagem interestela...         967
# 4249  Chef suíço que se suicidou pode ter sido vítim...         353
# 4250  Humoristas satirizam comportamento de brasilei...         288
#
# [4251 rows x 2 columns]

# %%
X = train_df[['text', 'TotalWords']]
Y = train_df['label']

# %%
classifier.fit(X, Y)
preds = classifier.predict(X)
# Out:
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/base.py:465: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/pipeline.py:451: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
balanced_accuracy_score(Y, preds)
# Out:
# 0.9994765083104306

# %%
f1_score(Y, preds, average='micro')
# Out:
# 0.9994932860400304

# %%
write_predictions(classifier.predict(dev_df[['text', 'TotalWords']]), 'submission_xgboost.csv')
# Out:
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/pipeline.py:451: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# Saving predictions to submission_xgboost.csv
# Predicted 100 sentences
# Predicted 200 sentences
# Predicted 300 sentences
# Predicted 400 sentences
# Predicted 500 sentences
# Predicted 600 sentences
# Predicted 700 sentences
# Predicted 800 sentences
# Predicted 900 sentences
# Predicted 1000 sentences
# Predicted 1100 sentences
# Predicted 1200 sentences
# Predicted 1300 sentences
# Predicted 1400 sentences
# Predicted 1500 sentences
# Predicted 1600 sentences
# Predicted 1700 sentences
# Predicted 1800 sentences
# Predicted 1900 sentences
# Predicted 2000 sentences
# Predicted 2100 sentences
# Predicted 2200 sentences
# Predicted 2300 sentences
# Predicted 2400 sentences
# Predicted 2500 sentences
# Predicted 2600 sentences
# Predicted 2700 sentences
# Predicted 2800 sentences
# Predicted 2900 sentences
# Predicted 3000 sentences
# Predicted 3100 sentences
# Predicted 3200 sentences
# Predicted 3300 sentences
# Predicted 3400 sentences
# Predicted 3500 sentences
# Predicted 3600 sentences
# Predicted 3700 sentences
# Predicted 3800 sentences
# Predicted 3900 sentences
# Predicted 4000 sentences
# Predicted 4100 sentences
# Predicted 4200 sentences
# Finished predicting 4251 sentences
# Results saved in /media/discoD/Mestrado/FASAM/submission_xgboost.csv

# %%
model = Pipeline([
    ('features', FeatureUnion([
        ('text', Pipeline([
            ('colext', TextSelector('text')),
            ('tfidf', TfidfVectorizer(tokenizer=Tokenizer, stop_words=stop_words, ngram_range=(1,2)))
        ])),
        ('words', Pipeline([
            ('wordext', NumberSelector('TotalWords')),
            ('wscaler', StandardScaler()),
        ])),
    ])),
    ('clf', OneVsRestClassifier(LinearSVC(random_state=0, max_iter=3000, tol=1e-6, class_weight='balanced'))),
    ])

# %%
model.fit(X, Y)
# Out:
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/base.py:465: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=None,
#        transformer_list=[('text', Pipeline(memory=None,
#      steps=[('colext', TextSelector(field='text')), ('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='co...    multi_class='ovr', penalty='l2', random_state=0, tol=1e-06, verbose=0),
#           n_jobs=None))])

# %%
preds = model.predict(X)
# Out:
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/pipeline.py:451: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
balanced_accuracy_score(Y, preds)
# Out:
# 0.9992147624656459

# %%
f1_score(Y, preds, average='micro')
# Out:
# 0.9992399290600456

# %%
write_predictions(model.predict(dev_df[['text', 'TotalWords']]), 'submission_onevsrest.csv')
# Out:
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/pipeline.py:451: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# Saving predictions to submission_onevsrest.csv
# Predicted 100 sentences
# Predicted 200 sentences
# Predicted 300 sentences
# Predicted 400 sentences
# Predicted 500 sentences
# Predicted 600 sentences
# Predicted 700 sentences
# Predicted 800 sentences
# Predicted 900 sentences
# Predicted 1000 sentences
# Predicted 1100 sentences
# Predicted 1200 sentences
# Predicted 1300 sentences
# Predicted 1400 sentences
# Predicted 1500 sentences
# Predicted 1600 sentences
# Predicted 1700 sentences
# Predicted 1800 sentences
# Predicted 1900 sentences
# Predicted 2000 sentences
# Predicted 2100 sentences
# Predicted 2200 sentences
# Predicted 2300 sentences
# Predicted 2400 sentences
# Predicted 2500 sentences
# Predicted 2600 sentences
# Predicted 2700 sentences
# Predicted 2800 sentences
# Predicted 2900 sentences
# Predicted 3000 sentences
# Predicted 3100 sentences
# Predicted 3200 sentences
# Predicted 3300 sentences
# Predicted 3400 sentences
# Predicted 3500 sentences
# Predicted 3600 sentences
# Predicted 3700 sentences
# Predicted 3800 sentences
# Predicted 3900 sentences
# Predicted 4000 sentences
# Predicted 4100 sentences
# Predicted 4200 sentences
# Finished predicting 4251 sentences
# Results saved in /media/discoD/Mestrado/FASAM/submission_onevsrest.csv
