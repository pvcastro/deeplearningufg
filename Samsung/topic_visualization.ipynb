# %% [markdown]
# # Loading the models for model visualization

# %%
from gensim.models import LdaModel, Phrases
from gensim.corpora import Dictionary

import pyLDAvis.gensim
pyLDAvis.enable_notebook()

from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

import load_lee_background_corpus as load_texts

# %% [markdown]
# ### Loading the previously saved models

# %%
dictionary = Dictionary.load('dicionario_1')
phraser = Phrases.load('frases_1')
model = LdaModel.load('modelo_1')

train_texts = load_texts.get_train_texts()
corpus = [dictionary.doc2bow(text) for text in train_texts]
# Out:
# /Users/home/Desenvolvimento/anaconda3/lib/python3.6/site-packages/gensim/test/test_data
# Returning 300 training texts

# %% [markdown]
# ### Display the model's topics

# %%
model.top_topics(texts=train_texts, dictionary=dictionary, coherence='c_v')
# Out:
# [([(0.012895719851996067, 'control'),
#    (0.010342960406119079, 'policy'),
#    (0.010204058999972919, 'action'),
#    (0.0083134585671251707, 'reinforcement'),
#    (0.0077073513365406455, 'optimal'),
#    (0.0064955063811230748, 'dynamic'),
#    (0.0056830889368868712, 'reinforcement_learning'),
#    (0.0049995162344316632, 'controller'),
#    (0.0045728156409747247, 'convergence'),
#    (0.0044776870085259527, 'trajectory'),
#    (0.004461860340494026, 'stochastic'),
#    (0.0042653262640453609, 'reward'),
#    (0.0038912369684233551, 'gradient'),
#    (0.0036308006428268178, 'iteration'),
#    (0.0035011231384248164, 'decision'),
#    (0.0033716279132991701, 'cost'),
#    (0.0032404779465705271, 'path'),
#    (0.0032049180590683242, 'adaptive'),
#    (0.0031630354519811572, 'trial'),
#    (0.0030597839786760126, 'markov')],
#   nan),
#  ([(0.0083611383576793919, 'rule'),
#    (0.0039587138374270548, 'robot'),
#    (0.0038543241499306886, 'node'),
#    (0.0036722495034642393, 'architecture'),
#    (0.0035816461246332035, 'learn'),
#    (0.0035485997081343189, 'position'),
#    (0.003493415782809262, 'action'),
#    (0.0034635056857660021, 'environment'),
#    (0.0031222994624315352, 'learned'),
#    (0.0030230561519005218, 'control'),
#    (0.0029220147443930946, 'net'),
#    (0.0029035834423791311, 'trained'),
#    (0.0028446547023170238, 'connectionist'),
#    (0.0028127015648316805, 'hand'),
#    (0.0028044692449741846, 'hidden'),
#    (0.0027890102674169113, 'language'),
#    (0.0027192634275596838, 'object'),
#    (0.0027141161232981793, 'string'),
#    (0.00266899840882775, 'machine'),
#    (0.0026590185066969808, 'activation')],
#   nan),
#  ([(0.0087019349400993696, 'memory'),
#    (0.007467846832042135, 'neuron'),
#    (0.0063270197581030523, 'distance'),
#    (0.005204620857416218, 'matrix'),
#    (0.0046361688058263245, 'energy'),
#    (0.0044854397721363582, 'solution'),
#    (0.0044684519184394209, 'map'),
#    (0.0040663167486876314, 'dynamic'),
#    (0.0039428675565785828, 'field'),
#    (0.0037118272176141702, 'cluster'),
#    (0.0035339273617158106, 'attractor'),
#    (0.0034025093262739967, 'hopfield'),
#    (0.003310597717419996, 'capacity'),
#    (0.00318045508920763, 'connection'),
#    (0.0030581808101633632, 'constraint'),
#    (0.0030312670139454908, 'dimensional'),
#    (0.0029183655918934999, 'fig'),
#    (0.0026808722492926264, 'graph'),
#    (0.0026751661343802353, 'bit'),
#    (0.002651110720545303, 'associative')],
#   nan),
#  ([(0.014559518965896247, 'neuron'),
#    (0.014137511808902091, 'cell'),
#    (0.0066897529660345451, 'visual'),
#    (0.0062700816141757305, 'response'),
#    (0.0059381090937266736, 'activity'),
#    (0.0057011228270705998, 'circuit'),
#    (0.0054274119397364146, 'field'),
#    (0.0052366056886477205, 'synaptic'),
#    (0.0045684993584383295, 'chip'),
#    (0.0045436345667259894, 'motion'),
#    (0.0044779080935873836, 'stimulus'),
#    (0.0043736213907216619, 'direction'),
#    (0.0043535655842993721, 'connection'),
#    (0.004238090124721732, 'cortex'),
#    (0.0036464972210495388, 'layer'),
#    (0.0036382250313257685, 'eye'),
#    (0.0036163263396860896, 'orientation'),
#    (0.0035105751570045128, 'fig'),
#    (0.0033570334806384385, 'spatial'),
#    (0.0033234106025881766, 'voltage')],
#   nan),
#  ([(0.014886469381724547, 'speech'),
#    (0.01428229553753064, 'word'),
#    (0.012438673345114186, 'recognition'),
#    (0.0077260390087214321, 'sequence'),
#    (0.006614813093579054, 'context'),
#    (0.0063955878342659015, 'hidden'),
#    (0.005647053186294845, 'hmm'),
#    (0.00556262505389941, 'speaker'),
#    (0.0049141915112339216, 'recurrent'),
#    (0.0047998854168181601, 'architecture'),
#    (0.0044260533261759917, 'mixture'),
#    (0.0042118664313149515, 'trained'),
#    (0.0038876454157621893, 'class'),
#    (0.0038681493132302603, 'phoneme'),
#    (0.0035645604207176708, 'layer'),
#    (0.0035367534002899745, 'frame'),
#    (0.0034750275063975444, 'acoustic'),
#    (0.003447938554677545, 'net'),
#    (0.0033924909251753376, 'signal'),
#    (0.0033238312829524685, 'speech_recognition')],
#   nan),
#  ([(0.013529746286885028, 'layer'),
#    (0.013075714221561457, 'hidden'),
#    (0.0094565925255605254, 'net'),
#    (0.0074505944284766548, 'hidden_unit'),
#    (0.0062490090443009612, 'node'),
#    (0.0046785179685423879, 'class'),
#    (0.0041932419712785276, 'threshold'),
#    (0.0040963001116977099, 'character'),
#    (0.0040093961778648749, 'back'),
#    (0.0039455081156984772, 'propagation'),
#    (0.0037973920784833345, 'architecture'),
#    (0.0036053420983162511, 'hidden_layer'),
#    (0.003356048030051492, 'trained'),
#    (0.0032546172410621668, 'back_propagation'),
#    (0.0031411613331402727, 'generalization'),
#    (0.0030212233415626575, 'recognition'),
#    (0.0029534899556284732, 'classification'),
#    (0.0029071885923084646, 'dimension'),
#    (0.0029068143019047809, 'training_set'),
#    (0.0028207763768007738, 'bound')],
#   nan),
#  ([(0.0096088375106014191, 'class'),
#    (0.0092911658204330259, 'classifier'),
#    (0.0078138156839832468, 'tree'),
#    (0.0063675243623706711, 'classification'),
#    (0.0054709763950110315, 'kernel'),
#    (0.0047838924712435213, 'decision'),
#    (0.0047591957846909736, 'sample'),
#    (0.0046660360472530445, 'regression'),
#    (0.0045548661565365193, 'xi'),
#    (0.0041554980571806704, 'bound'),
#    (0.0040312334884774056, 'machine'),
#    (0.0039362567668978967, 'loss'),
#    (0.0037455944845021945, 'prediction'),
#    (0.0035496111882202469, 'let'),
#    (0.0035019389534490125, 'training_set'),
#    (0.0034025272995282753, 'estimate'),
#    (0.0032676105546180236, 'support'),
#    (0.0031899008042386491, 'generalization'),
#    (0.0031039836482172514, 'hypothesis'),
#    (0.0028986120920272305, 'validation')],
#   nan),
#  ([(0.0075997215105520462, 'gaussian'),
#    (0.0075147393091411219, 'matrix'),
#    (0.0064340721756849326, 'noise'),
#    (0.0056795969076568909, 'component'),
#    (0.0056355581894993682, 'density'),
#    (0.0049832854840925903, 'approximation'),
#    (0.0040773505240464334, 'estimate'),
#    (0.0040228121731598994, 'variance'),
#    (0.0037594074274351313, 'optimal'),
#    (0.0036645023141166524, 'likelihood'),
#    (0.0035784057550582952, 'mixture'),
#    (0.0034642690687854446, 'gradient'),
#    (0.0032914331051125058, 'independent'),
#    (0.0032511009653240909, 'estimation'),
#    (0.003053390173553589, 'log'),
#    (0.0030066150033646339, 'source'),
#    (0.0029865510356899003, 'eq'),
#    (0.0029388785669367855, 'sample'),
#    (0.002908909055161989, 'covariance'),
#    (0.0028801499647465572, 'prior')],
#   nan),
#  ([(0.027112245961577509, 'image'),
#    (0.010849061993496365, 'object'),
#    (0.0069061716142091523, 'recognition'),
#    (0.0058842039795909329, 'face'),
#    (0.0041516898895582136, 'pixel'),
#    (0.0040369021945049367, 'view'),
#    (0.0036686696055683358, 'region'),
#    (0.0036666616798578531, 'bayesian'),
#    (0.0034929367056304372, 'human'),
#    (0.0034601223058838677, 'prior'),
#    (0.0033245420987627725, 'visual'),
#    (0.0030724767208861062, 'component'),
#    (0.0030611448004329547, 'scale'),
#    (0.0028568506263953034, 'vision'),
#    (0.0028464121503309543, 'class'),
#    (0.0027847362246290423, 'scene'),
#    (0.0026766680757240413, 'mixture'),
#    (0.0025374658546912982, 'shape'),
#    (0.0024903878860222323, 'similarity'),
#    (0.002326778238387082, 'gaussian')],
#   nan),
#  ([(0.014827615774385374, 'signal'),
#    (0.012926126318406879, 'spike'),
#    (0.0091032281015564539, 'frequency'),
#    (0.0085395434970704162, 'noise'),
#    (0.0074835460264832711, 'stimulus'),
#    (0.0073604822908739992, 'channel'),
#    (0.0069013654264047861, 'neuron'),
#    (0.0066530541459187149, 'response'),
#    (0.0050762697700375038, 'auditory'),
#    (0.0049680885377354307, 'sound'),
#    (0.0044665818436748781, 'filter'),
#    (0.0044350540848524323, 'firing'),
#    (0.0037988082147431736, 'train'),
#    (0.0034679364602827759, 'temporal'),
#    (0.0033696467720481082, 'cell'),
#    (0.0033041985620375831, 'event'),
#    (0.00318835383552432, 'potential'),
#    (0.0031843589249008967, 'detection'),
#    (0.0030673060857010297, 'source'),
#    (0.0029386094617201599, 'cue')],
#   nan)]

# %% [markdown]
# ### User pyLDAvis to visualize the topics
#
# The red bars represent the frequency of a term in a given topic, (proportional to p(term | topic)), and the blue bars represent a term's frequency across the entire corpus, (proportional to p(term)). Change the value of λ to adjust the term rankings -- small values of λ (near 0) highlight potentially rare, but exclusive terms for the selected topic, and large values of λ (near 1) highlight frequent, but not necessarily exclusive, terms for the selected topic.

# %%
pyLDAvis.gensim.prepare(model, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      46.023085        1       1 -0.002719  0.017408
# 9      12.157599        1       2  0.122980  0.025812
# 6      11.529606        1       3 -0.107158 -0.007147
# 0       8.840869        1       4 -0.045408 -0.099085
# 3       7.167230        1       5  0.185384 -0.027699
# 8       5.175572        1       6 -0.007396  0.065340
# 5       3.668370        1       7 -0.041229  0.022221
# 4       3.287834        1       8 -0.042743  0.111118
# 2       1.565531        1       9  0.005453 -0.060041
# 7       0.584305        1      10 -0.067164 -0.047928, topic_info=     Category       Freq                  Term      Total  loglift  logprob
# term
# 1661  Default  11.000000                 image  11.000000  30.0000  30.0000
# 836   Default  13.000000                hidden  13.000000  29.0000  29.0000
# 10    Default  13.000000                neuron  13.000000  28.0000  28.0000
# 681   Default  13.000000                 layer  13.000000  27.0000  27.0000
# 410   Default  11.000000                object  11.000000  26.0000  26.0000
# 2663  Default   9.000000                 spike   9.000000  25.0000  25.0000
# 1408  Default  14.000000                signal  14.000000  24.0000  24.0000
# 389   Default   9.000000                memory   9.000000  23.0000  23.0000
# 18    Default  12.000000                   net  12.000000  22.0000  22.0000
# 2662  Default  15.000000                action  15.000000  21.0000  21.0000
# 686   Default  17.000000               control  17.000000  20.0000  20.0000
# 1142  Default   9.000000                  cell   9.000000  19.0000  19.0000
# 2297  Default  10.000000                 noise  10.000000  18.0000  18.0000
# 6799  Default   7.000000                policy   7.000000  17.0000  17.0000
# 2040  Default   7.000000           recognition   7.000000  16.0000  16.0000
# 2897  Default   6.000000         reinforcement   6.000000  15.0000  15.0000
# 1580  Default  26.000000                  rule  26.000000  14.0000  14.0000
# 388   Default  11.000000                 class  11.000000  13.0000  13.0000
# 1032  Default  10.000000               dynamic  10.000000  12.0000  12.0000
# 1218  Default   4.000000                  word   4.000000  11.0000  11.0000
# 1940  Default  12.000000              sequence  12.000000  10.0000  10.0000
# 837   Default   7.000000            classifier   7.000000   9.0000   9.0000
# 1049  Default   6.000000           hidden_unit   6.000000   8.0000   8.0000
# 3984  Default   4.000000                speech   4.000000   7.0000   7.0000
# 915   Default  16.000000                  node  16.000000   6.0000   6.0000
# 98    Default   4.000000                matrix   4.000000   5.0000   5.0000
# 647   Default   8.000000               optimal   8.000000   4.0000   4.0000
# 403   Default  13.000000          architecture  13.000000   3.0000   3.0000
# 1138  Default   7.000000              stimulus   7.000000   2.0000   2.0000
# 269   Default   8.000000             frequency   8.000000   1.0000   1.0000
# ...       ...        ...                   ...        ...      ...      ...
# 2891  Topic10   0.127144            likelihood   2.064858   2.3550  -5.6091
# 2447  Topic10   0.139576              variance   2.506693   2.2544  -5.5158
# 6826  Topic10   0.096182                    em   1.334964   2.5121  -5.8881
# 4102  Topic10   0.067410             estimator   0.719671   2.7745  -6.2436
# 220   Topic10   0.103621                    eq   1.701319   2.3441  -5.8136
# 1907  Topic10   0.172900         approximation   4.813564   1.8160  -5.3017
# 548   Topic10   0.197059             component   6.813587   1.5993  -5.1709
# 1361  Topic10   0.124156               mixture   2.904736   1.9899  -5.6328
# 2297  Topic10   0.223237                 noise  10.199606   1.3206  -5.0461
# 3201  Topic10   0.112800            estimation   2.492928   2.0469  -5.7288
# 8157  Topic10   0.057950  generalization_error   0.696109   2.6566  -6.3948
# 8058  Topic10   0.045168          em_algorithm   0.400257   2.9608  -6.6440
# 2441  Topic10   0.114200           independent   4.086228   1.5651  -5.7164
# 2295  Topic10   0.141468              estimate   7.057678   1.2327  -5.5023
# 2214  Topic10   0.105940                   log   3.744317   1.5774  -5.7915
# 444   Topic10   0.120196              gradient   5.552256   1.3097  -5.6653
# 2874  Topic10   0.099930                 prior   3.529223   1.5781  -5.8499
# 1144  Topic10   0.104318                source   4.246383   1.4361  -5.8069
# 647   Topic10   0.130436               optimal   8.748117   0.9368  -5.5835
# 650   Topic10   0.089904             nonlinear   2.710680   1.7363  -5.9556
# 1817  Topic10   0.085589                 basis   3.712884   1.3725  -6.0048
# 1386  Topic10   0.101967                sample   7.723320   0.8152  -5.8297
# 1790  Topic10   0.090846        generalization   6.878406   0.8155  -5.9452
# 6067  Topic10   0.072779              bayesian   2.077710   1.7909  -6.1670
# 997   Topic10   0.079514               maximum   4.004595   1.2232  -6.0784
# 0     Topic10   0.087066              solution   8.632627   0.5459  -5.9877
# 1580  Topic10   0.094007                  rule  26.176461  -0.4867  -5.9110
# 1408  Topic10   0.088991                signal  14.959429   0.0179  -5.9658
# 433   Topic10   0.080686                 bound   5.414337   0.9363  -6.0638
# 2236  Topic10   0.081397            prediction  11.069394   0.2299  -6.0550
#
# [731 rows x 6 columns], token_table=      Topic      Freq           Term
# term
# 4654      2  0.710106       acoustic
# 4654      8  0.710106       acoustic
# 2662      1  0.625156         action
# 2662      2  0.062516         action
# 2662      4  0.312578         action
# 1797      1  0.707024     activation
# 1797      2  0.101003     activation
# 1797      7  0.101003     activation
# 1250      1  0.455780       activity
# 1250      2  0.151927       activity
# 1250      5  0.455780       activity
# 1802      1  0.508923       adaptive
# 1802      4  0.339282       adaptive
# 2657      2  0.854156      amplitude
# 7         2  0.346318         analog
# 7         5  0.346318         analog
# 1907      1  0.207746  approximation
# 1907      3  0.207746  approximation
# 1907      4  0.415493  approximation
# 403       1  0.726642   architecture
# 403       5  0.072664   architecture
# 403       7  0.072664   architecture
# 403       8  0.072664   architecture
# 6035      1  1.024356            arm
# 378       1  0.592399    associative
# 2839      2  1.053392       auditory
# 3458      1  0.934145      automaton
# 3197      1  1.047745     autonomous
# 858       1  0.531934           back
# 858       7  0.177311           back
# ...     ...       ...            ...
# 829       3  0.469275           tree
# 1315      1  0.322955          trial
# 1315      2  0.322955          trial
# 1315      3  0.161477          trial
# 1315      4  0.322955          trial
# 696       1  0.431485         update
# 696       4  0.215742         update
# 6027      1  0.906242           user
# 7890      3  0.832615     validation
# 7830      3  0.877208         vapnik
# 2447      3  0.398932       variance
# 3364      1  1.081292        vehicle
# 2861      5  0.541534       velocity
# 1530      1  0.642674           view
# 1530      6  0.214225           view
# 2311      1  0.505526         vision
# 2311      6  0.505526         vision
# 2302      1  0.182571         visual
# 2302      2  0.182571         visual
# 2302      5  0.547712         visual
# 2302      6  0.182571         visual
# 1807      5  0.803465           vlsi
# 2690      2  0.377657        voltage
# 2690      5  0.377657        voltage
# 2821      2  0.652184       waveform
# 1218      1  0.211187           word
# 1218      8  0.633562           word
# 7465      1  1.065774      workspace
# 2317      1  0.738979          world
# 524       3  0.709839             xi
#
# [581 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 10, 7, 1, 4, 9, 6, 5, 3, 8])
