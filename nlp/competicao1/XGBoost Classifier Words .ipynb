# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import nltk
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
from nltk.tokenize import word_tokenize
import re
from sklearn.metrics import balanced_accuracy_score, f1_score
from pathlib import Path
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

# %%
stop_words = [word.strip() for word in open('stopwords-pt.txt', mode='r', encoding='utf8')]

# %%
sent_tokenizer = nltk.data.load('tokenizers/punkt/portuguese.pickle')

# %%
class TextSelector(BaseEstimator, TransformerMixin):
    def __init__(self, field):
        self.field = field
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.field]
    
class NumberSelector(BaseEstimator, TransformerMixin):
    def __init__(self, field):
        self.field = field
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[[self.field]]
    
def Tokenizer(str_input):
    words = re.sub(r"[^A-Za-z0-9\-]", " ", str_input).lower().split()
    porter_stemmer=nltk.PorterStemmer()
    words = [porter_stemmer.stem(word) for word in words]
    return words

def get_total_words(row):
    return len(word_tokenize(row['text']))

def write_predictions(predictions, out_path):
    count = 0

    with open(out_path, mode='w', encoding='utf-8') as out_file:
        print('Saving predictions to %s' % out_path)
        out_file.write('id,category\n')
        idx = 0
        for result in predictions:
            count += 1
            out_file.write(str(idx) + ',' + result + '\n')
            idx += 1
            if count % 100 == 0:
                print('Predicted %d sentences' % count)
    out_file.close()
    print('Finished predicting %d sentences' % count)
    print('Results saved in %s' % Path(out_path).absolute())

# %%
stop_words.extend(Tokenizer(' '.join(stop_words)))
stop_words = sorted(stop_words)
stop_words
# Out:
# ['a',
#  'a',
#  'a',
#  'acerca',
#  'acerca',
#  'adeu',
#  'adeus',
#  'agora',
#  'agora',
#  'ainda',
#  'ainda',
#  'al',
#  'alem',
#  'alem',
#  'algma',
#  'algmas',
#  'algo',
#  'algo',
#  'alguma',
#  'algumas',
#  'algun',
#  'alguns',
#  'ali',
#  'ali',
#  'além',
#  'amba',
#  'ambas',
#  'ambo',
#  'ambos',
#  'amo',
#  'amo',
#  'amo',
#  'ano',
#  'ano',
#  'ano',
#  'anos',
#  'ant',
#  'antes',
#  'ao',
#  'ao',
#  'ao',
#  'aond',
#  'aonde',
#  'aos',
#  'ap',
#  'apena',
#  'apenas',
#  'apo',
#  'apoio',
#  'apoio',
#  'apontar',
#  'apontar',
#  'apos',
#  'após',
#  'aquel',
#  'aquel',
#  'aquela',
#  'aquela',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aqui',
#  'aqui',
#  'aquilo',
#  'aquilo',
#  'as',
#  'as',
#  'assim',
#  'assim',
#  'at',
#  'atr',
#  'atrav',
#  'através',
#  'atrás',
#  'até',
#  'aí',
#  'baixo',
#  'baixo',
#  'bastant',
#  'bastante',
#  'bem',
#  'bem',
#  'boa',
#  'boa',
#  'boa',
#  'boas',
#  'bom',
#  'bom',
#  'bon',
#  'bons',
#  'breve',
#  'breve',
#  'c',
#  'cada',
#  'cada',
#  'caminho',
#  'caminho',
#  'catorz',
#  'catorze',
#  'cedo',
#  'cedo',
#  'cento',
#  'cento',
#  'certament',
#  'certamente',
#  'certeza',
#  'certeza',
#  'cima',
#  'cima',
#  'cinco',
#  'cinco',
#  'coisa',
#  'coisa',
#  'com',
#  'com',
#  'como',
#  'como',
#  'comprido',
#  'comprido',
#  'conhecido',
#  'conhecido',
#  'conselho',
#  'conselho',
#  'contra',
#  'contra',
#  'contudo',
#  'contudo',
#  'corrent',
#  'corrente',
#  'cuja',
#  'cuja',
#  'cuja',
#  'cujas',
#  'cujo',
#  'cujo',
#  'cujo',
#  'cujos',
#  'custa',
#  'custa',
#  'cá',
#  'd',
#  'd',
#  'd',
#  'da',
#  'da',
#  'da',
#  'daquel',
#  'daquel',
#  'daquela',
#  'daquela',
#  'daquela',
#  'daquelas',
#  'daquele',
#  'daqueles',
#  'dar',
#  'dar',
#  'das',
#  'de',
#  'de',
#  'de',
#  'debaixo',
#  'debaixo',
#  'dela',
#  'dela',
#  'dela',
#  'delas',
#  'dele',
#  'dele',
#  'dele',
#  'deles',
#  'demai',
#  'demais',
#  'dentro',
#  'dentro',
#  'depoi',
#  'depois',
#  'desd',
#  'desde',
#  'desligado',
#  'desligado',
#  'dess',
#  'dess',
#  'dessa',
#  'dessa',
#  'dessa',
#  'dessas',
#  'desse',
#  'desses',
#  'dest',
#  'dest',
#  'desta',
#  'desta',
#  'desta',
#  'destas',
#  'deste',
#  'destes',
#  'deve',
#  'deve',
#  'devem',
#  'devem',
#  'dever',
#  'deverá',
#  'dez',
#  'dez',
#  'dezanov',
#  'dezanove',
#  'dezassei',
#  'dezasseis',
#  'dezasset',
#  'dezassete',
#  'dezoito',
#  'dezoito',
#  'dia',
#  'dia',
#  'diant',
#  'diante',
#  'direita',
#  'direita',
#  'dispo',
#  'dispoe',
#  'dispoem',
#  'dispoem',
#  'diversa',
#  'diversa',
#  'diversa',
#  'diversas',
#  'diverso',
#  'diversos',
#  'diz',
#  'diz',
#  'dizem',
#  'dizem',
#  'dizer',
#  'dizer',
#  'do',
#  'do',
#  'do',
#  'doi',
#  'dois',
#  'dos',
#  'doze',
#  'doze',
#  'dua',
#  'duas',
#  'durant',
#  'durante',
#  'dá',
#  'dão',
#  'dúvida',
#  'e',
#  'e',
#  'e',
#  'ela',
#  'ela',
#  'ela',
#  'elas',
#  'ele',
#  'ele',
#  'ele',
#  'eles',
#  'em',
#  'em',
#  'em',
#  'embora',
#  'embora',
#  'enquanto',
#  'enquanto',
#  'ent',
#  'entao',
#  'entao',
#  'entr',
#  'entre',
#  'então',
#  'era',
#  'era',
#  'eram',
#  'eram',
#  'ess',
#  'ess',
#  'essa',
#  'essa',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'est',
#  'est',
#  'est',
#  'est',
#  'est',
#  'est',
#  'esta',
#  'esta',
#  'esta',
#  'estado',
#  'estado',
#  'estamo',
#  'estamos',
#  'estar',
#  'estar',
#  'estar',
#  'estará',
#  'estas',
#  'estava',
#  'estava',
#  'estavam',
#  'estavam',
#  'este',
#  'esteja',
#  'esteja',
#  'estejam',
#  'estejam',
#  'estejamo',
#  'estejamos',
#  'estes',
#  'estev',
#  'esteve',
#  'estiv',
#  'estiv',
#  'estiv',
#  'estiv',
#  'estive',
#  'estivemo',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estivera',
#  'estiveram',
#  'estiveram',
#  'estiverem',
#  'estiverem',
#  'estivermo',
#  'estivermos',
#  'estivess',
#  'estivesse',
#  'estivessem',
#  'estivessem',
#  'estivest',
#  'estivest',
#  'estiveste',
#  'estivestes',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'estou',
#  'está',
#  'estás',
#  'estávamos',
#  'estão',
#  'eu',
#  'eu',
#  'exemplo',
#  'exemplo',
#  'f',
#  'f',
#  'fa',
#  'falta',
#  'falta',
#  'far',
#  'fará',
#  'favor',
#  'favor',
#  'faz',
#  'faz',
#  'faze',
#  'fazei',
#  'fazeis',
#  'fazem',
#  'fazem',
#  'fazemo',
#  'fazemos',
#  'fazer',
#  'fazer',
#  'fazes',
#  'fazia',
#  'fazia',
#  'faço',
#  'fez',
#  'fez',
#  'fim',
#  'fim',
#  'final',
#  'final',
#  'foi',
#  'foi',
#  'fomo',
#  'fomos',
#  'for',
#  'for',
#  'fora',
#  'fora',
#  'foram',
#  'foram',
#  'forem',
#  'forem',
#  'forma',
#  'forma',
#  'formo',
#  'formos',
#  'foss',
#  'fosse',
#  'fossem',
#  'fossem',
#  'fost',
#  'fost',
#  'foste',
#  'fostes',
#  'fui',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'geral',
#  'geral',
#  'grand',
#  'grand',
#  'grande',
#  'grandes',
#  'grupo',
#  'grupo',
#  'h',
#  'h',
#  'ha',
#  'ha',
#  'haja',
#  'haja',
#  'hajam',
#  'hajam',
#  'hajamo',
#  'hajamos',
#  'havemo',
#  'havemos',
#  'havia',
#  'havia',
#  'hei',
#  'hei',
#  'hoje',
#  'hoje',
#  'hora',
#  'hora',
#  'hora',
#  'horas',
#  'houv',
#  'houv',
#  'houv',
#  'houve',
#  'houvemo',
#  'houvemos',
#  'houver',
#  'houver',
#  'houver',
#  'houver',
#  'houver',
#  'houvera',
#  'houvera',
#  'houveram',
#  'houveram',
#  'houverei',
#  'houverei',
#  'houverem',
#  'houverem',
#  'houveremo',
#  'houveremos',
#  'houveria',
#  'houveria',
#  'houveriam',
#  'houveriam',
#  'houvermo',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvess',
#  'houvesse',
#  'houvessem',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'iniciar',
#  'iniciar',
#  'inicio',
#  'inicio',
#  'ir',
#  'ir',
#  'ir',
#  'irá',
#  'is',
#  'isso',
#  'isso',
#  'ist',
#  'ista',
#  'ista',
#  'iste',
#  'isto',
#  'isto',
#  'j',
#  'já',
#  'l',
#  'lado',
#  'lado',
#  'lhe',
#  'lhe',
#  'lhe',
#  'lhes',
#  'ligado',
#  'ligado',
#  'local',
#  'local',
#  'logo',
#  'logo',
#  'long',
#  'longe',
#  'ltimo',
#  'lugar',
#  'lugar',
#  'lá',
#  'm',
#  'm',
#  'm',
#  'm',
#  'm',
#  'm',
#  'm',
#  'ma',
#  'mai',
#  'maior',
#  'maior',
#  'maioria',
#  'maioria',
#  'maioria',
#  'maiorias',
#  'mais',
#  'mal',
#  'mal',
#  'mas',
#  'me',
#  'me',
#  'mediant',
#  'mediante',
#  'meio',
#  'meio',
#  'meno',
#  'menor',
#  'menor',
#  'menos',
#  'mero',
#  'mese',
#  'meses',
#  'mesma',
#  'mesma',
#  'mesma',
#  'mesmas',
#  'mesmo',
#  'mesmo',
#  'mesmo',
#  'mesmos',
#  'meu',
#  'meu',
#  'meu',
#  'meus',
#  'mil',
#  'mil',
#  'minha',
#  'minha',
#  'minha',
#  'minhas',
#  'momento',
#  'momento',
#  'muito',
#  'muito',
#  'muito',
#  'muitos',
#  'máximo',
#  'mês',
#  'n',
#  'n',
#  'n',
#  'n',
#  'na',
#  'na',
#  'na',
#  'nada',
#  'nada',
#  'nao',
#  'nao',
#  'naquel',
#  'naquel',
#  'naquela',
#  'naquela',
#  'naquela',
#  'naquelas',
#  'naquele',
#  'naqueles',
#  'nas',
#  'nem',
#  'nem',
#  'nenhuma',
#  'nenhuma',
#  'ness',
#  'ness',
#  'nessa',
#  'nessa',
#  'nessa',
#  'nessas',
#  'nesse',
#  'nesses',
#  'nest',
#  'nest',
#  'nesta',
#  'nesta',
#  'nesta',
#  'nestas',
#  'neste',
#  'nestes',
#  'nhamo',
#  'no',
#  'no',
#  'no',
#  'noit',
#  'noite',
#  'nome',
#  'nome',
#  'nos',
#  'nossa',
#  'nossa',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nosso',
#  'nosso',
#  'nossos',
#  'nova',
#  'nova',
#  'nova',
#  'novas',
#  'nove',
#  'nove',
#  'novo',
#  'novo',
#  'novo',
#  'novos',
#  'num',
#  'num',
#  'numa',
#  'numa',
#  'numa',
#  'numas',
#  'nun',
#  'nunca',
#  'nunca',
#  'nuns',
#  'não',
#  'nível',
#  'nós',
#  'número',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'obra',
#  'obra',
#  'obrigada',
#  'obrigada',
#  'obrigado',
#  'obrigado',
#  'oitava',
#  'oitava',
#  'oitavo',
#  'oitavo',
#  'oito',
#  'oito',
#  'ond',
#  'onde',
#  'ontem',
#  'ontem',
#  'onz',
#  'onze',
#  'os',
#  'os',
#  'ou',
#  'ou',
#  'outra',
#  'outra',
#  'outra',
#  'outras',
#  'outro',
#  'outro',
#  'outro',
#  'outros',
#  'p',
#  'p',
#  'p',
#  'para',
#  'para',
#  'parec',
#  'parece',
#  'part',
#  'parte',
#  'partir',
#  'partir',
#  'pauca',
#  'paucas',
#  'pegar',
#  'pegar',
#  'pela',
#  'pela',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelo',
#  'pelo',
#  'pelos',
#  'perant',
#  'perante',
#  'perto',
#  'perto',
#  'pessoa',
#  'pessoas',
#  'pode',
#  'pode',
#  'podem',
#  'podem',
#  'poder',
#  'poder',
#  'poder',
#  'poderá',
#  'podia',
#  'podia',
#  'poi',
#  'pois',
#  'ponto',
#  'ponto',
#  'ponto',
#  'pontos',
#  'por',
#  'por',
#  'porqu',
#  'porqu',
#  'porque',
#  'porquê',
#  'portanto',
#  'portanto',
#  'posi',
#  'posição',
#  'poss',
#  'possivelment',
#  'possivelmente',
#  'posso',
#  'posso',
#  'possível',
#  'pouca',
#  'pouca',
#  'pouco',
#  'pouco',
#  'pouco',
#  'poucos',
#  'povo',
#  'povo',
#  'pr',
#  'pr',
#  'pr',
#  'pr',
#  'pr',
#  'pr',
#  'pr',
#  'pr',
#  'pria',
#  'pria',
#  'primeira',
#  'primeira',
#  'primeira',
#  'primeiras',
#  'primeiro',
#  'primeiro',
#  'primeiro',
#  'primeiros',
#  'prio',
#  'prio',
#  'promeiro',
#  'promeiro',
#  'propio',
#  'propios',
#  'proprio',
#  'proprio',
#  'própria',
#  'próprias',
#  'próprio',
#  'próprios',
#  'próxima',
#  'próximas',
#  'próximo',
#  'próximos',
#  'puderam',
#  'puderam',
#  'pôde',
#  'põe',
#  'põem',
#  'qu',
#  'qu',
#  'quai',
#  'quais',
#  'qual',
#  'qual',
#  'qualquer',
#  'qualquer',
#  'quando',
#  'quando',
#  'quanto',
#  'quanto',
#  'quarta',
#  'quarta',
#  'quarto',
#  'quarto',
#  'quatro',
#  'quatro',
#  'que',
#  'que',
#  'quem',
#  'quem',
#  'quer',
#  'quer',
#  'quer',
#  'querei',
#  'quereis',
#  'querem',
#  'querem',
#  'querema',
#  'queremas',
#  'queres',
#  'quero',
#  'quero',
#  'quest',
#  'questão',
#  'quieto',
#  'quieto',
#  'quinta',
#  'quinta',
#  'quinto',
#  'quinto',
#  'quinz',
#  'quinze',
#  'quáis',
#  'quê',
#  'ramo',
#  'ramo',
#  'ramo',
#  'ramo',
#  'ramo',
#  'rea',
#  'rela',
#  'relação',
#  'rio',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  'sabe',
#  'sabe',
#  'sabem',
#  'sabem',
#  'saber',
#  'saber',
#  'se',
#  'se',
#  'segunda',
#  'segunda',
#  'segundo',
#  'segundo',
#  'sei',
#  'sei',
#  'sei',
#  'seis',
#  'seja',
#  'seja',
#  'sejam',
#  'sejam',
#  'sejamo',
#  'sejamos',
#  'sem',
#  'sem',
#  'sempr',
#  'sempre',
#  'sendo',
#  'sendo',
#  'ser',
#  'ser',
#  'ser',
#  'ser',
#  'ser',
#  'serei',
#  'serei',
#  'seremo',
#  'seremos',
#  'seria',
#  'seria',
#  'seriam',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'sete',
#  'sete',
#  'seu',
#  'seu',
#  'seu',
#  'seus',
#  'sexta',
#  'sexta',
#  'sexto',
#  'sexto',
#  'sim',
#  'sim',
#  'sistema',
#  'sistema',
#  'sob',
#  'sob',
#  'sobr',
#  'sobre',
#  'soi',
#  'sois',
#  'soment',
#  'somente',
#  'somo',
#  'somos',
#  'sou',
#  'sou',
#  'ssemo',
#  'ssemo',
#  'ssemo',
#  'ssemo',
#  'sua',
#  'sua',
#  'sua',
#  'suas',
#  'são',
#  'sétima',
#  'sétimo',
#  'só',
#  't',
#  't',
#  't',
#  't',
#  'tal',
#  'tal',
#  'talvez',
#  'talvez',
#  'tamb',
#  'tambem',
#  'tambem',
#  'também',
#  'tanta',
#  'tanta',
#  'tanta',
#  'tantas',
#  'tanto',
#  'tanto',
#  'tard',
#  'tarde',
#  'te',
#  'te',
#  'tem',
#  'tem',
#  'temo',
#  'temos',
#  'tempo',
#  'tempo',
#  'ten',
#  'tend',
#  'tendes',
#  'tenha',
#  'tenha',
#  'tenham',
#  'tenham',
#  'tenhamo',
#  ...]

# %%
classifier = Pipeline([
    ('features', FeatureUnion([
        ('text', Pipeline([
            ('colext', TextSelector('text')),
            ('tfidf', TfidfVectorizer(tokenizer=Tokenizer, stop_words=stop_words, ngram_range=(1,2))),
            ('svd', TruncatedSVD(algorithm='randomized', n_components=300)), #for XGB
        ])),
        ('words', Pipeline([
            ('wordext', NumberSelector('TotalWords')),
            ('wscaler', StandardScaler()),
        ])),
    ])),
    ('clf', XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.1)),
    ])

# %%
train_df = pd.read_csv('train_text_label.csv')

# %%
dev_df = pd.read_csv('dev_text.csv')

# %%
X = train_df[['text']]
Y = train_df['label']

# %%
classifier.fit(X, Y)
preds = classifier.predict(X)
# Out:
# /home/pedro/anaconda3/envs/allennlp/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['adeu', 'al', 'algma', 'alguma', 'algun', 'amba', 'ambo', 'amo', 'ant', 'aond', 'ap', 'apena', 'apo', 'aquel', 'at', 'atr', 'atrav', 'bastant', 'bon', 'c', 'catorz', 'certament', 'corrent', 'd', 'daquel', 'demai', 'depoi', 'desd', 'dess', 'dest', 'dever', 'dezanov', 'dezassei', 'dezasset', 'diant', 'dispo', 'diverso', 'doi', 'dua', 'durant', 'ent', 'entr', 'ess', 'est', 'estamo', 'estejamo', 'estev', 'estiv', 'estivemo', 'estivermo', 'estivess', 'estivest', 'f', 'fa', 'far', 'faze', 'fazei', 'fazemo', 'fomo', 'formo', 'foss', 'fost', 'grand', 'h', 'hajamo', 'havemo', 'houv', 'houvemo', 'houveremo', 'houvermo', 'houvess', 'is', 'ist', 'j', 'l', 'long', 'ltimo', 'm', 'ma', 'mai', 'mediant', 'meno', 'mero', 'mese', 'n', 'naquel', 'ness', 'nest', 'nhamo', 'noit', 'nun', 'ond', 'onz', 'p', 'parec', 'part', 'pauca', 'perant', 'pessoa', 'poi', 'porqu', 'posi', 'poss', 'possivelment', 'pr', 'pria', 'prio', 'propio', 'qu', 'quai', 'querei', 'querema', 'quest', 'quinz', 'ramo', 'rea', 'rela', 'rio', 's', 'sejamo', 'sempr', 'seremo', 'sobr', 'soi', 'soment', 'somo', 'ssemo', 't', 'tamb', 'tard', 'temo', 'ten', 'tend', 'tenhamo', 'tent', 'teremo', 'tima', 'timo', 'tiv', 'tivemo', 'tivermo', 'tivess', 'tivest', 'tr', 'un', 'v', 'vamo', 'vel', 'ven', 'verdad', 'veze', 'vida', 'vint', 'vo', 'voc', 'xima', 'ximo'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
balanced_accuracy_score(Y, preds)
# Out:
# 0.9996073812328229

# %%
f1_score(Y, preds, average='micro')
# Out:
# 0.9996199645300228

# %%
write_predictions(classifier.predict(dev_df[['text']]), 'submission_xgboost_words.csv')
# Out:
# Saving predictions to submission_xgboost_words.csv
# Predicted 100 sentences
# Predicted 200 sentences
# Predicted 300 sentences
# Predicted 400 sentences
# Predicted 500 sentences
# Predicted 600 sentences
# Predicted 700 sentences
# Predicted 800 sentences
# Predicted 900 sentences
# Predicted 1000 sentences
# Predicted 1100 sentences
# Predicted 1200 sentences
# Predicted 1300 sentences
# Predicted 1400 sentences
# Predicted 1500 sentences
# Predicted 1600 sentences
# Predicted 1700 sentences
# Predicted 1800 sentences
# Predicted 1900 sentences
# Predicted 2000 sentences
# Predicted 2100 sentences
# Predicted 2200 sentences
# Predicted 2300 sentences
# Predicted 2400 sentences
# Predicted 2500 sentences
# Predicted 2600 sentences
# Predicted 2700 sentences
# Predicted 2800 sentences
# Predicted 2900 sentences
# Predicted 3000 sentences
# Predicted 3100 sentences
# Predicted 3200 sentences
# Predicted 3300 sentences
# Predicted 3400 sentences
# Predicted 3500 sentences
# Predicted 3600 sentences
# Predicted 3700 sentences
# Predicted 3800 sentences
# Predicted 3900 sentences
# Predicted 4000 sentences
# Predicted 4100 sentences
# Predicted 4200 sentences
# Finished predicting 4251 sentences
# Results saved in /media/discoD/Mestrado/FASAM/submission_xgboost_words.csv

# %%
texts, labels = [], []
for idx, row in train_df.iterrows():
    text = row['text']
    sentences = sentence_tokenizer.tokenize(text)
    for sentence in sentences:
        texts.append(sentence)
        labels.append(row['label'])

# %%
train_extended_df = pd.DataFrame({'text': texts, 'label': labels})
train_extended_df
# Out:
#                                                      text               label
# 0       Casa da Barra Funda tem clima roceiro e receit...              comida
# 1       No Quem Quer Pão 75, casa de clima roceiro em ...              comida
# 2       O café coado é de um lote limitado, de grãos d...              comida
# 3       Se é final da tarde, um pão de queijo robusto ...              comida
# 4       Se é para encerrar o almoço, vai bem o brigade...              comida
# 5       É tentador também sugerir uma fatia dos bolos ...              comida
# 6       Meu palpite, porém, é que ainda falta para que...              comida
# 7       A pequena casa é embalada por música popular b...              comida
# 8       O tom hospitaleiro avança para a cozinha, orqu...              comida
# 9       Suas receitas são caseiras e, no balanço, sabo...              comida
# 10      Exemplo: a coxa e a sobrecoxa de frango (R$ 19...              comida
# 11      A pele, crocante, ganha graça com o incremento...              comida
# 12      Também se sai bem a tilápia, carnuda e suculen...              comida
# 13      Para acompanhar, arroz cremoso, com leve toque...              comida
# 14      Pode-se passar batido pelo filé-mignon (R$ 21,...              comida
# 15               Mais o arroz e feijão nosso de cada dia.              comida
# 16                      QUEM QUER PÃO 75  QUANDO: DE SEG.              comida
# 17      A SEX., DAS 8H ÀS 18H ONDE: R. DONA ELISA, 117...              comida
# 18                                         (11) 2538-0844              comida
# 19      Professores de SP decidem manter greve; grupo ...            educacao
# 20                                              Paulista.            educacao
# 21      Professores da rede estadual decidiram manter ...            educacao
# 22      A categoria fez uma assembleia na tarde desta ...            educacao
# 23      Os manifestantes fechavam a pista sentido Cons...            educacao
# 24      Eles deverão passar pela rua da Consolação par...            educacao
# 25      A categoria, que tem a data-base em março, rei...            educacao
# 26      A greve já afeta a rotina de algumas escolas d...            educacao
# 27      Como a Folha mostrou nesta semana, há casos de...            educacao
# 28      Funcionários de uma das escolas visitadas pela...            educacao
# 29      Após ser questionada pela Folha, a Secretaria ...            educacao
# ...                                                   ...                 ...
# 191460  Lá funcionava a Fábrica de Criatividade, uma O...  empreendedorsocial
# 191461  Fuga, a irmã e uma amiga investiram suas econo...  empreendedorsocial
# 191462  "Os primeiros alunos sabiam que era um teste, ...  empreendedorsocial
# 191463  Em um ano, o negócio havia se expandido e alca...  empreendedorsocial
# 191464  Nesse meio tempo, a 4You2 se desvinculou da in...  empreendedorsocial
# 191465  Foi quando Fuga convidou um ex-colega de Aisec...  empreendedorsocial
# 191466  O americano Raley White, 27, entrou na 4You2 e...  empreendedorsocial
# 191467  A maior mudança foi o valor da mensalidade, qu...  empreendedorsocial
# 191468  "Não devemos subir mais do que isso", diz o ad...  empreendedorsocial
# 191469  Outra nova tática foi procurar funcionários ma...  empreendedorsocial
# 191470  White elaborou um manual de normatização de ce...  empreendedorsocial
# 191471  Até o fim de 2017, o plano é que haja 14 escol...  empreendedorsocial
# 191472  Fuga já foi procurado por comunidades de outra...  empreendedorsocial
# 191473  "Acho que deu certo por causa do preço, mas ta...  empreendedorsocial
# 191474  Nossa taxa de evasão fica bem abaixo do mercad...  empreendedorsocial
# 191475                     Nenhum professor é brasileiro.  empreendedorsocial
# 191476  Jovens estrangeiros que nunca deram aula apren...  empreendedorsocial
# 191477  "A seleção é muito parecida com a que a Aiesec...  empreendedorsocial
# 191478  Pegamos as propostas de valor que eles têm e u...  empreendedorsocial
# 191479  O processo seletivo dura três meses, e, segund...  empreendedorsocial
# 191480  A 4You2 trouxe ao Brasil mais de cem alunos-pr...  empreendedorsocial
# 191481  Há ainda seis refugiados que ensinam a língua ...  empreendedorsocial
# 191482  A empresa que começou com um capital de R$ 10 ...  empreendedorsocial
# 191483  Fuga comprou a parte das outras duas sócias po...  empreendedorsocial
# 191484  A equipe começou um processo de captação exter...  empreendedorsocial
# 191485  A transferência de algum poder para administra...  empreendedorsocial
# 191486  "Se eu resolvo cobrar mais, meu aluno vai ter ...  empreendedorsocial
# 191487  "Daí vou ter de pagar mais para o professor e ...  empreendedorsocial
# 191488           "Eu nunca consegui fazer um intercâmbio.  empreendedorsocial
# 191489                       Agora vivo em um", diz Fuga.  empreendedorsocial
#
# [191490 rows x 2 columns]

# %%
train_extended_df['TotalWords'] = train_extended_df.apply(lambda row: get_total_words(row), axis=1)
train_extended_df
# Out:
#                                                      text               label  \
# 0       Casa da Barra Funda tem clima roceiro e receit...              comida
# 1       No Quem Quer Pão 75, casa de clima roceiro em ...              comida
# 2       O café coado é de um lote limitado, de grãos d...              comida
# 3       Se é final da tarde, um pão de queijo robusto ...              comida
# 4       Se é para encerrar o almoço, vai bem o brigade...              comida
# 5       É tentador também sugerir uma fatia dos bolos ...              comida
# 6       Meu palpite, porém, é que ainda falta para que...              comida
# 7       A pequena casa é embalada por música popular b...              comida
# 8       O tom hospitaleiro avança para a cozinha, orqu...              comida
# 9       Suas receitas são caseiras e, no balanço, sabo...              comida
# 10      Exemplo: a coxa e a sobrecoxa de frango (R$ 19...              comida
# 11      A pele, crocante, ganha graça com o incremento...              comida
# 12      Também se sai bem a tilápia, carnuda e suculen...              comida
# 13      Para acompanhar, arroz cremoso, com leve toque...              comida
# 14      Pode-se passar batido pelo filé-mignon (R$ 21,...              comida
# 15               Mais o arroz e feijão nosso de cada dia.              comida
# 16                      QUEM QUER PÃO 75  QUANDO: DE SEG.              comida
# 17      A SEX., DAS 8H ÀS 18H ONDE: R. DONA ELISA, 117...              comida
# 18                                         (11) 2538-0844              comida
# 19      Professores de SP decidem manter greve; grupo ...            educacao
# 20                                              Paulista.            educacao
# 21      Professores da rede estadual decidiram manter ...            educacao
# 22      A categoria fez uma assembleia na tarde desta ...            educacao
# 23      Os manifestantes fechavam a pista sentido Cons...            educacao
# 24      Eles deverão passar pela rua da Consolação par...            educacao
# 25      A categoria, que tem a data-base em março, rei...            educacao
# 26      A greve já afeta a rotina de algumas escolas d...            educacao
# 27      Como a Folha mostrou nesta semana, há casos de...            educacao
# 28      Funcionários de uma das escolas visitadas pela...            educacao
# 29      Após ser questionada pela Folha, a Secretaria ...            educacao
# ...                                                   ...                 ...
# 191460  Lá funcionava a Fábrica de Criatividade, uma O...  empreendedorsocial
# 191461  Fuga, a irmã e uma amiga investiram suas econo...  empreendedorsocial
# 191462  "Os primeiros alunos sabiam que era um teste, ...  empreendedorsocial
# 191463  Em um ano, o negócio havia se expandido e alca...  empreendedorsocial
# 191464  Nesse meio tempo, a 4You2 se desvinculou da in...  empreendedorsocial
# 191465  Foi quando Fuga convidou um ex-colega de Aisec...  empreendedorsocial
# 191466  O americano Raley White, 27, entrou na 4You2 e...  empreendedorsocial
# 191467  A maior mudança foi o valor da mensalidade, qu...  empreendedorsocial
# 191468  "Não devemos subir mais do que isso", diz o ad...  empreendedorsocial
# 191469  Outra nova tática foi procurar funcionários ma...  empreendedorsocial
# 191470  White elaborou um manual de normatização de ce...  empreendedorsocial
# 191471  Até o fim de 2017, o plano é que haja 14 escol...  empreendedorsocial
# 191472  Fuga já foi procurado por comunidades de outra...  empreendedorsocial
# 191473  "Acho que deu certo por causa do preço, mas ta...  empreendedorsocial
# 191474  Nossa taxa de evasão fica bem abaixo do mercad...  empreendedorsocial
# 191475                     Nenhum professor é brasileiro.  empreendedorsocial
# 191476  Jovens estrangeiros que nunca deram aula apren...  empreendedorsocial
# 191477  "A seleção é muito parecida com a que a Aiesec...  empreendedorsocial
# 191478  Pegamos as propostas de valor que eles têm e u...  empreendedorsocial
# 191479  O processo seletivo dura três meses, e, segund...  empreendedorsocial
# 191480  A 4You2 trouxe ao Brasil mais de cem alunos-pr...  empreendedorsocial
# 191481  Há ainda seis refugiados que ensinam a língua ...  empreendedorsocial
# 191482  A empresa que começou com um capital de R$ 10 ...  empreendedorsocial
# 191483  Fuga comprou a parte das outras duas sócias po...  empreendedorsocial
# 191484  A equipe começou um processo de captação exter...  empreendedorsocial
# 191485  A transferência de algum poder para administra...  empreendedorsocial
# 191486  "Se eu resolvo cobrar mais, meu aluno vai ter ...  empreendedorsocial
# 191487  "Daí vou ter de pagar mais para o professor e ...  empreendedorsocial
# 191488           "Eu nunca consegui fazer um intercâmbio.  empreendedorsocial
# 191489                       Agora vivo em um", diz Fuga.  empreendedorsocial
#
#         TotalWords
# 0               11
# 1               25
# 2               27
# 3               38
# 4               33
# 5               40
# 6               24
# 7               43
# 8               31
# 9               11
# 10              25
# 11              25
# 12              20
# 13              16
# 14              41
# 15              10
# 16               9
# 17              20
# 18               4
# 19              13
# 20               2
# 21              14
# 22              23
# 23              38
# 24              12
# 25              48
# 26              13
# 27              36
# 28              25
# 29              22
# ...            ...
# 191460          22
# 191461          40
# 191462          19
# 191463          33
# 191464          38
# 191465          13
# 191466          19
# 191467          26
# 191468          15
# 191469          21
# 191470          37
# 191471          40
# 191472          19
# 191473          20
# 191474          13
# 191475           5
# 191476          19
# 191477          13
# 191478          17
# 191479          22
# 191480          30
# 191481          21
# 191482          22
# 191483          19
# 191484          18
# 191485          24
# 191486          31
# 191487          43
# 191488           8
# 191489           9
#
# [191490 rows x 3 columns]

# %%
X = train_extended_df[['text', 'TotalWords']]
Y = train_extended_df['label']

# %%
classifier.fit(X, Y)
# Out:
# Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=None,
#        transformer_list=[('text', Pipeline(memory=None,
#      steps=[('colext', TextSelector(field='text')), ('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='co...
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1))])
