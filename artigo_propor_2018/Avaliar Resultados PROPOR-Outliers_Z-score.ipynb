# %%
import json
import pandas as pd
from pathlib import Path
from pprint import pprint
import datetime
import time
from scipy import stats
import numpy as np
import matplotlib as plt

import pandas
import researchpy as rp
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp

# %matplotlib inline

# %%
TRAINING_ROUND = 'Training_Round'
EPOCHS = 'Epochs'
SCENARIO = 'Scenario'
EMBEDDING = 'Embedding'
TAGGING_SCHEME = 'Tagging_Scheme'
CAP_DIM = 'Capitalisation_Dim'
LOWER = 'Lower'
CHAR_DIM = 'Char_LSTM_Dim'
WORD_DIM = 'Word_LSTM_Dim'
PRECISION = 'Precision'
RECALL = 'Recall'
F1_SCORE = 'F1_Score'

# %%
columns = [TRAINING_ROUND, EPOCHS, SCENARIO, EMBEDDING, TAGGING_SCHEME, CAP_DIM, LOWER, CHAR_DIM, WORD_DIM, PRECISION, RECALL, F1_SCORE]

# %%
columns
# Out:
# ['Training_Round',
#  'Epochs',
#  'Scenario',
#  'Embedding',
#  'Tagging_Scheme',
#  'Capitalisation_Dim',
#  'Lower',
#  'Char_LSTM_Dim',
#  'Word_LSTM_Dim',
#  'Precision',
#  'Recall',
#  'F1_Score']

# %%
pd.set_option('display.max_columns', 1000)
training_data_df = pd.read_csv('resultados.csv')
training_data_df
# Out:
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 0                  0       5  selective  Wang2Vec            iob
# 1                  0       5  selective  Wang2Vec            iob
# 2                  0       5  selective  Wang2Vec            iob
# 3                  0       5  selective  Wang2Vec            iob
# 4                  0       5  selective  Wang2Vec            iob
# 5                  0       5  selective  Wang2Vec            iob
# 6                  0       5  selective  Wang2Vec            iob
# 7                  0       5  selective  Wang2Vec            iob
# 8                  0       5  selective  Wang2Vec            iob
# 9                  0       5  selective  Wang2Vec            iob
# 10                 0       5  selective  Wang2Vec            iob
# 11                 0       5  selective  Wang2Vec            iob
# 12                 0       5  selective  Wang2Vec            iob
# 13                 0       5  selective  Wang2Vec            iob
# 14                 0       5  selective  Wang2Vec            iob
# 15                 0       5  selective  Wang2Vec            iob
# 16                 0       5  selective  Wang2Vec          iobes
# 17                 0       5  selective  Wang2Vec          iobes
# 18                 0       5  selective  Wang2Vec          iobes
# 19                 0       5  selective  Wang2Vec          iobes
# 20                 0       5  selective  Wang2Vec          iobes
# 21                 0       5  selective  Wang2Vec          iobes
# 22                 0       5  selective  Wang2Vec          iobes
# 23                 0       5  selective  Wang2Vec          iobes
# 24                 0       5  selective  Wang2Vec          iobes
# 25                 0       5  selective  Wang2Vec          iobes
# 26                 0       5  selective  Wang2Vec          iobes
# 27                 0       5  selective  Wang2Vec          iobes
# 28                 0       5  selective  Wang2Vec          iobes
# 29                 0       5  selective  Wang2Vec          iobes
# ...              ...     ...        ...       ...            ...
# 1250               9       5  selective  Word2Vec            iob
# 1251               9       5  selective  Word2Vec            iob
# 1252               9       5  selective  Word2Vec            iob
# 1253               9       5  selective  Word2Vec            iob
# 1254               9       5  selective  Word2Vec            iob
# 1255               9       5  selective  Word2Vec            iob
# 1256               9       5  selective  Word2Vec            iob
# 1257               9       5  selective  Word2Vec            iob
# 1258               9       5  selective  Word2Vec            iob
# 1259               9       5  selective  Word2Vec            iob
# 1260               9       5  selective  Word2Vec            iob
# 1261               9       5  selective  Word2Vec            iob
# 1262               9       5  selective  Word2Vec            iob
# 1263               9       5  selective  Word2Vec            iob
# 1264               9       5  selective  Word2Vec          iobes
# 1265               9       5  selective  Word2Vec          iobes
# 1266               9       5  selective  Word2Vec          iobes
# 1267               9       5  selective  Word2Vec          iobes
# 1268               9       5  selective  Word2Vec          iobes
# 1269               9       5  selective  Word2Vec          iobes
# 1270               9       5  selective  Word2Vec          iobes
# 1271               9       5  selective  Word2Vec          iobes
# 1272               9       5  selective  Word2Vec          iobes
# 1273               9       5  selective  Word2Vec          iobes
# 1274               9       5  selective  Word2Vec          iobes
# 1275               9       5  selective  Word2Vec          iobes
# 1276               9       5  selective  Word2Vec          iobes
# 1277               9       5  selective  Word2Vec          iobes
# 1278               9       5  selective  Word2Vec          iobes
# 1279               9       5  selective  Word2Vec          iobes
#
#       Capitalisation_Dim  Lower  Char_LSTM_Dim  Word_LSTM_Dim  Precision  \
# 0                  False  False             25            100      58.95
# 1                  False  False             25            200      61.60
# 2                  False  False             50            100      66.50
# 3                  False  False             50            200      58.54
# 4                  False   True             25            100      66.28
# 5                  False   True             25            200      71.00
# 6                  False   True             50            100      70.14
# 7                  False   True             50            200      66.93
# 8                   True  False             25            100      58.62
# 9                   True  False             25            200      64.42
# 10                  True  False             50            100      66.29
# 11                  True  False             50            200      57.48
# 12                  True   True             25            100      70.32
# 13                  True   True             25            200      69.64
# 14                  True   True             50            100      69.42
# 15                  True   True             50            200      68.37
# 16                 False  False             25            100      62.34
# 17                 False  False             25            200      59.79
# 18                 False  False             50            100      68.57
# 19                 False  False             50            200      59.35
# 20                 False   True             25            100      67.04
# 21                 False   True             25            200      69.78
# 22                 False   True             50            100      67.37
# 23                 False   True             50            200       1.09
# 24                  True  False             25            100      64.54
# 25                  True  False             25            200      58.86
# 26                  True  False             50            100      61.45
# 27                  True  False             50            200      61.48
# 28                  True   True             25            100      68.14
# 29                  True   True             25            200      68.93
# ...                  ...    ...            ...            ...        ...
# 1250               False  False             50            100      56.50
# 1251               False  False             50            200      53.05
# 1252               False   True             25            100      52.88
# 1253               False   True             25            200      51.21
# 1254               False   True             50            100      48.90
# 1255               False   True             50            200      53.92
# 1256                True  False             25            100      60.26
# 1257                True  False             25            200      53.88
# 1258                True  False             50            100      56.27
# 1259                True  False             50            200      60.33
# 1260                True   True             25            100      52.93
# 1261                True   True             25            200      50.44
# 1262                True   True             50            100      46.86
# 1263                True   True             50            200      55.14
# 1264               False  False             25            100      59.74
# 1265               False  False             25            200      51.19
# 1266               False  False             50            100      59.56
# 1267               False  False             50            200      56.36
# 1268               False   True             25            100      47.82
# 1269               False   True             25            200      53.66
# 1270               False   True             50            100      51.79
# 1271               False   True             50            200      55.89
# 1272                True  False             25            100      57.79
# 1273                True  False             25            200      55.91
# 1274                True  False             50            100      58.84
# 1275                True  False             50            200      55.10
# 1276                True   True             25            100      51.59
# 1277                True   True             25            200      52.38
# 1278                True   True             50            100      49.53
# 1279                True   True             50            200      56.24
#
#       Recall  F1_Score
# 0      54.79     56.79
# 1      52.06     56.43
# 2      47.47     55.40
# 3      50.74     54.36
# 4      67.73     67.00
# 5      62.67     66.58
# 6      65.18     67.57
# 7      63.57     65.21
# 8      57.55     58.08
# 9      50.45     56.59
# 10     48.87     56.26
# 11     26.17     35.97
# 12     62.53     66.20
# 13     62.93     66.11
# 14     64.29     66.75
# 15     64.72     66.49
# 16     52.64     57.08
# 17     51.34     55.25
# 18     44.68     54.10
# 19     54.03     56.57
# 20     64.11     65.54
# 21     62.60     66.00
# 22     65.97     66.67
# 23      6.92      1.88
# 24     52.28     57.77
# 25     54.54     56.62
# 26     50.41     55.39
# 27     55.11     58.12
# 28     64.50     66.27
# 29     65.15     66.99
# ...      ...       ...
# 1250   53.78     55.11
# 1251   53.32     53.18
# 1252   50.02     51.41
# 1253   44.93     47.86
# 1254   38.26     42.93
# 1255   46.40     49.87
# 1256   49.80     54.53
# 1257   52.78     53.32
# 1258   55.18     55.72
# 1259   52.67     56.24
# 1260   48.23     50.47
# 1261   53.39     51.87
# 1262   52.67     49.59
# 1263   43.10     48.38
# 1264   50.59     54.79
# 1265   54.82     52.94
# 1266   51.85     55.43
# 1267   54.36     55.34
# 1268   46.47     47.14
# 1269   46.76     49.97
# 1270   52.81     52.30
# 1271   43.24     48.76
# 1272   50.95     54.15
# 1273   52.06     53.92
# 1274   53.35     55.96
# 1275   53.07     54.06
# 1276   43.06     46.94
# 1277   45.00     48.41
# 1278   46.83     48.14
# 1279   42.95     48.71
#
# [1280 rows x 12 columns]

# %%
training_data_df = training_data_df[training_data_df.Scenario == 'selective']
len(training_data_df)
# Out:
# 1280

# %%
z = np.abs(stats.zscore(training_data_df[F1_SCORE]))
print(z)
training_data_df = training_data_df[pd.Series([False if el > 3 else True for el in z]).values]
training_data_df
# Out:
# [0.13270249 0.10281247 0.01729379 ... 0.56307084 0.58548835 0.53816248]
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 0                  0       5  selective  Wang2Vec            iob
# 1                  0       5  selective  Wang2Vec            iob
# 2                  0       5  selective  Wang2Vec            iob
# 3                  0       5  selective  Wang2Vec            iob
# 4                  0       5  selective  Wang2Vec            iob
# 5                  0       5  selective  Wang2Vec            iob
# 6                  0       5  selective  Wang2Vec            iob
# 7                  0       5  selective  Wang2Vec            iob
# 8                  0       5  selective  Wang2Vec            iob
# 9                  0       5  selective  Wang2Vec            iob
# 10                 0       5  selective  Wang2Vec            iob
# 11                 0       5  selective  Wang2Vec            iob
# 12                 0       5  selective  Wang2Vec            iob
# 13                 0       5  selective  Wang2Vec            iob
# 14                 0       5  selective  Wang2Vec            iob
# 15                 0       5  selective  Wang2Vec            iob
# 16                 0       5  selective  Wang2Vec          iobes
# 17                 0       5  selective  Wang2Vec          iobes
# 18                 0       5  selective  Wang2Vec          iobes
# 19                 0       5  selective  Wang2Vec          iobes
# 20                 0       5  selective  Wang2Vec          iobes
# 21                 0       5  selective  Wang2Vec          iobes
# 22                 0       5  selective  Wang2Vec          iobes
# 24                 0       5  selective  Wang2Vec          iobes
# 25                 0       5  selective  Wang2Vec          iobes
# 26                 0       5  selective  Wang2Vec          iobes
# 27                 0       5  selective  Wang2Vec          iobes
# 28                 0       5  selective  Wang2Vec          iobes
# 29                 0       5  selective  Wang2Vec          iobes
# 30                 0       5  selective  Wang2Vec          iobes
# ...              ...     ...        ...       ...            ...
# 1250               9       5  selective  Word2Vec            iob
# 1251               9       5  selective  Word2Vec            iob
# 1252               9       5  selective  Word2Vec            iob
# 1253               9       5  selective  Word2Vec            iob
# 1254               9       5  selective  Word2Vec            iob
# 1255               9       5  selective  Word2Vec            iob
# 1256               9       5  selective  Word2Vec            iob
# 1257               9       5  selective  Word2Vec            iob
# 1258               9       5  selective  Word2Vec            iob
# 1259               9       5  selective  Word2Vec            iob
# 1260               9       5  selective  Word2Vec            iob
# 1261               9       5  selective  Word2Vec            iob
# 1262               9       5  selective  Word2Vec            iob
# 1263               9       5  selective  Word2Vec            iob
# 1264               9       5  selective  Word2Vec          iobes
# 1265               9       5  selective  Word2Vec          iobes
# 1266               9       5  selective  Word2Vec          iobes
# 1267               9       5  selective  Word2Vec          iobes
# 1268               9       5  selective  Word2Vec          iobes
# 1269               9       5  selective  Word2Vec          iobes
# 1270               9       5  selective  Word2Vec          iobes
# 1271               9       5  selective  Word2Vec          iobes
# 1272               9       5  selective  Word2Vec          iobes
# 1273               9       5  selective  Word2Vec          iobes
# 1274               9       5  selective  Word2Vec          iobes
# 1275               9       5  selective  Word2Vec          iobes
# 1276               9       5  selective  Word2Vec          iobes
# 1277               9       5  selective  Word2Vec          iobes
# 1278               9       5  selective  Word2Vec          iobes
# 1279               9       5  selective  Word2Vec          iobes
#
#       Capitalisation_Dim  Lower  Char_LSTM_Dim  Word_LSTM_Dim  Precision  \
# 0                  False  False             25            100      58.95
# 1                  False  False             25            200      61.60
# 2                  False  False             50            100      66.50
# 3                  False  False             50            200      58.54
# 4                  False   True             25            100      66.28
# 5                  False   True             25            200      71.00
# 6                  False   True             50            100      70.14
# 7                  False   True             50            200      66.93
# 8                   True  False             25            100      58.62
# 9                   True  False             25            200      64.42
# 10                  True  False             50            100      66.29
# 11                  True  False             50            200      57.48
# 12                  True   True             25            100      70.32
# 13                  True   True             25            200      69.64
# 14                  True   True             50            100      69.42
# 15                  True   True             50            200      68.37
# 16                 False  False             25            100      62.34
# 17                 False  False             25            200      59.79
# 18                 False  False             50            100      68.57
# 19                 False  False             50            200      59.35
# 20                 False   True             25            100      67.04
# 21                 False   True             25            200      69.78
# 22                 False   True             50            100      67.37
# 24                  True  False             25            100      64.54
# 25                  True  False             25            200      58.86
# 26                  True  False             50            100      61.45
# 27                  True  False             50            200      61.48
# 28                  True   True             25            100      68.14
# 29                  True   True             25            200      68.93
# 30                  True   True             50            100      67.96
# ...                  ...    ...            ...            ...        ...
# 1250               False  False             50            100      56.50
# 1251               False  False             50            200      53.05
# 1252               False   True             25            100      52.88
# 1253               False   True             25            200      51.21
# 1254               False   True             50            100      48.90
# 1255               False   True             50            200      53.92
# 1256                True  False             25            100      60.26
# 1257                True  False             25            200      53.88
# 1258                True  False             50            100      56.27
# 1259                True  False             50            200      60.33
# 1260                True   True             25            100      52.93
# 1261                True   True             25            200      50.44
# 1262                True   True             50            100      46.86
# 1263                True   True             50            200      55.14
# 1264               False  False             25            100      59.74
# 1265               False  False             25            200      51.19
# 1266               False  False             50            100      59.56
# 1267               False  False             50            200      56.36
# 1268               False   True             25            100      47.82
# 1269               False   True             25            200      53.66
# 1270               False   True             50            100      51.79
# 1271               False   True             50            200      55.89
# 1272                True  False             25            100      57.79
# 1273                True  False             25            200      55.91
# 1274                True  False             50            100      58.84
# 1275                True  False             50            200      55.10
# 1276                True   True             25            100      51.59
# 1277                True   True             25            200      52.38
# 1278                True   True             50            100      49.53
# 1279                True   True             50            200      56.24
#
#       Recall  F1_Score
# 0      54.79     56.79
# 1      52.06     56.43
# 2      47.47     55.40
# 3      50.74     54.36
# 4      67.73     67.00
# 5      62.67     66.58
# 6      65.18     67.57
# 7      63.57     65.21
# 8      57.55     58.08
# 9      50.45     56.59
# 10     48.87     56.26
# 11     26.17     35.97
# 12     62.53     66.20
# 13     62.93     66.11
# 14     64.29     66.75
# 15     64.72     66.49
# 16     52.64     57.08
# 17     51.34     55.25
# 18     44.68     54.10
# 19     54.03     56.57
# 20     64.11     65.54
# 21     62.60     66.00
# 22     65.97     66.67
# 24     52.28     57.77
# 25     54.54     56.62
# 26     50.41     55.39
# 27     55.11     58.12
# 28     64.50     66.27
# 29     65.15     66.99
# 30     65.54     66.73
# ...      ...       ...
# 1250   53.78     55.11
# 1251   53.32     53.18
# 1252   50.02     51.41
# 1253   44.93     47.86
# 1254   38.26     42.93
# 1255   46.40     49.87
# 1256   49.80     54.53
# 1257   52.78     53.32
# 1258   55.18     55.72
# 1259   52.67     56.24
# 1260   48.23     50.47
# 1261   53.39     51.87
# 1262   52.67     49.59
# 1263   43.10     48.38
# 1264   50.59     54.79
# 1265   54.82     52.94
# 1266   51.85     55.43
# 1267   54.36     55.34
# 1268   46.47     47.14
# 1269   46.76     49.97
# 1270   52.81     52.30
# 1271   43.24     48.76
# 1272   50.95     54.15
# 1273   52.06     53.92
# 1274   53.35     55.96
# 1275   53.07     54.06
# 1276   43.06     46.94
# 1277   45.00     48.41
# 1278   46.83     48.14
# 1279   42.95     48.71
#
# [1235 rows x 12 columns]

# %%
training_data_df.groupby([TAGGING_SCHEME]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                 count       mean       std    min    25%    50%    75%    max
# Tagging_Scheme
# iob             618.0  57.030437  7.469194  19.23  53.97  56.14  63.39  68.26
# iobes           617.0  56.940665  7.718509  19.73  54.10  56.43  63.36  67.99

# %%
training_data_df.groupby([EMBEDDING]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#            count       mean       std    min      25%     50%    75%    max
# Embedding
# Wang2Vec   305.0  60.004656  7.795033  19.23  55.9900  58.050  66.44  68.26
# FastText   305.0  59.104918  8.062926  21.27  56.1900  57.860  65.06  67.05
# Glove      309.0  57.932589  6.035712  19.73  54.8800  57.030  62.63  64.89
# Word2Vec   316.0  51.100032  4.469993  22.25  48.7975  51.545  54.43  56.92

# %%
training_data_df.groupby([CAP_DIM]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                     count      mean       std    min    25%    50%      75%  \
# Capitalisation_Dim
# True                625.0  57.27856  7.218754  19.73  54.14  56.46  63.5500
# False               610.0  56.68541  7.950705  19.23  53.90  56.15  63.1625
#
#                       max
# Capitalisation_Dim
# True                68.26
# False               68.07

# %%
training_data_df.groupby([CHAR_DIM]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                count       mean       std    min     25%    50%    75%    max
# Char_LSTM_Dim
# 25             617.0  57.163063  7.310514  19.73  54.050  56.24  63.39  68.26
# 50             618.0  56.808398  7.864590  19.23  54.045  56.26  63.37  68.07

# %%
training_data_df.groupby([WORD_DIM]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                count       mean       std    min    25%     50%    75%    max
# Word_LSTM_Dim
# 100            626.0  57.135272  7.611859  19.23  54.31  56.375  63.37  68.26
# 200            609.0  56.831724  7.574353  19.73  53.82  56.130  63.39  68.07

# %%
training_data_df.groupby([LOWER]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#        count       mean       std    min      25%    50%     75%    max
# Lower
# True   612.0  59.713399  8.241165  22.55  50.5375  63.40  65.740  68.26
# False  623.0  54.305939  5.754651  19.23  54.3100  55.47  56.475  59.82

# %%
training_data_df.groupby([EMBEDDING, TAGGING_SCHEME, CAP_DIM, WORD_DIM, CHAR_DIM, LOWER]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                                                                                count  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True    10.0
#                                             200           50            True     6.0
#           iobes          True               200           25            True    10.0
#           iob            True               100           50            True    10.0
#           iobes          True               100           25            True    10.0
#                                                           50            True    10.0
#                                             200           50            True    10.0
#                          False              200           50            True     9.0
#                                             100           25            True     9.0
#           iob            False              200           25            True     9.0
#                                             100           25            True     8.0
#           iobes          False              200           25            True     9.0
# FastText  iob            True               100           25            True    10.0
#                                             200           25            True     9.0
#                          False              100           25            True    10.0
#           iobes          False              200           25            True     9.0
#                          True               200           25            True    10.0
#           iob            False              200           50            True    10.0
#           iobes          True               100           50            True     8.0
#                          False              100           25            True    10.0
#                                             200           50            True     8.0
# Wang2Vec  iob            True               100           25            True    10.0
# FastText  iob            True               200           50            True    10.0
#                          False              100           50            True     9.0
#           iobes          True               100           25            True    10.0
# Glove     iob            True               100           50            True    10.0
#                                                           25            True     9.0
#                          False              100           25            True     9.0
# Wang2Vec  iob            True               200           50            True    10.0
# Glove     iobes          True               100           25            True    10.0
# ...                                                                              ...
# Word2Vec  iob            True               200           25            False   10.0
# FastText  iob            True               200           25            False   10.0
#           iobes          False              200           25            False   10.0
# Glove     iobes          False              100           50            False   10.0
#           iob            True               100           50            False   10.0
# Wang2Vec  iob            False              100           50            False   10.0
# Glove     iobes          False              200           25            False    9.0
# Word2Vec  iob            False              100           25            False   10.0
# Glove     iobes          True               200           25            False    9.0
# Word2Vec  iobes          True               200           50            False    9.0
# FastText  iob            False              200           50            False   10.0
# Wang2Vec  iob            True               200           50            False    9.0
# Word2Vec  iob            False              100           25            True    10.0
#           iobes          True               100           50            True    10.0
#           iob            False              100           50            False   10.0
#                                             200           50            True    10.0
#           iobes          False              200           50            True    10.0
#                                             100           50            True    10.0
#           iob            True               100           25            True    10.0
#           iobes          True               200           50            True    10.0
#           iob            False              100           50            True    10.0
#           iobes          True               100           25            True    10.0
#           iob            True               200           25            True    10.0
#                                             100           50            True    10.0
#                          False              200           25            True     9.0
#           iobes          False              200           25            True    10.0
#                                             100           25            True    10.0
#           iob            True               200           50            True    10.0
#           iobes          True               200           25            True    10.0
# FastText  iobes          False              100           25            False   10.0
#
#                                                                                     mean  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   66.901000
#                                             200           50            True   66.818333
#           iobes          True               200           25            True   66.788000
#           iob            True               100           50            True   66.668000
#           iobes          True               100           25            True   66.550000
#                                                           50            True   66.446000
#                                             200           50            True   66.328000
#                          False              200           50            True   66.315556
#                                             100           25            True   66.250000
#           iob            False              200           25            True   66.227778
#                                             100           25            True   66.218750
#           iobes          False              200           25            True   65.940000
# FastText  iob            True               100           25            True   65.836000
#                                             200           25            True   65.278889
#                          False              100           25            True   65.259000
#           iobes          False              200           25            True   64.811111
#                          True               200           25            True   64.729000
#           iob            False              200           50            True   64.634000
#           iobes          True               100           50            True   64.513750
#                          False              100           25            True   64.368000
#                                             200           50            True   63.966250
# Wang2Vec  iob            True               100           25            True   63.950000
# FastText  iob            True               200           50            True   63.393000
#                          False              100           50            True   63.372222
#           iobes          True               100           25            True   63.310000
# Glove     iob            True               100           50            True   62.995000
#                                                           25            True   62.816667
#                          False              100           25            True   62.705556
# Wang2Vec  iob            True               200           50            True   62.694000
# Glove     iobes          True               100           25            True   62.613000
# ...                                                                                  ...
# Word2Vec  iob            True               200           25            False  53.460000
# FastText  iob            True               200           25            False  53.108000
#           iobes          False              200           25            False  52.703000
# Glove     iobes          False              100           50            False  52.694000
#           iob            True               100           50            False  52.489000
# Wang2Vec  iob            False              100           50            False  52.309000
# Glove     iobes          False              200           25            False  51.667778
# Word2Vec  iob            False              100           25            False  51.509000
# Glove     iobes          True               200           25            False  51.362222
# Word2Vec  iobes          True               200           50            False  50.858889
# FastText  iob            False              200           50            False  50.019000
# Wang2Vec  iob            True               200           50            False  49.980000
# Word2Vec  iob            False              100           25            True   49.637000
#           iobes          True               100           50            True   49.536000
#           iob            False              100           50            False  49.241000
#                                             200           50            True   49.153000
#           iobes          False              200           50            True   49.137000
#                                             100           50            True   49.136000
#           iob            True               100           25            True   49.032000
#           iobes          True               200           50            True   48.987000
#           iob            False              100           50            True   48.679000
#           iobes          True               100           25            True   48.598000
#           iob            True               200           25            True   48.434000
#                                             100           50            True   48.404000
#                          False              200           25            True   48.282222
#           iobes          False              200           25            True   48.069000
#                                             100           25            True   47.938000
#           iob            True               200           50            True   47.849000
#           iobes          True               200           25            True   47.344000
# FastText  iobes          False              100           25            False  45.852000
#
#                                                                                      std  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True    0.721641
#                                             200           50            True    1.050950
#           iobes          True               200           25            True    0.771432
#           iob            True               100           50            True    0.790974
#           iobes          True               100           25            True    1.105039
#                                                           50            True    1.103260
#                                             200           50            True    0.419571
#                          False              200           50            True    0.910647
#                                             100           25            True    0.560134
#           iob            False              200           25            True    0.446760
#                                             100           25            True    1.454701
#           iobes          False              200           25            True    1.030728
# FastText  iob            True               100           25            True    0.611777
#                                             200           25            True    0.634556
#                          False              100           25            True    0.888988
#           iobes          False              200           25            True    1.182449
#                          True               200           25            True    1.051522
#           iob            False              200           50            True    0.748913
#           iobes          True               100           50            True    2.098897
#                          False              100           25            True    4.215779
#                                             200           50            True    3.022610
# Wang2Vec  iob            True               100           25            True    9.360411
# FastText  iob            True               200           50            True    3.937312
#                          False              100           50            True    4.827437
#           iobes          True               100           25            True    6.793863
# Glove     iob            True               100           50            True    0.973165
#                                                           25            True    1.021164
#                          False              100           25            True    0.884818
# Wang2Vec  iob            True               200           50            True   12.344834
# Glove     iobes          True               100           25            True    1.207229
# ...                                                                                  ...
# Word2Vec  iob            True               200           25            False   1.347401
# FastText  iob            True               200           25            False   8.982280
#           iobes          False              200           25            False  10.397058
# Glove     iobes          False              100           50            False   7.016845
#           iob            True               100           50            False   7.381545
# Wang2Vec  iob            False              100           50            False  11.671200
# Glove     iobes          False              200           25            False  10.433670
# Word2Vec  iob            False              100           25            False   9.722452
# Glove     iobes          True               200           25            False  11.902336
# Word2Vec  iobes          True               200           50            False   9.160808
# FastText  iob            False              200           50            False  13.364860
# Wang2Vec  iob            True               200           50            False  12.695439
# Word2Vec  iob            False              100           25            True    1.567893
#           iobes          True               100           50            True    0.926921
#           iob            False              100           50            False  12.836257
#                                             200           50            True    1.987562
#           iobes          False              200           50            True    1.437653
#                                             100           50            True    2.135698
#           iob            True               100           25            True    1.725346
#           iobes          True               200           50            True    1.344818
#           iob            False              100           50            True    2.778243
#           iobes          True               100           25            True    1.155939
#           iob            True               200           25            True    1.984737
#                                             100           50            True    1.931644
#                          False              200           25            True    2.069860
#           iobes          False              200           25            True    2.013617
#                                             100           25            True    2.347967
#           iob            True               200           50            True    3.496673
#           iobes          True               200           25            True    2.079531
# FastText  iobes          False              100           25            False  16.261060
#
#                                                                                  min  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   65.44
#                                             200           50            True   65.21
#           iobes          True               200           25            True   65.54
#           iob            True               100           50            True   65.00
#           iobes          True               100           25            True   63.99
#                                                           50            True   63.63
#                                             200           50            True   65.60
#                          False              200           50            True   64.87
#                                             100           25            True   65.51
#           iob            False              200           25            True   65.47
#                                             100           25            True   63.18
#           iobes          False              200           25            True   64.15
# FastText  iob            True               100           25            True   64.78
#                                             200           25            True   64.14
#                          False              100           25            True   64.14
#           iobes          False              200           25            True   63.14
#                          True               200           25            True   63.11
#           iob            False              200           50            True   63.09
#           iobes          True               100           50            True   59.82
#                          False              100           25            True   52.44
#                                             200           50            True   56.80
# Wang2Vec  iob            True               100           25            True   37.49
# FastText  iob            True               200           50            True   52.43
#                          False              100           50            True   50.69
#           iobes          True               100           25            True   44.09
# Glove     iob            True               100           50            True   61.44
#                                                           25            True   61.08
#                          False              100           25            True   61.61
# Wang2Vec  iob            True               200           50            True   27.58
# Glove     iobes          True               100           25            True   59.37
# ...                                                                              ...
# Word2Vec  iob            True               200           25            False  51.92
# FastText  iob            True               200           25            False  27.68
#           iobes          False              200           25            False  23.25
# Glove     iobes          False              100           50            False  33.18
#           iob            True               100           50            False  31.61
# Wang2Vec  iob            False              100           50            False  19.23
# Glove     iobes          False              200           25            False  23.98
# Word2Vec  iob            False              100           25            False  24.07
# Glove     iobes          True               200           25            False  19.73
# Word2Vec  iobes          True               200           50            False  26.59
# FastText  iob            False              200           50            False  21.65
# Wang2Vec  iob            True               200           50            False  21.36
# Word2Vec  iob            False              100           25            True   46.85
#           iobes          True               100           50            True   48.14
#           iob            False              100           50            False  22.25
#                                             200           50            True   46.26
#           iobes          False              200           50            True   46.45
#                                             100           50            True   45.68
#           iob            True               100           25            True   45.96
#           iobes          True               200           50            True   46.85
#           iob            False              100           50            True   42.93
#           iobes          True               100           25            True   46.94
#           iob            True               200           25            True   44.34
#                                             100           50            True   45.23
#                          False              200           25            True   45.58
#           iobes          False              200           25            True   44.33
#                                             100           25            True   42.97
#           iob            True               200           50            True   38.92
#           iobes          True               200           25            True   43.81
# FastText  iobes          False              100           25            False  21.27
#
#                                                                                    25%  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   66.4250
#                                             200           50            True   66.2075
#           iobes          True               200           25            True   66.2750
#           iob            True               100           50            True   66.3300
#           iobes          True               100           25            True   66.2625
#                                                           50            True   66.3150
#                                             200           50            True   66.2125
#                          False              200           50            True   66.1600
#                                             100           25            True   65.6300
#           iob            False              200           25            True   65.8600
#                                             100           25            True   65.6825
#           iobes          False              200           25            True   65.7200
# FastText  iob            True               100           25            True   65.4750
#                                             200           25            True   65.1700
#                          False              100           25            True   64.5925
#           iobes          False              200           25            True   63.7100
#                          True               200           25            True   64.3175
#           iob            False              200           50            True   64.2075
#           iobes          True               100           50            True   64.3475
#                          False              100           25            True   65.3025
#                                             200           50            True   63.8550
# Wang2Vec  iob            True               100           25            True   65.7650
# FastText  iob            True               200           50            True   63.7275
#                          False              100           50            True   64.4500
#           iobes          True               100           25            True   64.9150
# Glove     iob            True               100           50            True   62.4550
#                                                           25            True   62.0700
#                          False              100           25            True   61.8200
# Wang2Vec  iob            True               200           50            True   66.1375
# Glove     iobes          True               100           25            True   62.6825
# ...                                                                                ...
# Word2Vec  iob            True               200           25            False  52.3600
# FastText  iob            True               200           25            False  54.9150
#           iobes          False              200           25            False  54.8925
# Glove     iobes          False              100           50            False  54.7175
#           iob            True               100           50            False  53.9025
# Wang2Vec  iob            False              100           50            False  55.3250
# Glove     iobes          False              200           25            False  54.1100
# Word2Vec  iob            False              100           25            False  53.7850
# Glove     iobes          True               200           25            False  54.3300
# Word2Vec  iobes          True               200           50            False  52.6900
# FastText  iob            False              200           50            False  55.8400
# Wang2Vec  iob            True               200           50            False  53.8700
# Word2Vec  iob            False              100           25            True   48.3575
#           iobes          True               100           50            True   48.9625
#           iob            False              100           50            False  52.8250
#                                             200           50            True   48.0000
#           iobes          False              200           50            True   48.7975
#                                             100           50            True   47.5950
#           iob            True               100           25            True   47.9875
#           iobes          True               200           50            True   47.9775
#           iob            False              100           50            True   48.2175
#           iobes          True               100           25            True   47.5475
#           iob            True               200           25            True   47.8150
#                                             100           50            True   47.6000
#                          False              200           25            True   47.2500
#           iobes          False              200           25            True   46.5800
#                                             100           25            True   47.3250
#           iob            True               200           50            True   47.2500
#           iobes          True               200           25            True   46.2025
# FastText  iobes          False              100           25            False  31.6250
#
#                                                                                   50%  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   67.105
#                                             200           50            True   67.155
#           iobes          True               200           25            True   66.845
#           iob            True               100           50            True   66.755
#           iobes          True               100           25            True   66.440
#                                                           50            True   66.630
#                                             200           50            True   66.460
#                          False              200           50            True   66.180
#                                             100           25            True   66.470
#           iob            False              200           25            True   66.250
#                                             100           25            True   66.685
#           iobes          False              200           25            True   66.000
# FastText  iob            True               100           25            True   65.780
#                                             200           25            True   65.270
#                          False              100           25            True   65.140
#           iobes          False              200           25            True   65.040
#                          True               200           25            True   64.425
#           iob            False              200           50            True   64.765
#           iobes          True               100           50            True   64.640
#                          False              100           25            True   65.670
#                                             200           50            True   65.025
# Wang2Vec  iob            True               100           25            True   66.830
# FastText  iob            True               200           50            True   64.360
#                          False              100           50            True   64.890
#           iobes          True               100           25            True   64.985
# Glove     iob            True               100           50            True   62.900
#                                                           25            True   63.040
#                          False              100           25            True   62.920
# Wang2Vec  iob            True               200           50            True   66.570
# Glove     iobes          True               100           25            True   62.785
# ...                                                                               ...
# Word2Vec  iob            True               200           25            False  53.295
# FastText  iob            True               200           25            False  55.745
#           iobes          False              200           25            False  55.565
# Glove     iobes          False              100           50            False  54.845
#           iob            True               100           50            False  54.755
# Wang2Vec  iob            False              100           50            False  55.505
# Glove     iobes          False              200           25            False  55.360
# Word2Vec  iob            False              100           25            False  54.275
# Glove     iobes          True               200           25            False  55.340
# Word2Vec  iobes          True               200           50            False  53.980
# FastText  iob            False              200           50            False  56.090
# Wang2Vec  iob            True               200           50            False  55.990
# Word2Vec  iob            False              100           25            True   50.125
#           iobes          True               100           50            True   49.285
#           iob            False              100           50            False  55.075
#                                             200           50            True   48.990
#           iobes          False              200           50            True   49.225
#                                             100           50            True   49.685
#           iob            True               100           25            True   49.860
#           iobes          True               200           50            True   49.010
#           iob            False              100           50            True   49.380
#           iobes          True               100           25            True   48.825
#           iob            True               200           25            True   48.290
#                                             100           50            True   48.825
#                          False              200           25            True   47.860
#           iobes          False              200           25            True   48.545
#                                             100           25            True   48.005
#           iob            True               200           50            True   48.515
#           iobes          True               200           25            True   48.105
# FastText  iobes          False              100           25            False  55.400
#
#                                                                                    75%  \
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   67.4925
#                                             200           50            True   67.3600
#           iobes          True               200           25            True   67.2000
#           iob            True               100           50            True   67.2925
#           iobes          True               100           25            True   67.2775
#                                                           50            True   66.7175
#                                             200           50            True   66.6125
#                          False              200           50            True   66.8500
#                                             100           25            True   66.6300
#           iob            False              200           25            True   66.5100
#                                             100           25            True   67.0775
#           iobes          False              200           25            True   66.3100
# FastText  iob            True               100           25            True   66.1875
#                                             200           25            True   65.7000
#                          False              100           25            True   65.7100
#           iobes          False              200           25            True   65.6800
#                          True               200           25            True   65.3800
#           iob            False              200           50            True   65.0975
#           iobes          True               100           50            True   65.9900
#                          False              100           25            True   65.9750
#                                             200           50            True   65.6200
# Wang2Vec  iob            True               100           25            True   67.7900
# FastText  iob            True               200           50            True   65.0100
#                          False              100           50            True   65.3500
#           iobes          True               100           25            True   65.5475
# Glove     iob            True               100           50            True   63.4800
#                                                           25            True   63.4000
#                          False              100           25            True   63.1200
# Wang2Vec  iob            True               200           50            True   66.7950
# Glove     iobes          True               100           25            True   63.2850
# ...                                                                                ...
# Word2Vec  iob            True               200           25            False  54.6050
# FastText  iob            True               200           25            False  56.5575
#           iobes          False              200           25            False  56.6500
# Glove     iobes          False              100           50            False  54.9925
#           iob            True               100           50            False  55.3500
# Wang2Vec  iob            False              100           50            False  56.0575
# Glove     iobes          False              200           25            False  55.7600
# Word2Vec  iob            False              100           25            False  55.2725
# Glove     iobes          True               200           25            False  56.1100
# Word2Vec  iobes          True               200           50            False  54.0600
# FastText  iob            False              200           50            False  56.4650
# Wang2Vec  iob            True               200           50            False  57.0100
# Word2Vec  iob            False              100           25            True   50.7925
#           iobes          True               100           50            True   50.2425
#           iob            False              100           50            False  56.1125
#                                             200           50            True   50.2900
#           iobes          False              200           50            True   50.0500
#                                             100           50            True   49.8950
#           iob            True               100           25            True   50.2625
#           iobes          True               200           50            True   50.0975
#           iob            False              100           50            True   50.1675
#           iobes          True               100           25            True   49.4350
#           iob            True               200           25            True   49.3700
#                                             100           50            True   49.4825
#                          False              200           25            True   49.2100
#           iobes          False              200           25            True   49.7625
#                                             100           25            True   49.4400
#           iob            True               200           50            True   49.4850
#           iobes          True               200           25            True   48.7625
# FastText  iobes          False              100           25            False  56.2350
#
#                                                                                  max
# Embedding Tagging_Scheme Capitalisation_Dim Word_LSTM_Dim Char_LSTM_Dim Lower
# Wang2Vec  iob            False              100           50            True   67.69
#                                             200           50            True   68.07
#           iobes          True               200           25            True   67.99
#           iob            True               100           50            True   67.64
#           iobes          True               100           25            True   67.87
#                                                           50            True   67.79
#                                             200           50            True   66.78
#                          False              200           50            True   67.94
#                                             100           25            True   66.92
#           iob            False              200           25            True   66.93
#                                             100           25            True   67.74
#           iobes          False              200           25            True   67.60
# FastText  iob            True               100           25            True   66.90
#                                             200           25            True   66.02
#                          False              100           25            True   66.78
#           iobes          False              200           25            True   66.58
#                          True               200           25            True   66.42
#           iob            False              200           50            True   65.59
#           iobes          True               100           50            True   66.40
#                          False              100           25            True   66.42
#                                             200           50            True   65.96
# Wang2Vec  iob            True               100           25            True   68.26
# FastText  iob            True               200           50            True   66.07
#                          False              100           50            True   66.18
#           iobes          True               100           25            True   67.05
# Glove     iob            True               100           50            True   64.89
#                                                           25            True   64.32
#                          False              100           25            True   64.04
# Wang2Vec  iob            True               200           50            True   67.22
# Glove     iobes          True               100           25            True   63.60
# ...                                                                              ...
# Word2Vec  iob            True               200           25            False  55.65
# FastText  iob            True               200           25            False  57.48
#           iobes          False              200           25            False  57.56
# Glove     iobes          False              100           50            False  56.97
#           iob            True               100           50            False  55.86
# Wang2Vec  iob            False              100           50            False  58.28
# Glove     iobes          False              200           25            False  56.34
# Word2Vec  iob            False              100           25            False  56.69
# Glove     iobes          True               200           25            False  56.44
# Word2Vec  iobes          True               200           50            False  55.49
# FastText  iob            False              200           50            False  56.98
# Wang2Vec  iob            True               200           50            False  58.05
# Word2Vec  iob            False              100           25            True   51.41
#           iobes          True               100           50            True   51.09
#           iob            False              100           50            False  56.92
#                                             200           50            True   52.42
#           iobes          False              200           50            True   51.18
#                                             100           50            True   52.30
#           iob            True               100           25            True   50.55
#           iobes          True               200           50            True   50.94
#           iob            False              100           50            True   51.92
#           iobes          True               100           25            True   50.18
#           iob            True               200           25            True   51.87
#                                             100           50            True   51.56
#                          False              200           25            True   51.71
#           iobes          False              200           25            True   50.50
#                                             100           25            True   51.53
#           iob            True               200           50            True   52.18
#           iobes          True               200           25            True   49.57
# FastText  iobes          False              100           25            False  58.10
#
# [128 rows x 8 columns]

# %%
training_data_df.groupby([TRAINING_ROUND]).describe()[F1_SCORE].sort_values(by='mean', ascending=False)
# Out:
#                 count       mean       std    min      25%     50%     75%  \
# Training_Round
# 0               125.0  57.475200  6.581119  29.93  54.4700  56.500  63.170
# 4               121.0  57.434298  6.212425  36.85  53.9700  56.480  63.400
# 2               125.0  57.322080  7.756478  22.25  54.6800  56.350  64.040
# 9               125.0  57.234880  6.703790  27.68  54.3100  56.330  63.120
# 1               124.0  57.164355  7.429988  21.65  54.1025  55.815  63.390
# 6               125.0  57.145600  7.490060  24.07  54.1500  56.510  63.270
# 3               123.0  56.678130  8.296802  24.32  54.0200  56.170  63.575
# 8               124.0  56.676613  8.047166  21.51  53.1575  56.080  63.355
# 7               122.0  56.365164  7.958107  19.73  53.3200  56.050  62.620
# 5               121.0  56.332149  9.178500  19.23  53.6800  56.030  63.310
#
#                   max
# Training_Round
# 0               67.57
# 4               68.26
# 2               68.07
# 9               67.87
# 1               67.99
# 6               67.74
# 3               67.79
# 8               67.73
# 7               67.53
# 5               67.86

# %%
rp.summary_cont(training_data_df[F1_SCORE])
# Out:
#    Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0  F1_Score  1235.0  56.985587  7.591828  0.216029  56.561761  57.409413

# %%
rp.summary_cont(training_data_df.groupby(EMBEDDING))[F1_SCORE]
# Out:
#              N       Mean        SD        SE  95% Conf.   Interval
# Embedding
# FastText   305  59.104918  8.062926  0.461682  58.200022  60.009814
# Glove      309  57.932589  6.035712  0.343360  57.259604  58.605574
# Wang2Vec   305  60.004656  7.795033  0.446342  59.129825  60.879487
# Word2Vec   316  51.100032  4.469993  0.251457  50.607176  51.592887

# %%
print(F1_SCORE, EMBEDDING, TAGGING_SCHEME, CAP_DIM, CHAR_DIM, WORD_DIM, LOWER)
# Out:
# F1_Score Embedding Tagging_Scheme Capitalisation_Dim Char_LSTM_Dim Word_LSTM_Dim Lower

# %%
# Fits the model with the interaction term
# This will also automatically include the main effects for each factor
model = ols('F1_Score ~ C(Embedding)*C(Tagging_Scheme)*C(Capitalisation_Dim)*C(Char_LSTM_Dim)*C(Word_LSTM_Dim)*C(Lower)', training_data_df).fit()

# Seeing if the overall model is significant
print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .20f}")
# Out:
# Overall model F( 127, 1107) =  11.344, p =  0.00000000000000000000

# %%
model.mse_model, model.mse_resid, model.mse_total
# Out:
# (316.6834896190153, 27.916753629428882, 57.63585854894061)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               F1_Score   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     11.34
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):          5.63e-130
# Time:                        22:23:00   Log-Likelihood:                -3740.6
# No. Observations:                1235   AIC:                             7737.
# Df Residuals:                    1107   BIC:                             8392.
# Df Model:                         127
# Covariance Type:            nonrobust
# =====================================================================================================================================================================================================================
#                                                                                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                                                            56.7950      1.671     33.992      0.000      53.517      60.073
# C(Embedding)[T.Glove]                                                                                                                                -1.1490      2.363     -0.486      0.627      -5.785       3.487
# C(Embedding)[T.Wang2Vec]                                                                                                                             -1.1730      2.363     -0.496      0.620      -5.809       3.463
# C(Embedding)[T.Word2Vec]                                                                                                                             -5.2860      2.363     -2.237      0.025      -9.922      -0.650
# C(Tagging_Scheme)[T.iobes]                                                                                                                          -10.9430      2.363     -4.631      0.000     -15.579      -6.307
# C(Capitalisation_Dim)[T.True]                                                                                                                        -0.5390      2.363     -0.228      0.820      -5.175       4.097
# C(Char_LSTM_Dim)[T.50]                                                                                                                               -0.4817      2.428     -0.198      0.843      -5.245       4.282
# C(Word_LSTM_Dim)[T.200]                                                                                                                              -1.3888      2.506     -0.554      0.580      -6.306       3.529
# C(Lower)[T.True]                                                                                                                                      8.4640      2.363      3.582      0.000       3.828      13.100
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]                                                                                                     10.4120      3.342      3.116      0.002       3.855      16.969
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]                                                                                                   9.3677      3.388      2.765      0.006       2.721      16.015
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]                                                                                                  13.5740      3.342      4.062      0.000       7.017      20.131
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]                                                                                                  -0.3020      3.342     -0.090      0.928      -6.859       6.255
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]                                                                                               -0.1670      3.342     -0.050      0.960      -6.724       6.390
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]                                                                                                3.2920      3.342      0.985      0.325      -3.265       9.849
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                                             10.6290      3.342      3.181      0.002       4.072      17.186
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]                                                                                                         -0.5233      3.388     -0.154      0.877      -7.170       6.124
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]                                                                                                      -2.8313      3.388     -0.836      0.403      -9.478       3.816
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]                                                                                                      -1.7863      3.388     -0.527      0.598      -8.433       4.861
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                                                    11.1108      3.433      3.236      0.001       4.374      17.847
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                                                  0.8787      3.388      0.259      0.795      -5.768       7.526
# C(Embedding)[T.Glove]:C(Word_LSTM_Dim)[T.200]                                                                                                        -0.2172      3.489     -0.062      0.950      -7.064       6.629
# C(Embedding)[T.Wang2Vec]:C(Word_LSTM_Dim)[T.200]                                                                                                      1.0298      3.445      0.299      0.765      -5.729       7.788
# C(Embedding)[T.Word2Vec]:C(Word_LSTM_Dim)[T.200]                                                                                                      3.6788      3.445      1.068      0.286      -3.080      10.437
# C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                                                    8.2398      3.445      2.392      0.017       1.481      14.998
# C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                                                -1.7592      3.445     -0.511      0.610      -8.518       4.999
# C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                                                       -4.9056      3.489     -1.406      0.160     -11.752       1.941
# C(Embedding)[T.Glove]:C(Lower)[T.True]                                                                                                               -1.4044      3.388     -0.415      0.679      -8.052       5.243
# C(Embedding)[T.Wang2Vec]:C(Lower)[T.True]                                                                                                             2.1328      3.445      0.619      0.536      -4.626       8.891
# C(Embedding)[T.Word2Vec]:C(Lower)[T.True]                                                                                                           -10.3360      3.342     -3.093      0.002     -16.893      -3.779
# C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                                          10.0520      3.342      3.008      0.003       3.495      16.609
# C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                                                        1.1160      3.342      0.334      0.738      -5.441       7.673
# C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                                              -1.4051      3.433     -0.409      0.682      -8.141       5.331
# C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                                             -1.7480      3.489     -0.501      0.616      -8.594       5.098
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                       -8.9920      4.726     -1.903      0.057     -18.265       0.281
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                    -6.9063      4.791     -1.442      0.150     -16.307       2.494
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]                                                                   -13.2900      4.726     -2.812      0.005     -22.563      -4.017
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                             -12.5268      4.791     -2.615      0.009     -21.927      -3.126
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                           -6.1544      4.823     -1.276      0.202     -15.618       3.309
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]                                                                           -7.4138      4.791     -1.547      0.122     -16.814       1.987
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                           -2.1897      4.759     -0.460      0.645     -11.526       7.147
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                         3.4013      4.759      0.715      0.475      -5.935      12.738
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                         2.1563      4.759      0.453      0.651      -7.180      11.493
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                                     -10.7578      4.791     -2.245      0.025     -20.158      -1.357
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                            -10.0810      4.863     -2.073      0.038     -19.623      -0.539
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                          -6.4174      4.863     -1.320      0.187     -15.960       3.125
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]                                                                         -10.9618      4.799     -2.284      0.023     -20.378      -1.545
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                           2.8122      4.831      0.582      0.561      -6.667      12.292
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                        3.1032      4.799      0.647      0.518      -6.313      12.520
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                       -1.3328      4.799     -0.278      0.781     -10.749       8.084
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                                     -4.4282      4.831     -0.917      0.360     -13.908       5.051
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                                  5.9236      4.863      1.218      0.223      -3.619      15.466
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                               8.5736      4.831      1.775      0.076      -0.906      18.053
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                               7.4196      4.831      1.536      0.125      -2.060      16.899
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                            -2.1788      4.895     -0.445      0.656     -11.783       7.426
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                                          6.4666      4.831      1.338      0.181      -3.013      15.946
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                   -10.9566      4.791     -2.287      0.022     -20.357      -1.556
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                 -8.4454      4.863     -1.737      0.083     -17.988       1.097
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Lower)[T.True]                                                                                -14.3820      4.726     -3.043      0.002     -23.655      -5.109
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                                 -0.1639      4.791     -0.034      0.973      -9.564       9.237
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                              -2.6788      4.799     -0.558      0.577     -12.095       6.738
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                              -4.4740      4.726     -0.947      0.344     -13.747       4.799
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                                           -12.2640      4.726     -2.595      0.010     -21.537      -2.991
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                         2.2556      4.823      0.468      0.640      -7.208      11.719
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                      5.4004      4.863      1.110      0.267      -4.142      14.943
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                      2.7151      4.791      0.567      0.571      -6.685      12.116
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                  -13.7200      4.823     -2.845      0.005     -23.184      -4.256
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                                                -3.2849      4.791     -0.686      0.493     -12.685       6.116
# C(Embedding)[T.Glove]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                        2.8325      4.895      0.579      0.563      -6.772      12.437
# C(Embedding)[T.Wang2Vec]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                     2.1161      4.935      0.429      0.668      -7.566      11.798
# C(Embedding)[T.Word2Vec]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                    -1.8968      4.863     -0.390      0.697     -11.439       7.646
# C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                  -4.6599      4.863     -0.958      0.338     -14.202       4.882
# C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                4.3389      4.863      0.892      0.372      -5.203      13.881
# C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                                       9.3041      4.895      1.901      0.058      -0.301      18.909
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                                13.7658      6.730      2.046      0.041       0.562      26.970
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                              3.2621      6.776      0.481      0.630     -10.032      16.556
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]                                              6.5528      6.730      0.974      0.330      -6.651      19.757
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                                2.2736      6.827      0.333      0.739     -11.121      15.669
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                             0.4935      6.827      0.072      0.942     -12.901      13.888
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]                                             8.2662      6.758      1.223      0.222      -4.994      21.527
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                       6.9970      6.850      1.022      0.307      -6.442      20.436
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                   -4.3966      6.850     -0.642      0.521     -17.836       9.043
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                   -1.6502      6.804     -0.243      0.808     -15.001      11.700
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                   -4.6966      6.781     -0.693      0.489     -18.002       8.609
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                               -17.0226      6.781     -2.510      0.012     -30.328      -3.717
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                                -8.5226      6.810     -1.252      0.211     -21.884       4.839
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                                              -2.2128      6.827     -0.324      0.746     -15.608      11.182
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                      11.8589      6.753      1.756      0.079      -1.390      25.108
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                   11.1101      6.804      1.633      0.103      -2.240      24.460
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Lower)[T.True]                                                   16.1900      6.683      2.422      0.016       3.077      29.303
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                             11.0706      6.798      1.628      0.104      -2.269      24.410
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                           2.7925      6.872      0.406      0.685     -10.691      16.276
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                          12.1790      6.753      1.804      0.072      -1.070      25.428
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                           4.9288      6.776      0.727      0.467      -8.366      18.223
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                        1.0406      6.781      0.153      0.878     -12.265      14.346
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                        0.5799      6.730      0.086      0.931     -12.624      13.784
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                                                     18.8638      6.804      2.772      0.006       5.513      32.214
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                             8.0771      6.895      1.172      0.242      -5.451      21.605
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                          2.5185      6.945      0.363      0.717     -11.108      16.145
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                          8.8676      6.804      1.303      0.193      -4.483      22.218
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                         -5.5710      6.850     -0.813      0.416     -19.010       7.868
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                      -8.2219      6.855     -1.199      0.231     -21.673       5.229
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                      -0.4901      6.804     -0.072      0.943     -13.840      12.860
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                     2.8244      6.827      0.414      0.679     -10.571      16.219
# C(Embedding)[T.Glove]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                                -9.7605      6.872     -1.420      0.156     -23.244       3.723
# C(Embedding)[T.Wang2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                            -13.0638      7.012     -1.863      0.063     -26.822       0.694
# C(Embedding)[T.Word2Vec]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                             -9.9894      6.827     -1.463      0.144     -23.384       3.406
# C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                            1.4313      6.923      0.207      0.836     -12.152      15.014
# C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                                        -8.4580      6.827     -1.239      0.216     -21.853       4.937
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                        -1.9227      9.618     -0.200      0.842     -20.795      16.950
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                     15.7035      9.618      1.633      0.103      -3.169      34.576
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]                      1.6377      9.606      0.170      0.865     -17.211      20.486
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                              -19.6016      9.586     -2.045      0.041     -38.411      -0.793
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                            -8.2189      9.639     -0.853      0.394     -27.131      10.693
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Lower)[T.True]                           -15.2488      9.537     -1.599      0.110     -33.962       3.465
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                              -1.5860      9.683     -0.164      0.870     -20.584      17.412
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                            4.1973      9.687      0.433      0.665     -14.809      23.204
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                           -8.8042      9.570     -0.920      0.358     -27.581       9.973
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                     -5.1517      9.719     -0.530      0.596     -24.221      13.917
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                  10.9001      9.865      1.105      0.269      -8.456      30.257
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                   0.4389      9.639      0.046      0.964     -18.473      19.351
# C(Embedding)[T.Glove]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                   6.3754      9.634      0.662      0.508     -12.529      25.279
# C(Embedding)[T.Wang2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                               17.6617      9.719      1.817      0.069      -1.407      36.731
# C(Embedding)[T.Word2Vec]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                                8.7282      9.606      0.909      0.364     -10.120      27.577
# C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]                             -3.2385      9.707     -0.334      0.739     -22.284      15.807
# C(Embedding)[T.Glove]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]        7.1180     13.674      0.521      0.603     -19.711      33.947
# C(Embedding)[T.Wang2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]   -14.9203     13.744     -1.086      0.278     -41.888      12.047
# C(Embedding)[T.Word2Vec]:C(Tagging_Scheme)[T.iobes]:C(Capitalisation_Dim)[T.True]:C(Char_LSTM_Dim)[T.50]:C(Word_LSTM_Dim)[T.200]:C(Lower)[T.True]     6.4344     13.597      0.473      0.636     -20.244      33.113
# ==============================================================================
# Omnibus:                     1096.207   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28617.023
# Skew:                          -4.181   Prob(JB):                         0.00
# Kurtosis:                      25.050   Cond. No.                         591.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
res = sm.stats.anova_lm(model, typ= 2)

# %%
res
# Out:
#                                                           sum_sq      df  \
# C(Embedding)                                        15634.307190     3.0
# C(Tagging_Scheme)                                       3.390585     1.0
# C(Capitalisation_Dim)                                  58.050738     1.0
# C(Char_LSTM_Dim)                                       30.411899     1.0
# C(Word_LSTM_Dim)                                       21.109064     1.0
# C(Lower)                                             9295.791169     1.0
# C(Embedding):C(Tagging_Scheme)                        140.257542     3.0
# C(Embedding):C(Capitalisation_Dim)                     67.188428     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim)                95.220703     1.0
# C(Embedding):C(Char_LSTM_Dim)                          27.585483     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim)                      8.137807     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim)                  2.103009     1.0
# C(Embedding):C(Word_LSTM_Dim)                           1.069425     3.0
# C(Tagging_Scheme):C(Word_LSTM_Dim)                     33.530023     1.0
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                141.338627     1.0
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                       4.909472     1.0
# C(Embedding):C(Lower)                               11891.789470     3.0
# C(Tagging_Scheme):C(Lower)                             20.876621     1.0
# C(Capitalisation_Dim):C(Lower)                         28.324836     1.0
# C(Char_LSTM_Dim):C(Lower)                              14.180397     1.0
# C(Word_LSTM_Dim):C(Lower)                              26.972314     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    173.116107     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)        81.421910     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     38.673509     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     15.244258     1.0
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)       180.947548     3.0
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     50.046226     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...     22.044503     1.0
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)         92.795833     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...      6.213484     1.0
# ...                                                          ...     ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)                197.413435     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)           121.692193     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)        34.172953     1.0
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                 43.043717     3.0
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)            39.791543     1.0
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)         2.656784     1.0
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)             45.552919     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     66.514807     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    152.331402     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    107.261525     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     48.346652     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...      0.030389     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    106.711517     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    135.914225     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     22.304438     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    191.115869     1.0
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...    142.660800     3.0
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     18.125419     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...      1.299624     1.0
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...    133.902920     3.0
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...      5.721328     1.0
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...     19.822308     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     50.073679     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    200.785066     3.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     41.884409     3.0
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     22.595840     3.0
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    105.060603     3.0
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     14.431239     1.0
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     93.573122     3.0
# Residual                                            30903.846268  1107.0
#
#                                                              F        PR(>F)
# C(Embedding)                                        186.677713  5.995006e-98
# C(Tagging_Scheme)                                     0.121453  7.275297e-01
# C(Capitalisation_Dim)                                 2.079423  1.495795e-01
# C(Char_LSTM_Dim)                                      1.089378  2.968369e-01
# C(Word_LSTM_Dim)                                      0.756143  3.847267e-01
# C(Lower)                                            332.982527  3.029907e-65
# C(Embedding):C(Tagging_Scheme)                        1.674712  1.706998e-01
# C(Embedding):C(Capitalisation_Dim)                    0.802247  4.926646e-01
# C(Tagging_Scheme):C(Capitalisation_Dim)               3.410880  6.503463e-02
# C(Embedding):C(Char_LSTM_Dim)                         0.329378  8.041220e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim)                    0.291503  5.893678e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim)                0.075331  7.837780e-01
# C(Embedding):C(Word_LSTM_Dim)                         0.012769  9.980274e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim)                    1.201072  2.733459e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                5.062860  2.463962e-02
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                     0.175861  6.750359e-01
# C(Embedding):C(Lower)                               141.991074  7.754798e-78
# C(Tagging_Scheme):C(Lower)                            0.747817  3.873556e-01
# C(Capitalisation_Dim):C(Lower)                        1.014618  3.140192e-01
# C(Char_LSTM_Dim):C(Lower)                             0.507953  4.761766e-01
# C(Word_LSTM_Dim):C(Lower)                             0.966169  3.258521e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    2.067052  1.028745e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)       0.972199  4.050636e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    0.461772  7.090371e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    0.546061  4.600882e-01
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)       2.160561  9.102517e-02
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...    0.597565  6.166657e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...    0.789651  3.743986e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)        1.108006  3.447945e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...    0.222572  6.371802e-01
# ...                                                        ...           ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)                2.357168  7.025264e-02
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)           4.359110  3.703969e-02
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)       1.224102  2.687975e-01
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                0.513953  6.727298e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)           1.425364  2.327783e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)       0.095168  7.577651e-01
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)            1.631741  2.017302e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    0.794204  4.971576e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    1.818877  1.419237e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    1.280731  2.795806e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    0.577272  6.300103e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    0.001089  9.736860e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    1.274163  2.818423e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    1.622851  1.823348e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    0.266321  8.496979e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    6.845920  9.005385e-03
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...    1.703407  1.645657e-01
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...    0.216422  8.850431e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...    0.046554  8.292125e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...    1.598836  1.879711e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...    0.204942  6.508494e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...    0.710051  3.996090e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    0.597893  6.164516e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    2.397426  6.660560e-02
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    0.500111  6.822718e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    0.269800  8.472006e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    1.254451  2.887307e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    0.516938  4.723024e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    1.117288  3.409753e-01
# Residual                                                   NaN           NaN
#
# [64 rows x 4 columns]

# %%
# Calculating effect size
def anova_table(aov):
    aov['mean_sq'] = aov[:]['sum_sq']/aov[:]['df']
    
    aov['eta_sq'] = aov[:-1]['sum_sq']/sum(aov['sum_sq'])
    
    aov['omega_sq'] = (aov[:-1]['sum_sq']-(aov[:-1]['df']*aov['mean_sq'][-1]))/(sum(aov['sum_sq'])+aov['mean_sq'][-1])
    
    cols = ['sum_sq', 'mean_sq', 'df', 'F', 'PR(>F)', 'eta_sq', 'omega_sq']
    aov = aov[cols]
    return aov

anova_table(res)
# Out:
#                                                           sum_sq      mean_sq  \
# C(Embedding)                                        15634.307190  5211.435730
# C(Tagging_Scheme)                                       3.390585     3.390585
# C(Capitalisation_Dim)                                  58.050738    58.050738
# C(Char_LSTM_Dim)                                       30.411899    30.411899
# C(Word_LSTM_Dim)                                       21.109064    21.109064
# C(Lower)                                             9295.791169  9295.791169
# C(Embedding):C(Tagging_Scheme)                        140.257542    46.752514
# C(Embedding):C(Capitalisation_Dim)                     67.188428    22.396143
# C(Tagging_Scheme):C(Capitalisation_Dim)                95.220703    95.220703
# C(Embedding):C(Char_LSTM_Dim)                          27.585483     9.195161
# C(Tagging_Scheme):C(Char_LSTM_Dim)                      8.137807     8.137807
# C(Capitalisation_Dim):C(Char_LSTM_Dim)                  2.103009     2.103009
# C(Embedding):C(Word_LSTM_Dim)                           1.069425     0.356475
# C(Tagging_Scheme):C(Word_LSTM_Dim)                     33.530023    33.530023
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                141.338627   141.338627
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                       4.909472     4.909472
# C(Embedding):C(Lower)                               11891.789470  3963.929823
# C(Tagging_Scheme):C(Lower)                             20.876621    20.876621
# C(Capitalisation_Dim):C(Lower)                         28.324836    28.324836
# C(Char_LSTM_Dim):C(Lower)                              14.180397    14.180397
# C(Word_LSTM_Dim):C(Lower)                              26.972314    26.972314
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    173.116107    57.705369
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)        81.421910    27.140637
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     38.673509    12.891170
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     15.244258    15.244258
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)       180.947548    60.315849
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     50.046226    16.682075
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...     22.044503    22.044503
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)         92.795833    30.931944
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...      6.213484     6.213484
# ...                                                          ...          ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)                197.413435    65.804478
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)           121.692193   121.692193
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)        34.172953    34.172953
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                 43.043717    14.347906
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)            39.791543    39.791543
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)         2.656784     2.656784
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)             45.552919    45.552919
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     66.514807    22.171602
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    152.331402    50.777134
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    107.261525    35.753842
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     48.346652    16.115551
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...      0.030389     0.030389
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    106.711517    35.570506
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...    135.914225    45.304742
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     22.304438     7.434813
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...    191.115869   191.115869
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...    142.660800    47.553600
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     18.125419     6.041806
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...      1.299624     1.299624
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...    133.902920    44.634307
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...      5.721328     5.721328
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...     19.822308    19.822308
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     50.073679    16.691226
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...    200.785066    66.928355
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     41.884409    13.961470
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     22.595840     7.531947
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...    105.060603    35.020201
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     14.431239    14.431239
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     93.573122    31.191041
# Residual                                            30903.846268    27.916754
#
#                                                         df           F  \
# C(Embedding)                                           3.0  186.677713
# C(Tagging_Scheme)                                      1.0    0.121453
# C(Capitalisation_Dim)                                  1.0    2.079423
# C(Char_LSTM_Dim)                                       1.0    1.089378
# C(Word_LSTM_Dim)                                       1.0    0.756143
# C(Lower)                                               1.0  332.982527
# C(Embedding):C(Tagging_Scheme)                         3.0    1.674712
# C(Embedding):C(Capitalisation_Dim)                     3.0    0.802247
# C(Tagging_Scheme):C(Capitalisation_Dim)                1.0    3.410880
# C(Embedding):C(Char_LSTM_Dim)                          3.0    0.329378
# C(Tagging_Scheme):C(Char_LSTM_Dim)                     1.0    0.291503
# C(Capitalisation_Dim):C(Char_LSTM_Dim)                 1.0    0.075331
# C(Embedding):C(Word_LSTM_Dim)                          3.0    0.012769
# C(Tagging_Scheme):C(Word_LSTM_Dim)                     1.0    1.201072
# C(Capitalisation_Dim):C(Word_LSTM_Dim)                 1.0    5.062860
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                      1.0    0.175861
# C(Embedding):C(Lower)                                  3.0  141.991074
# C(Tagging_Scheme):C(Lower)                             1.0    0.747817
# C(Capitalisation_Dim):C(Lower)                         1.0    1.014618
# C(Char_LSTM_Dim):C(Lower)                              1.0    0.507953
# C(Word_LSTM_Dim):C(Lower)                              1.0    0.966169
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    2.067052
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)        3.0    0.972199
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     3.0    0.461772
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     1.0    0.546061
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)        3.0    2.160561
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     3.0    0.597565
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...     1.0    0.789651
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)         3.0    1.108006
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...     1.0    0.222572
# ...                                                    ...         ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)                 3.0    2.357168
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)            1.0    4.359110
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)        1.0    1.224102
# C(Embedding):C(Word_LSTM_Dim):C(Lower)                 3.0    0.513953
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)            1.0    1.425364
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)        1.0    0.095168
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)             1.0    1.631741
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    0.794204
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    1.818877
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     3.0    1.280731
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     3.0    0.577272
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     1.0    0.001089
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    1.274163
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     3.0    1.622851
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     3.0    0.266321
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     1.0    6.845920
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...     3.0    1.703407
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...     3.0    0.216422
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...     1.0    0.046554
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...     3.0    1.598836
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...     1.0    0.204942
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...     1.0    0.710051
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    0.597893
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    2.397426
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    0.500111
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...     3.0    0.269800
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...     3.0    1.254451
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...     1.0    0.516938
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...     3.0    1.117288
# Residual                                            1107.0         NaN
#
#                                                           PR(>F)  \
# C(Embedding)                                        5.995006e-98
# C(Tagging_Scheme)                                   7.275297e-01
# C(Capitalisation_Dim)                               1.495795e-01
# C(Char_LSTM_Dim)                                    2.968369e-01
# C(Word_LSTM_Dim)                                    3.847267e-01
# C(Lower)                                            3.029907e-65
# C(Embedding):C(Tagging_Scheme)                      1.706998e-01
# C(Embedding):C(Capitalisation_Dim)                  4.926646e-01
# C(Tagging_Scheme):C(Capitalisation_Dim)             6.503463e-02
# C(Embedding):C(Char_LSTM_Dim)                       8.041220e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim)                  5.893678e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim)              7.837780e-01
# C(Embedding):C(Word_LSTM_Dim)                       9.980274e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim)                  2.733459e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim)              2.463962e-02
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                   6.750359e-01
# C(Embedding):C(Lower)                               7.754798e-78
# C(Tagging_Scheme):C(Lower)                          3.873556e-01
# C(Capitalisation_Dim):C(Lower)                      3.140192e-01
# C(Char_LSTM_Dim):C(Lower)                           4.761766e-01
# C(Word_LSTM_Dim):C(Lower)                           3.258521e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  1.028745e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)     4.050636e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  7.090371e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  4.600882e-01
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)     9.102517e-02
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...  6.166657e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...  3.743986e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)      3.447945e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...  6.371802e-01
# ...                                                          ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)              7.025264e-02
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)         3.703969e-02
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)     2.687975e-01
# C(Embedding):C(Word_LSTM_Dim):C(Lower)              6.727298e-01
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)         2.327783e-01
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)     7.577651e-01
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)          2.017302e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  4.971576e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  1.419237e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  2.795806e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  6.300103e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  9.736860e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  2.818423e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  1.823348e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  8.496979e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  9.005385e-03
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...  1.645657e-01
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...  8.850431e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...  8.292125e-01
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...  1.879711e-01
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...  6.508494e-01
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...  3.996090e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  6.164516e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  6.660560e-02
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  6.822718e-01
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  8.472006e-01
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  2.887307e-01
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  4.723024e-01
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  3.409753e-01
# Residual                                                     NaN
#
#                                                           eta_sq  omega_sq
# C(Embedding)                                        2.188563e-01  0.217599
# C(Tagging_Scheme)                                   4.746299e-05 -0.000343
# C(Capitalisation_Dim)                               8.126212e-04  0.000422
# C(Char_LSTM_Dim)                                    4.257199e-04  0.000035
# C(Word_LSTM_Dim)                                    2.954945e-04 -0.000095
# C(Lower)                                            1.301268e-01  0.129685
# C(Embedding):C(Tagging_Scheme)                      1.963390e-03  0.000791
# C(Embedding):C(Capitalisation_Dim)                  9.405348e-04 -0.000232
# C(Tagging_Scheme):C(Capitalisation_Dim)             1.332944e-03  0.000942
# C(Embedding):C(Char_LSTM_Dim)                       3.861544e-04 -0.000786
# C(Tagging_Scheme):C(Char_LSTM_Dim)                  1.139168e-04 -0.000277
# C(Capitalisation_Dim):C(Char_LSTM_Dim)              2.943889e-05 -0.000361
# C(Embedding):C(Word_LSTM_Dim)                       1.497031e-05 -0.001157
# C(Tagging_Scheme):C(Word_LSTM_Dim)                  4.693688e-04  0.000079
# C(Capitalisation_Dim):C(Word_LSTM_Dim)              1.978524e-03  0.001587
# C(Char_LSTM_Dim):C(Word_LSTM_Dim)                   6.872507e-05 -0.000322
# C(Embedding):C(Lower)                               1.664668e-01  0.165230
# C(Tagging_Scheme):C(Lower)                          2.922406e-04 -0.000099
# C(Capitalisation_Dim):C(Lower)                      3.965042e-04  0.000006
# C(Char_LSTM_Dim):C(Lower)                           1.985038e-04 -0.000192
# C(Word_LSTM_Dim):C(Lower)                           3.775710e-04 -0.000013
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  2.423360e-03  0.001250
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)     1.139782e-03 -0.000033
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  5.413697e-04 -0.000631
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  2.133962e-04 -0.000177
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)     2.532988e-03  0.001360
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...  7.005703e-04 -0.000472
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...  3.085892e-04 -0.000082
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim)      1.298999e-03  0.000127
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...  8.697923e-05 -0.000304
# ...                                                          ...       ...
# C(Embedding):C(Char_LSTM_Dim):C(Lower)              2.763485e-03  0.001590
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Lower)         1.703504e-03  0.001312
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Lower)     4.783689e-04  0.000088
# C(Embedding):C(Word_LSTM_Dim):C(Lower)              6.025459e-04 -0.000570
# C(Tagging_Scheme):C(Word_LSTM_Dim):C(Lower)         5.570205e-04  0.000166
# C(Capitalisation_Dim):C(Word_LSTM_Dim):C(Lower)     3.719090e-05 -0.000353
# C(Char_LSTM_Dim):C(Word_LSTM_Dim):C(Lower)          6.376709e-04  0.000247
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  9.311052e-04 -0.000241
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  2.132406e-03  0.000960
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  1.501497e-03  0.000329
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  6.767789e-04 -0.000495
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  4.253969e-07 -0.000390
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  1.493797e-03  0.000321
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  1.902590e-03  0.000730
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  3.122279e-04 -0.000860
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  2.675329e-03  0.002284
# C(Embedding):C(Tagging_Scheme):C(Word_LSTM_Dim)...  1.997032e-03  0.000824
# C(Embedding):C(Capitalisation_Dim):C(Word_LSTM_...  2.537280e-04 -0.000918
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Word_...  1.819274e-05 -0.000372
# C(Embedding):C(Char_LSTM_Dim):C(Word_LSTM_Dim):...  1.874435e-03  0.000702
# C(Tagging_Scheme):C(Char_LSTM_Dim):C(Word_LSTM_...  8.008981e-05 -0.000311
# C(Capitalisation_Dim):C(Char_LSTM_Dim):C(Word_L...  2.774819e-04 -0.000113
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  7.009546e-04 -0.000471
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  2.810683e-03  0.001638
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  5.863174e-04 -0.000586
# C(Embedding):C(Tagging_Scheme):C(Char_LSTM_Dim)...  3.163071e-04 -0.000856
# C(Embedding):C(Capitalisation_Dim):C(Char_LSTM_...  1.470687e-03  0.000298
# C(Tagging_Scheme):C(Capitalisation_Dim):C(Char_...  2.020152e-04 -0.000189
# C(Embedding):C(Tagging_Scheme):C(Capitalisation...  1.309880e-03  0.000137
# Residual                                                     NaN       NaN
#
# [64 rows x 7 columns]

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[EMBEDDING])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ==================================================
#  group1   group2  meandiff  lower    upper  reject
# --------------------------------------------------
# FastText  Glove   -1.1723  -2.5697   0.225  False
# FastText Wang2Vec  0.8997  -0.5022   2.3017 False
# FastText Word2Vec -8.0049  -9.3945  -6.6152  True
#  Glove   Wang2Vec  2.0721   0.6747   3.4694  True
#  Glove   Word2Vec -6.8326  -8.2176  -5.4475  True
# Wang2Vec Word2Vec -8.9046  -10.2943  -7.515  True
# --------------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[CAP_DIM])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
# False   True   0.5932  -0.2543 1.4406 False
# --------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[LOWER])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ===========================================
# group1 group2 meandiff lower  upper  reject
# -------------------------------------------
# False   True   5.4075  4.6151 6.1998  True
# -------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[TAGGING_SCHEME])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#  iob   iobes  -0.0898  -0.9378 0.7582 False
# --------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[CHAR_DIM])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   25     50   -0.3547  -1.2024 0.4931 False
# --------------------------------------------

# %%
mc = statsmodels.stats.multicomp.MultiComparison(training_data_df[F1_SCORE], training_data_df[WORD_DIM])
mc_results = mc.tukeyhsd()
print(mc_results)
# Out:
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#  100    200   -0.3035  -1.1515 0.5444 False
# --------------------------------------------
