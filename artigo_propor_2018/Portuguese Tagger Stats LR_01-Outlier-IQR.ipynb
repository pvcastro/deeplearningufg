# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.float_format = '{:,.2f}'.format

# %%
def agrupar_colunas(row, colunas):
    valores = []
    for coluna in colunas:
        valores.append(str(row[coluna]))
    return ', '.join(valores)

# %%
def outliers_iqr(values):
    quartile_1, quartile_3 = np.percentile(values, [50, 75])
    print('quartile 1, quartile 3', quartile_1, quartile_3)
    iqr = quartile_3 - quartile_1
    print('iqr', iqr)
    lower_bound = quartile_1 - (iqr * 1.5)
    print(lower_bound)
    upper_bound = quartile_3 + (iqr * 1.5)
    print(upper_bound)
    #return np.where((values > upper_bound) | (values < lower_bound))
    result = (values <= upper_bound) & (values >= lower_bound)
    #print(result)
    return result

# %%
dados_df = pd.read_csv('resultados.csv')
#dados_df['Short Embedding'] = dados_df.apply(lambda row: get_short_embedding(row['Embedding']), axis=1)
dados_df
# Out:
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 0                  0       5  selective  Wang2Vec            iob
# 1                  0       5  selective  Wang2Vec            iob
# 2                  0       5  selective  Wang2Vec            iob
# 3                  0       5  selective  Wang2Vec            iob
# 4                  0       5  selective  Wang2Vec            iob
# 5                  0       5  selective  Wang2Vec            iob
# 6                  0       5  selective  Wang2Vec            iob
# 7                  0       5  selective  Wang2Vec            iob
# 8                  0       5  selective  Wang2Vec            iob
# 9                  0       5  selective  Wang2Vec            iob
# 10                 0       5  selective  Wang2Vec            iob
# 11                 0       5  selective  Wang2Vec            iob
# 12                 0       5  selective  Wang2Vec            iob
# ...

# %%
dados_df['Capitalization_Normalization'] = dados_df.apply(lambda row: agrupar_colunas(row, colunas=['Capitalisation_Dim','Lower']), axis=1)

# %%
dados_df['Hidden_Units'] = dados_df.apply(lambda row: agrupar_colunas(row, colunas=['Char_LSTM_Dim','Word_LSTM_Dim']), axis=1)

# %%
dados_df
# Out:
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 0                  0       5  selective  Wang2Vec            iob
# 1                  0       5  selective  Wang2Vec            iob
# 2                  0       5  selective  Wang2Vec            iob
# 3                  0       5  selective  Wang2Vec            iob
# 4                  0       5  selective  Wang2Vec            iob
# 5                  0       5  selective  Wang2Vec            iob
# 6                  0       5  selective  Wang2Vec            iob
# 7                  0       5  selective  Wang2Vec            iob
# 8                  0       5  selective  Wang2Vec            iob
# 9                  0       5  selective  Wang2Vec            iob
# 10                 0       5  selective  Wang2Vec            iob
# 11                 0       5  selective  Wang2Vec            iob
# 12                 0       5  selective  Wang2Vec            iob
# ...

# %%
groups = dados_df.groupby(['Epochs','Embedding','Scenario','Tagging_Scheme','Capitalization_Normalization','Hidden_Units'])

# %%
len(groups)
# Out:
# 128

# %%
first_group = groups.get_group((5,'Wang2Vec','selective','iob','False, True', '50, 200'))
first_group
# Out:
#      Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 7                 0       5  selective  Wang2Vec            iob
# 39                1       5  selective  Wang2Vec            iob
# 71                2       5  selective  Wang2Vec            iob
# 103               3       5  selective  Wang2Vec            iob
# 135               4       5  selective  Wang2Vec            iob
# 167               5       5  selective  Wang2Vec            iob
# 199               6       5  selective  Wang2Vec            iob
# 231               7       5  selective  Wang2Vec            iob
# 263               8       5  selective  Wang2Vec            iob
# 295               9       5  selective  Wang2Vec            iob
#
#      Capitalisation_Dim  Lower  Char_LSTM_Dim  Word_LSTM_Dim  Precision  \
# 7                 False   True             50            200      66.93
# 39                False   True             50            200      69.12
# ...

# %%
outliers_iqr(first_group['F1_Score'])
# Out:
# quartile 1, quartile 3 65.57 67.2125
# iqr 1.6425000000000125
# 63.106249999999974
# 69.67625000000002
# 7       True
# 39      True
# 71      True
# 103     True
# 135    False
# 167    False
# 199     True
# 231    False
# 263     True
# 295    False
# Name: F1_Score, dtype: bool

# %%
filtered_groups = []
for group in groups.groups:
    group_df = groups.get_group(group)
    #print(group_df)
    group_df = group_df[outliers_iqr(group_df['F1_Score'])]
    #print(group_df)
    #print(group_df['F1 Score'], outliers_iqr(group_df['F1 Score']))
    #filtered = outliers_iqr(group_df['F1 Score'].tolist())
    #print(filtered[0], type(filtered))
    #filtered = filtered.tolist()
    #print(filtered, type(filtered))
    #filter_list += filtered[0]
    filtered_groups.append(group_df)
# Out:
# quartile 1, quartile 3 56.945 57.82000000000001
# iqr 0.8750000000000071
# 55.63249999999999
# 59.13250000000002
# quartile 1, quartile 3 55.144999999999996 56.1425
# iqr 0.9975000000000023
# 53.64874999999999
# 57.63875
# quartile 1, quartile 3 56.1 56.53
# iqr 0.4299999999999997
# 55.455
# 57.175
# quartile 1, quartile 3 56.09 56.465
# iqr 0.375
# 55.5275
# 57.0275
# quartile 1, quartile 3 65.14 65.71000000000001
# iqr 0.5700000000000074
# 64.285
# 66.56500000000003
# quartile 1, quartile 3 64.13 65.2875
# iqr 1.1574999999999989
# 62.39375
# 67.02374999999999
# quartile 1, quartile 3 64.875 65.3125
# iqr 0.4375
# 64.21875
# 65.96875
# quartile 1, quartile 3 64.765 65.0975
# iqr 0.332499999999996
# 64.26625000000001
# 65.59625
# quartile 1, quartile 3 55.925 57.730000000000004
# iqr 1.8050000000000068
# 53.21749999999999
# 60.437500000000014
# quartile 1, quartile 3 55.745000000000005 56.5575
# iqr 0.8124999999999929
# 54.52625000000002
# 57.77624999999999
# ...

# %%
dados_df = pd.concat(filtered_groups)
dados_df
# Out:
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 320                0       5  selective  FastText            iob
# 352                1       5  selective  FastText            iob
# 384                2       5  selective  FastText            iob
# 416                3       5  selective  FastText            iob
# 448                4       5  selective  FastText            iob
# 544                7       5  selective  FastText            iob
# 576                8       5  selective  FastText            iob
# 608                9       5  selective  FastText            iob
# 353                1       5  selective  FastText            iob
# 385                2       5  selective  FastText            iob
# 417                3       5  selective  FastText            iob
# 449                4       5  selective  FastText            iob
# 481                5       5  selective  FastText            iob
# ...

# %%
dados_df.columns.values
# Out:
# array(['Training_Round', 'Epochs', 'Scenario', 'Embedding',
#        'Tagging_Scheme', 'Capitalisation_Dim', 'Lower', 'Char_LSTM_Dim',
#        'Word_LSTM_Dim', 'Precision', 'Recall', 'F1_Score',
#        'Capitalization_Normalization', 'Hidden_Units'], dtype=object)

# %%
dados_df.groupby('Embedding').describe(percentiles=[])
# Out:
#           Training_Round                          Epochs                      \
#                    count mean  std  min  50%  max  count mean  std  min  50%
# Embedding
# FastText          237.00 4.44 2.82 0.00 4.00 9.00 237.00 5.00 0.00 5.00 5.00
# Glove             216.00 4.30 2.91 0.00 4.00 9.00 216.00 5.00 0.00 5.00 5.00
# Wang2Vec          227.00 4.52 2.91 0.00 5.00 9.00 227.00 5.00 0.00 5.00 5.00
# Word2Vec          236.00 4.58 2.86 0.00 5.00 9.00 236.00 5.00 0.00 5.00 5.00
#
#                Char_LSTM_Dim                               Word_LSTM_Dim  \
#            max         count  mean   std   min   50%   max         count
# Embedding
# FastText  5.00        237.00 36.60 12.49 25.00 25.00 50.00        237.00
# Glove     5.00        216.00 37.38 12.53 25.00 25.00 50.00        216.00
# Wang2Vec  5.00        227.00 37.44 12.53 25.00 25.00 50.00        227.00
# Word2Vec  5.00        236.00 37.18 12.52 25.00 25.00 50.00        236.00
#
# ...

# %%
dados_fscore_df = dados_df.copy()
del dados_fscore_df['Training_Round']
del dados_fscore_df['Precision']
del dados_fscore_df['Recall']
del dados_fscore_df['Capitalisation_Dim']
del dados_fscore_df['Lower']
del dados_fscore_df['Char_LSTM_Dim']
del dados_fscore_df['Word_LSTM_Dim']
dados_fscore_df.pivot_table(columns=['Epochs','Embedding','Scenario','Tagging_Scheme','Capitalization_Normalization','Hidden_Units'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
#                                                                                               mean  \
#          Epochs Embedding Scenario  Tagging_Scheme Capitalization_Normalization Hidden_Units
# F1_Score 5      FastText  selective iob            False, False                 25, 100      57.43
#                                                                                 25, 200      55.66
#                                                                                 50, 100      56.15
#                                                                                 50, 200      56.32
#                                                    False, True                  25, 100      65.34
#                                                                                 25, 200      64.62
#                                                                                 50, 100      65.05
# ...

# %%
dados_fscore_df.pivot_table(columns=['Embedding'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
# /home/user/anaconda3/envs/allennlp/lib/python3.6/site-packages/pandas/core/reshape/pivot.py:42: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return concat(pieces, keys=keys, axis=1)
#                                  mean                                amax  \
# Embedding                    FastText Glove Wang2Vec Word2Vec    FastText
# Capitalization_Normalization      nan   nan      nan      nan  True, True
# Epochs                           5.00  5.00     5.00     5.00           5
# F1_Score                        60.95 58.98    60.94    52.03       66.86
# Hidden_Units                      nan   nan      nan      nan     50, 200
# Scenario                          nan   nan      nan      nan   selective
# ...

# %%
dados_fscore_df.pivot_table(columns=['Capitalization_Normalization'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
# /home/user/anaconda3/envs/allennlp/lib/python3.6/site-packages/pandas/core/reshape/pivot.py:42: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return concat(pieces, keys=keys, axis=1)
#                                      mean                                     \
# Capitalization_Normalization False, False False, True True, False True, True
# Embedding                             nan         nan         nan        nan
# Epochs                               5.00        5.00        5.00       5.00
# F1_Score                            55.66       60.82       55.74      60.90
# Hidden_Units                          nan         nan         nan        nan
# Scenario                              nan         nan         nan        nan
# ...

# %%
dados_fscore_df.pivot_table(columns=['Tagging_Scheme'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
# /home/user/anaconda3/envs/allennlp/lib/python3.6/site-packages/pandas/core/reshape/pivot.py:42: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return concat(pieces, keys=keys, axis=1)
#                               mean              amax              \
# Tagging_Scheme                 iob iobes         iob       iobes
# Capitalization_Normalization   nan   nan  True, True  True, True
# Embedding                      nan   nan    Word2Vec    Word2Vec
# Epochs                        5.00  5.00           5           5
# F1_Score                     58.15 58.22       68.26       67.87
# Hidden_Units                   nan   nan     50, 200     50, 200
# Scenario                       nan   nan   selective   selective
#
# ...

# %%
dados_fscore_df.pivot_table(columns=['Hidden_Units'], aggfunc=[np.mean, np.max, np.min, np.std])
# Out:
# /home/user/anaconda3/envs/allennlp/lib/python3.6/site-packages/pandas/core/reshape/pivot.py:42: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return concat(pieces, keys=keys, axis=1)
#                                 mean                                amax  \
# Hidden_Units                 25, 100 25, 200 50, 100 50, 200     25, 100
# Capitalization_Normalization     nan     nan     nan     nan  True, True
# Embedding                        nan     nan     nan     nan    Word2Vec
# Epochs                          5.00    5.00    5.00    5.00           5
# F1_Score                       58.59   57.68   58.43   58.05       68.26
# Scenario                         nan     nan     nan     nan   selective
# ...

# %%
dados_fscore_df.plot(kind='hist', x='Embedding', y='F1_Score')

# %%
def plot_and_save(data_frame, column, title, prefix='plt', save=False):
    data_frame.boxplot(column='F1_Score', by=column, showmeans=True, fontsize=16, showfliers=False)
    plt.title(title, fontsize=18)
    plt.suptitle("")
    plt.xlabel("")
    if save == True:
        filename = column.replace(' / ', '_').replace(' ','_').lower()
        plt.savefig(prefix + "_" + filename + ".pdf", bbox_inches='tight')

# %%
plot_and_save(dados_fscore_df, 'Embedding', 'Embeddings')
plot_and_save(dados_fscore_df, 'Tagging_Scheme', 'Tagging Schemes')
plot_and_save(dados_fscore_df, 'Capitalization_Normalization', 'Capitalization / Normalization')
plot_and_save(dados_fscore_df, 'Hidden_Units', 'Hidden Units')
plot_and_save(dados_df, 'Lower', 'Normalization')
plot_and_save(dados_df, 'Capitalisation_Dim', 'Capitalization')
plot_and_save(dados_df, 'Char_LSTM_Dim', 'Character LSTM Units')
plot_and_save(dados_df, 'Word_LSTM_Dim', 'Word LSTM Units')

# %%
cols_alias = {'Embedding': 'Embedding', 'Tagging_Scheme': 'Tagging Scheme', 'Capitalization_Normalization': 'Capitalization / Normalization', 'Hidden_Units': 'Hidden Units'}
fig, axes = plt.subplots(1, 4, figsize=(20, 5), sharey=True)

for idx, column in enumerate(cols_alias.keys()):
    idf = dados_fscore_df[['F1_Score',column]].pivot(columns=column)
    #print(idf)
    
    idf.plot.box(ax=axes[idx], showmeans=True)
    axes[idx].set_title(cols_alias.get(column), fontsize=15)
    axes[idx].set_xticklabels([e[1] for e in idf.columns])

plt.show()
fig.savefig('parameters_box_plots.pdf',bbox_inches='tight')

# %%
dados_fscore_df.shape
# Out:
# (916, 7)

# %%
dados_fscore_df[dados_fscore_df['Embedding'] == 'Wang2Vec'].shape
# Out:
# (227, 7)

# %%
dados_fscore_df[dados_fscore_df['Embedding'] == 'FastText'].shape
# Out:
# (237, 7)

# %%
dados_df[dados_df['Embedding'] == 'Wang2Vec'].shape
# Out:
# (227, 14)

# %%
dados_brutos_df = pd.read_csv('resultados.csv')
dados_brutos_df.groupby('Embedding')['F1_Score'].describe()
# Out:
#            count  mean   std  min   25%   50%   75%   max
# Embedding
# FastText  320.00 56.53 14.10 0.00 55.92 57.61 65.01 67.05
# Glove     320.00 56.17 11.12 1.01 54.72 56.58 62.61 64.89
# Wang2Vec  320.00 57.49 13.72 0.00 55.73 57.59 66.38 68.26
# Word2Vec  320.00 50.58  6.46 0.19 48.71 51.51 54.41 56.92

# %%
dados_brutos_df.boxplot(column='F1_Score', by='Embedding', showmeans=True, fontsize=13, showfliers=False)
plt.title('Embeddings', fontsize=15)
plt.suptitle("")
plt.xlabel("")
# Out:
# Text(0.5,0,'')

# %%
dados_sem_outliers_df = dados_brutos_df[dados_brutos_df['F1_Score'] >= 50]
dados_sem_outliers_df.shape
# Out:
# (1071, 12)

# %%
def renomear_tagging_scheme(row):
    if row['Tagging_Scheme'] == 'iob':
        return 'IOB2'
    elif row['Tagging_Scheme'] == 'iobes':
        return 'IOBES'

# %%
dados_sem_outliers_df['Tagging_Scheme'] = dados_sem_outliers_df.apply(lambda row: renomear_tagging_scheme(row), axis=1)
# Out:
# /home/user/anaconda3/envs/allennlp/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_sem_outliers_df
# Out:
#       Training_Round  Epochs   Scenario Embedding Tagging_Scheme  \
# 0                  0       5  selective  Wang2Vec           IOB2
# 1                  0       5  selective  Wang2Vec           IOB2
# 2                  0       5  selective  Wang2Vec           IOB2
# 3                  0       5  selective  Wang2Vec           IOB2
# 4                  0       5  selective  Wang2Vec           IOB2
# 5                  0       5  selective  Wang2Vec           IOB2
# 6                  0       5  selective  Wang2Vec           IOB2
# 7                  0       5  selective  Wang2Vec           IOB2
# 8                  0       5  selective  Wang2Vec           IOB2
# 9                  0       5  selective  Wang2Vec           IOB2
# 10                 0       5  selective  Wang2Vec           IOB2
# 12                 0       5  selective  Wang2Vec           IOB2
# 13                 0       5  selective  Wang2Vec           IOB2
# ...

# %%
dados_sem_outliers_df.boxplot(column='F1_Score', by='Embedding', showmeans=True, fontsize=13, showfliers=False)
plt.title('Embeddings', fontsize=15)
plt.suptitle("")
plt.xlabel("")
# Out:
# Text(0.5,0,'')

# %%
dados_sem_outliers_df.groupby('Embedding')['F1_Score'].describe()
dados_sem_outliers_df.groupby('Lower')['F1_Score'].describe()
# Out:
#        count  mean  std   min   25%   50%   75%   max
# Lower
# False 594.00 55.44 1.53 50.13 54.53 55.55 56.53 59.82
# True  477.00 63.39 4.36 50.03 62.66 64.55 66.17 68.26

# %%
plot_and_save(dados_sem_outliers_df, 'Embedding', 'Embeddings', prefix='plot', save=True)
plot_and_save(dados_sem_outliers_df, 'Tagging_Scheme', 'Tagging Schemes', prefix='plot', save=True)
plot_and_save(dados_sem_outliers_df, 'Lower', 'Normalization', prefix='plot', save=True)
plot_and_save(dados_sem_outliers_df, 'Capitalisation_Dim', 'Capitalization', prefix='plot', save=True)
plot_and_save(dados_sem_outliers_df, 'Char_LSTM_Dim', 'Character LSTM Units', prefix='plot', save=True)
plot_and_save(dados_sem_outliers_df, 'Word_LSTM_Dim', 'Word LSTM Units', prefix='plot', save=True)

# %%
dados_sem_outliers_df.groupby('Embedding')['F1_Score'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# Embedding
# FastText  290.00 60.55 4.59 50.69 56.46 58.39 65.16 67.05
# Glove     300.00 58.66 4.04 50.18 55.00 57.34 62.66 64.89
# Wang2Vec  292.00 61.18 5.29 50.13 56.21 58.33 66.47 68.26
# Word2Vec  189.00 53.72 1.84 50.03 52.38 54.05 55.29 56.92

# %%
groups = ['Embedding', 'Tagging_Scheme', 'Lower', 'Capitalisation_Dim', 'Char_LSTM_Dim', 'Word_LSTM_Dim']
for group in groups:
    print(dados_sem_outliers_df.groupby(group)['F1_Score'].describe())
# Out:
#            count  mean  std   min   25%   50%   75%   max
# Embedding
# FastText  290.00 60.55 4.59 50.69 56.46 58.39 65.16 67.05
# Glove     300.00 58.66 4.04 50.18 55.00 57.34 62.66 64.89
# Wang2Vec  292.00 61.18 5.29 50.13 56.21 58.33 66.47 68.26
# Word2Vec  189.00 53.72 1.84 50.03 52.38 54.05 55.29 56.92
#                 count  mean  std   min   25%   50%   75%   max
# Tagging_Scheme
# IOB2           544.00 58.84 5.13 50.03 54.89 56.66 64.05 68.26
# IOBES          527.00 59.14 4.94 50.13 55.35 57.03 64.03 67.99
#        count  mean  std   min   25%   50%   75%   max
# Lower
# False 594.00 55.44 1.53 50.13 54.53 55.55 56.53 59.82
# True  477.00 63.39 4.36 50.03 62.66 64.55 66.17 68.26
#                     count  mean  std   min   25%   50%   75%   max
# Capitalisation_Dim
# False              530.00 58.79 5.02 50.06 54.96 56.71 63.84 68.07
# True               541.00 59.18 5.05 50.03 55.30 57.02 64.32 68.26
#                count  mean  std   min   25%   50%   75%   max
# ...

# %%
dados_sem_outliers_df.groupby(groups)['F1_Score'].describe()
# Out:
#                                                                                count  \
# Embedding Tagging_Scheme Lower Capitalisation_Dim Char_LSTM_Dim Word_LSTM_Dim
# FastText  IOB2           False False              25            100            10.00
#                                                                 200             8.00
#                                                   50            100             9.00
#                                                                 200             8.00
#                                True               25            100            10.00
#                                                                 200             9.00
#                                                   50            100            10.00
#                                                                 200             9.00
#                          True  False              25            100            10.00
# ...

# %%
df_groups = dados_sem_outliers_df.groupby(groups)['F1_Score'].describe()
type(df_groups.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df_groups.sort_values(ascending=False, by=['mean'])
# Out:
#                                                                                count  \
# Embedding Tagging_Scheme Lower Capitalisation_Dim Char_LSTM_Dim Word_LSTM_Dim
# Wang2Vec  IOB2           True  False              50            100            10.00
#                                True               25            100             9.00
#                                False              50            200             6.00
#           IOBES          True  True               25            200            10.00
#           IOB2           True  True               50            100            10.00
#                                                                 200             9.00
#           IOBES          True  True               25            100            10.00
#                                                   50            100            10.00
#                                False              50            100             7.00
# ...

# %%
df_groups.sort_values(ascending=False, by=['max'])
# Out:
#                                                                                count  \
# Embedding Tagging_Scheme Lower Capitalisation_Dim Char_LSTM_Dim Word_LSTM_Dim
# Wang2Vec  IOB2           True  True               25            100             9.00
#                                False              50            200             6.00
#           IOBES          True  True               25            200            10.00
#                                False              50            200             9.00
#                                True               25            100            10.00
#                                                   50            100            10.00
#           IOB2           True  False              25            100             8.00
#                                                   50            100            10.00
#                                True               50            100            10.00
# ...

# %%
df_groups.to_csv('results_by_scenario.csv')

# %%
df_groups = df_groups.sort_values(ascending=False, by=['mean'])
df_groups.to_csv('results_by_scenario.csv')

# %%
df_groups.head(10).to_latex()
# Out:
# '\\begin{tabular}{llllllrrrrrrrr}\n\\toprule\n         &       &      &       &    &     &  count &  mean &  std &   min &   25\\% &   50\\% &   75\\% &   max \\\\\nEmbedding & Tagging\\_Scheme & Lower & Capitalisation\\_Dim & Char\\_LSTM\\_Dim & Word\\_LSTM\\_Dim &        &       &      &       &       &       &       &       \\\\\n\\midrule\nWang2Vec & IOB2 & True & False & 50 & 100 &  10.00 & 66.90 & 0.72 & 65.44 & 66.42 & 67.11 & 67.49 & 67.69 \\\\\n         &       &      & True  & 25 & 100 &   9.00 & 66.89 & 1.15 & 64.87 & 66.20 & 66.92 & 67.86 & 68.26 \\\\\n         &       &      & False & 50 & 200 &   6.00 & 66.82 & 1.05 & 65.21 & 66.21 & 67.16 & 67.36 & 68.07 \\\\\n         & IOBES & True & True  & 25 & 200 &  10.00 & 66.79 & 0.77 & 65.54 & 66.28 & 66.84 & 67.20 & 67.99 \\\\\n         & IOB2 & True & True  & 50 & 100 &  10.00 & 66.67 & 0.79 & 65.00 & 66.33 & 66.75 & 67.29 & 67.64 \\\\\n         &       &      &       &    & 200 &   9.00 & 66.60 & 0.44 & 65.94 & 66.28 & 66.6
# ...

# %%
print(df_groups.head(10).to_latex(columns=['mean','max']))
# Out:
# \begin{tabular}{llllllrr}
# \toprule
#          &       &      &       &    &     &  mean &   max \\
# Embedding & Tagging\_Scheme & Lower & Capitalisation\_Dim & Char\_LSTM\_Dim & Word\_LSTM\_Dim &       &       \\
# \midrule
# Wang2Vec & IOB2 & True & False & 50 & 100 & 66.90 & 67.69 \\
#          &       &      & True  & 25 & 100 & 66.89 & 68.26 \\
#          &       &      & False & 50 & 200 & 66.82 & 68.07 \\
#          & IOBES & True & True  & 25 & 200 & 66.79 & 67.99 \\
#          & IOB2 & True & True  & 50 & 100 & 66.67 & 67.64 \\
#          &       &      &       &    & 200 & 66.60 & 67.22 \\
#          & IOBES & True & True  & 25 & 100 & 66.55 & 67.87 \\
#          &       &      &       & 50 & 100 & 66.45 & 67.79 \\
#          &       &      & False & 50 & 100 & 66.37 & 67.58 \\
#          &       &      & True  & 50 & 200 & 66.33 & 66.78 \\
# \bottomrule
# \end{tabular}

# %%
df_groups.head(10)
# Out:
#                                                                                count  \
# Embedding Tagging_Scheme Lower Capitalisation_Dim Char_LSTM_Dim Word_LSTM_Dim
# Wang2Vec  IOB2           True  False              50            100            10.00
#                                True               25            100             9.00
#                                False              50            200             6.00
#           IOBES          True  True               25            200            10.00
#           IOB2           True  True               50            100            10.00
#                                                                 200             9.00
#           IOBES          True  True               25            100            10.00
#                                                   50            100            10.00
#                                False              50            100             7.00
# ...

# %%
len(dados_sem_outliers_df)
# Out:
# 1071

# %%
dados_sem_outliers_df.to_csv('resultados_sem_outliers.csv')
